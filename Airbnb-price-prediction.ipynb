# %% [markdown]
# ## Final Project Submission
#
# * Student name: Laura Lewis
# * Student pace: full time
# * Scheduled project review date/time: 17 May 2019, 3pm BST
# * Instructor name: Joe San Pietro
# * Blog post URL: part 1 (cleaning and pre-processing): https://towardsdatascience.com/predicting-airbnb-prices-with-deep-learning-part-1-how-to-clean-up-airbnb-data-a5d58e299f6c?source=friends_link&sk=0ad5a63e68210846c65f231826921a00
# ***

# %% [markdown]
# # Table of contents

# %% [markdown]
# [1. Introduction and project aims](#Introduction-and-project-aims)
#
# [2. The dataset](#The-dataset)
#
# [3. Cleaning and pre-processing](#Cleaning-and-pre-processing)
#
# [4. Exploratory data analysis](#Exploratory-data-analysis)
#    - [Time series](#Time-series)
#    - [Numerical features](#Numerical-features)
#    - [Categorical features](#Categorical-features)
#    - [Boolean (true or false) features](#Boolean-(true-or-false)-features)
#
# [5. Preparing the data for modeling](#Preparing-the-data-for-modeling)
#
# [6. Building a neural network](#Building-a-neural-network)
#
# [7. Conclusions and recommendations](#Conclusions-and-recommendations)

# %% [markdown]
# ***

# %% [markdown]
# # Introduction and project aims

# %% [markdown]
# Airbnb is a home-sharing platform that allows home-owners and renters ('hosts') to put their properties ('listings') online, so that guests can pay to stay in them. Hosts are expected to set their own prices for their listings. Although Airbnb and other sites provide some general guidance, there are currently no free services which help hosts price their properties. Paid third party pricing software is available, but generally you are required to put in your own expected average price ('base price'), and the algorithm will vary the daily price around that base price on each day depending on day of the week, seasonality, how far away the date is, and other factors.
#
# Airbnb pricing is important to get right, particularly in big cities like London where there is lots of competition and even small differences in prices can make the difference between optimum occupancy and high earnings, or being priced out of the market. It is also a difficult thing to do correctly, in order to balance the price with occupancy (which varies inversely with price) in order to maximise revenue.
#
# This project aims to use machine learning and deep learning to predict the base price for properties in London, and also to explore Airbnb listing data, in order to help Airbnb hosts maximise their earnings.
#
# Additional context: I previously worked for a year and a half at an Airbnb property management company, as head of the team responsible for pricing, revenue and analysis. Decisions made during the course of this project are therefore informed by domain expertise in this industry.

# %% [markdown]
# ***

# %% [markdown]
# # The dataset

# %% [markdown]
# The dataset used for this project comes from [Insideairbnb.com](https://insideairbnb.com/), an anti-Airbnb lobby group that scrapes Airbnb listings, reviews and calendar data for multiple cities around the world. The dataset was scraped on 9 April 2019 and contains information on all London Airbnb listings that were live on the site on that date. A GeoJSON file of London borough boundaries was also downloaded from the same site.
#
# The data is quite messy, and has some limitations. The major one is that it only includes the advertised price (sometimes called the 'sticker' price). The sticker price is the overall nightly price that is advertised to potential guests, rather than the actual average amount paid per night by previous guests. The advertised prices can be set to any arbitrary amount by the host, and hosts that are less experienced with Airbnb will often set these to very low (e.g. £0) or very high (e.g. £10,000) amounts.
#
# Nevertheless, this dataset can be used as a proof of concept. A more accurate version could be built using data on the actual average nightly rates paid, e.g. from sites like [AirDNA](https://www.airdna.co/) that sell higher quality Airbnb data.

# %% [markdown]
# ***

# %% [markdown]
# # Cleaning and pre-processing

# %% [markdown]
# ### Importing the libraries and data

# %%
# Importing required libraries
import pandas as pd
import numpy as np
from numpy.random import seed
seed(123)
import matplotlib.pyplot as plt
# %matplotlib inline
from datetime import datetime
import seaborn as sns
import geopandas as gpd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split, cross_val_score
import xgboost as xgb
from xgboost import plot_importance
from sklearn.metrics import explained_variance_score, mean_squared_error, r2_score
import time
from keras import models, layers, optimizers, regularizers
from keras.utils.vis_utils import model_to_dot
from IPython.display import SVG
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
raw_df = pd.read_csv('data/airbnb_listings_09-04-19.csv')
print(f"The dataset contains {len(raw_df)} Airbnb listings")
pd.set_option('display.max_columns', len(raw_df.columns)) # To view all columns
pd.set_option('display.max_rows', 100)
raw_df.head(3)
# Out:
# The dataset contains 79671 Airbnb listings
# C:\Users\Laura\Anaconda3\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (61,62,94) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       id                         listing_url       scrape_id last_scraped  \
# 0  13913  https://www.airbnb.com/rooms/13913  20190409040957   2019-04-11
# 1  15400  https://www.airbnb.com/rooms/15400  20190409040957   2019-04-11
# 2  17402  https://www.airbnb.com/rooms/17402  20190409040957   2019-04-11
#
#                                     name  \
# 0    Holiday London DB Room Let-on going
# 1    Bright Chelsea  Apartment. Chelsea!
# 2  Superb 3-Bed/2 Bath & Wifi: Trendy W1
#
#                                              summary  \
# 0  My bright double bedroom with a large window h...
# 1  Lots of windows and light.  St Luke's Gardens ...
# 2  Open from June 2018 after a 3-year break, we a...
#
#                                                space  \
# 0  Hello Everyone, I'm offering my lovely double ...
# 1  Bright Chelsea Apartment  This is a bright one...
# 2  Ready again from June 2018 for bookings after ...
#
#                                          description experiences_offered  \
# 0  My bright double bedroom with a large window h...            business
# 1  Lots of windows and light.  St Luke's Gardens ...            romantic
# 2  Open from June 2018 after a 3-year break, we a...                none
#
#                                neighborhood_overview  \
# 0  Finsbury Park is a friendly melting pot commun...
# 1                                     It is Chelsea.
# 2  Location, location, location! You won't find b...
#
#                                                notes  \
# 0  For art lovers I can give guest my Tate Member...
# 1  The building next door is in the process of be...
# 2  This property has new flooring throughout. Gue...
#
#                                              transit  \
# 0  The flat only a 10 minute walk to Finsbury Par...
# 1  The underground stations are South Kensington ...
# 2  You can walk to tourist London or take numerou...
#
#                                               access  \
# 0  Guest will have access to the self catering ki...
# 1  There are two wardrobes for guests exclusive u...
# 2            Full use of whole independent apartment
#
#                                          interaction  \
# 0  I like to have little chats with my guest over...
# 1  If I am in the country I like to welcome my gu...
# 2  Always available by email or phone (before, du...
#
#                                          house_rules  thumbnail_url  \
# 0  I'm an artist and have my artwork up on the wa...            NaN
# 1  NO SMOKING PLEASE.. No unauthorised guests. No...            NaN
# 2  The apartment benefits from new flooring throu...            NaN
#
#    medium_url                                        picture_url  \
# 0         NaN  https://a0.muscache.com/im/pictures/985879/b06...
# 1         NaN  https://a0.muscache.com/im/pictures/428392/462...
# 2         NaN  https://a0.muscache.com/im/pictures/5673eb4f-a...
#
#    xl_picture_url  host_id                                 host_url host_name  \
# 0             NaN    54730  https://www.airbnb.com/users/show/54730     Alina
# 1             NaN    60302  https://www.airbnb.com/users/show/60302  Philippa
# 2             NaN    67564  https://www.airbnb.com/users/show/67564       Liz
#
#    host_since                        host_location  \
# 0  2009-11-16      London, England, United Kingdom
# 1  2009-12-05  Kensington, England, United Kingdom
# 2  2010-01-04      London, England, United Kingdom
#
#                                           host_about  host_response_time  \
# 0  I am a Multi-Media Visual Artist and Creative ...        within a day
# 1  English, grandmother,  I have travelled quite ...  within a few hours
# 2  We are Liz and Jack.  We manage a number of ho...  within a few hours
#
#   host_response_rate  host_acceptance_rate host_is_superhost  \
# 0                60%                   NaN                 f
# 1               100%                   NaN                 f
# 2                62%                   NaN                 t
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/users/54730/profile...
# 1  https://a0.muscache.com/im/users/60302/profile...
# 2  https://a0.muscache.com/im/users/67564/profile...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/54730/profile...    LB of Islington
# 1  https://a0.muscache.com/im/users/60302/profile...            Chelsea
# 2  https://a0.muscache.com/im/users/67564/profile...          Fitzrovia
#
#    host_listings_count  host_total_listings_count  \
# 0                  4.0                        4.0
# 1                  1.0                        1.0
# 2                 16.0                       16.0
#
#                                   host_verifications host_has_profile_pic  \
# 0          ['email', 'phone', 'facebook', 'reviews']                    t
# 1  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 2  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
#
#   host_identity_verified                                     street  \
# 0                      f  Islington, Greater London, United Kingdom
# 1                      t                     London, United Kingdom
# 2                      t          London, Fitzrovia, United Kingdom
#
#      neighbourhood  neighbourhood_cleansed  neighbourhood_group_cleansed  \
# 0  LB of Islington               Islington                           NaN
# 1          Chelsea  Kensington and Chelsea                           NaN
# 2        Fitzrovia             Westminster                           NaN
#
#         city           state zipcode  market             smart_location  \
# 0  Islington  Greater London    N4 3  London  Islington, United Kingdom
# 1     London             NaN     SW3  London     London, United Kingdom
# 2     London       Fitzrovia  W1T4BP  London     London, United Kingdom
#
#   country_code         country  latitude  longitude is_location_exact  \
# 0           GB  United Kingdom  51.56802   -0.11121                 t
# 1           GB  United Kingdom  51.48796   -0.16898                 t
# 2           GB  United Kingdom  51.52098   -0.14002                 t
#
#   property_type        room_type  accommodates  bathrooms  bedrooms  beds  \
# 0     Apartment     Private room             2        1.0       1.0   0.0
# 1     Apartment  Entire home/apt             2        1.0       1.0   1.0
# 2     Apartment  Entire home/apt             6        2.0       3.0   3.0
#
#    bed_type                                          amenities  square_feet  \
# 0  Real Bed  {TV,"Cable TV",Wifi,Kitchen,"Paid parking off ...        538.0
# 1  Real Bed  {TV,"Cable TV",Internet,Wifi,"Air conditioning...          NaN
# 2  Real Bed  {TV,Wifi,Kitchen,"Paid parking off premises",E...          NaN
#
#      price weekly_price monthly_price security_deposit cleaning_fee  \
# 0   $65.00      $333.00     $1,176.00          $100.00       $15.00
# 1  $100.00      $600.00     $2,250.00          $150.00       $50.00
# 2  $500.00    $1,378.00           NaN          $350.00       $65.00
#
#    guests_included extra_people  minimum_nights  maximum_nights  \
# 0                1       $15.00               1              29
# 1                2        $0.00               3              50
# 2                4       $10.00               3             365
#
#    minimum_minimum_nights  maximum_minimum_nights  minimum_maximum_nights  \
# 0                       1                       1                      29
# 1                       3                       3                      50
# 2                       3                       3                     365
#
#    maximum_maximum_nights  minimum_nights_avg_ntm  maximum_nights_avg_ntm  \
# 0                      29                     1.0                    29.0
# 1                      50                     3.0                    50.0
# 2                     365                     3.0                   365.0
#
#   calendar_updated has_availability  availability_30  availability_60  \
# 0     4 months ago                t               10               39
# 1      5 weeks ago                t                4                4
# 2        yesterday                t               30               60
#
#    availability_90  availability_365 calendar_last_scraped  number_of_reviews  \
# 0               68               343            2019-04-11                 14
# 1                4               134            2019-04-11                 81
# 2               89               364            2019-04-11                 39
#
#    number_of_reviews_ltm first_review last_review  review_scores_rating  \
# 0                      3   2010-08-18  2018-06-17                  95.0
# 1                      0   2009-12-21  2018-03-30                  95.0
# 2                     14   2011-03-21  2018-10-15                  93.0
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                     9.0                       10.0                    9.0
# 1                    10.0                       10.0                   10.0
# 2                    10.0                        9.0                    9.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                     9.0                  9.0
# 1                         10.0                    10.0                  9.0
# 2                          9.0                    10.0                  9.0
#
#   requires_license license  jurisdiction_names instant_bookable  \
# 0                f     NaN                 NaN                f
# 1                f     NaN                 NaN                f
# 2                f     NaN                 NaN                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f                     moderate
# 1                        f  strict_14_with_grace_period
# 2                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             t                                t
# 2                             f                                f
#
#    calculated_host_listings_count  \
# 0                               3
# 1                               1
# 2                              13
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
# 1                                            1
# 2                                           13
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             2
# 1                                             0
# 2                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.13
# 1                                            0               0.71
# 2                                            0               0.40

# %% [markdown]
# ### Dropping initial columns

# %% [markdown]
# NLP will not be used in the creation of an initial model (although they could be used to augment the model later, e.g. through sentiment analysis). Therefore, free text columns will be dropped for now, as will other columns which are not useful for predicting price (e.g. url, host name and other host-related features that are unrelated to the property).

# %%
cols_to_drop = ['listing_url', 'scrape_id', 'last_scraped', 'name', 'summary', 'space', 'description', 'neighborhood_overview', 'notes', 'transit', 'access', 'interaction', 'house_rules', 'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_location', 'host_about', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'host_verifications', 'calendar_last_scraped']
df = raw_df.drop(cols_to_drop, axis=1)

# %% [markdown]
# Other columns can be dropped because they contain a majority of null entries.

# %%
df.isna().sum()
# Out:
# id                                                  0
# experiences_offered                                 0
# host_since                                        248
# host_response_time                              25699
# host_response_rate                              25699
# host_acceptance_rate                            79671
# host_is_superhost                                 248
# host_listings_count                               248
# host_total_listings_count                         248
# host_has_profile_pic                              248
# host_identity_verified                            248
# street                                              0
# neighbourhood                                       0
# neighbourhood_cleansed                              0
# neighbourhood_group_cleansed                    79671
# city                                              142
# state                                           17389
# zipcode                                          1938
# market                                            887
# smart_location                                      0
# country_code                                        0
# country                                             0
# latitude                                            0
# longitude                                           0
# is_location_exact                                   0
# property_type                                       0
# room_type                                           0
# accommodates                                        0
# bathrooms                                         147
# bedrooms                                           37
# beds                                              134
# bed_type                                            0
# amenities                                           0
# square_feet                                     79217
# price                                               0
# weekly_price                                    71828
# monthly_price                                   74079
# security_deposit                                28329
# cleaning_fee                                    21082
# guests_included                                     0
# extra_people                                        0
# minimum_nights                                      0
# maximum_nights                                      0
# minimum_minimum_nights                              0
# maximum_minimum_nights                              0
# minimum_maximum_nights                              0
# maximum_maximum_nights                              0
# minimum_nights_avg_ntm                              0
# maximum_nights_avg_ntm                              0
# calendar_updated                                    0
# has_availability                                    0
# availability_30                                     0
# availability_60                                     0
# availability_90                                     0
# availability_365                                    0
# number_of_reviews                                   0
# number_of_reviews_ltm                               0
# first_review                                    20342
# last_review                                     20342
# review_scores_rating                            22012
# review_scores_accuracy                          22072
# review_scores_cleanliness                       22057
# review_scores_checkin                           22127
# review_scores_communication                     22066
# review_scores_location                          22128
# review_scores_value                             22128
# requires_license                                    0
# license                                         79507
# jurisdiction_names                              79671
# instant_bookable                                    0
# is_business_travel_ready                            0
# cancellation_policy                                 0
# require_guest_profile_picture                       0
# require_guest_phone_verification                    0
# calculated_host_listings_count                      0
# calculated_host_listings_count_entire_homes         0
# calculated_host_listings_count_private_rooms        0
# calculated_host_listings_count_shared_rooms         0
# reviews_per_month                               20342
# dtype: int64

# %%
df.drop(['host_acceptance_rate', 'neighbourhood_group_cleansed', 'square_feet', 'weekly_price', 'monthly_price', 'license', 'jurisdiction_names'], axis=1, inplace=True)

df.set_index('id', inplace=True) # The id will be used as the index, as this could be useful in future e.g. if a separate dataset containing reviews for each property is linked to this one

# %% [markdown]
# host_listings_count and host_total_listings_count are the same in all but 248 cases. These cases are those where the value is NaN. Therefore one of these columns can be dropped. Other columns which split these into type of property will also be dropped, as they will be highly correlated (one will be the total of the others).

# %%
print(sum((df.host_listings_count == df.host_total_listings_count) == False))
df.loc[((df.host_listings_count == df.host_total_listings_count) == False)][:5]
# Out:
# 248
#        experiences_offered host_since host_response_time host_response_rate  \
# id
# 381741                none        NaN                NaN                NaN
# 388743                none        NaN                NaN                NaN
# 396100                none        NaN                NaN                NaN
# 400441                none        NaN                NaN                NaN
# 423592                none        NaN                NaN                NaN
#
#        host_is_superhost  host_listings_count  host_total_listings_count  \
# id
# 381741               NaN                  NaN                        NaN
# 388743               NaN                  NaN                        NaN
# 396100               NaN                  NaN                        NaN
# 400441               NaN                  NaN                        NaN
# 423592               NaN                  NaN                        NaN
#
#        host_has_profile_pic host_identity_verified  \
# id
# 381741                  NaN                    NaN
# 388743                  NaN                    NaN
# 396100                  NaN                    NaN
# 400441                  NaN                    NaN
# 423592                  NaN                    NaN
#
#                              street               neighbourhood  \
# id
# 381741       London, United Kingdom                 LB of Brent
# 388743  Lee, London, United Kingdom              LB of Lewisham
# 396100       London, United Kingdom               LB of Bromley
# 400441       London, United Kingdom                LB of Newham
# 423592      Barking, United Kingdom  LB of Barking and Dagenham
#
#        neighbourhood_cleansed     city   state   zipcode  market  \
# id
# 381741                  Brent   London     NaN      NW10  London
# 388743               Lewisham      Lee  London  SE12 0PT  London
# 396100                Bromley   London     NaN  SE26 4EQ  London
# 400441                 Newham   London     NaN   E12 6UW  London
# 423592   Barking and Dagenham  Barking     NaN  IG11 8LJ  London
#
#                  smart_location country_code         country  latitude  \
# id
# 381741   London, United Kingdom           GB  United Kingdom  51.53571
# 388743      Lee, United Kingdom           GB  United Kingdom  51.45615
# 396100   London, United Kingdom           GB  United Kingdom  51.42273
# 400441   London, United Kingdom           GB  United Kingdom  51.54841
# 423592  Barking, United Kingdom           GB  United Kingdom  51.53922
#
#         longitude is_location_exact property_type        room_type  \
# id
# 381741   -0.24497                 f     Apartment  Entire home/apt
# 388743    0.00956                 f     Apartment     Private room
# 396100   -0.05679                 t         House     Private room
# 400441    0.04934                 t     Apartment     Private room
# 423592    0.07048                 t     Apartment     Private room
#
#         accommodates  bathrooms  bedrooms  beds  bed_type  \
# id
# 381741             6        2.0       2.0   2.0  Real Bed
# 388743             1        NaN       1.0   1.0  Real Bed
# 396100             4        1.5       2.0   4.0  Real Bed
# 400441             2        2.0       1.0   1.0  Real Bed
# 423592             2        0.0       1.0   1.0  Real Bed
#
#                                                 amenities    price  \
# id
# 381741  {TV,"Cable TV",Internet,Wifi,Kitchen,"Pets liv...  $100.00
# 388743                                         {Internet}   $80.00
# 396100  {TV,Wifi,"Pets allowed","Pets live on this pro...   $60.00
# 400441  {TV,Wifi,Kitchen,"Free parking on premises",He...   $30.00
# 423592                                                 {}   $70.00
#
#        security_deposit cleaning_fee  guests_included extra_people  \
# id
# 381741          $250.00       $35.00                1        $0.00
# 388743              NaN          NaN                1        $0.00
# 396100            $0.00        $0.00                4        $0.00
# 400441              NaN          NaN                1       $20.00
# 423592              NaN          NaN                1        $0.00
#
#         minimum_nights  maximum_nights  minimum_minimum_nights  \
# id
# 381741               1            1125                       1
# 388743               1            1125                       1
# 396100               1               7                       1
# 400441             180            1825                     180
# 423592               1            1125                       1
#
#         maximum_minimum_nights  minimum_maximum_nights  \
# id
# 381741                       1                    1125
# 388743                       1                    1125
# 396100                       2                       7
# 400441                     180                    1825
# 423592                       1                    1125
#
#         maximum_maximum_nights  minimum_nights_avg_ntm  \
# id
# 381741                    1125                     1.0
# 388743                    1125                     1.0
# 396100                       7                     1.3
# 400441                    1825                   180.0
# 423592                    1125                     1.0
#
#         maximum_nights_avg_ntm calendar_updated has_availability  \
# id
# 381741                  1125.0            today                t
# 388743                  1125.0            never                t
# 396100                     7.0       4 days ago                t
# 400441                  1825.0    21 months ago                t
# 423592                  1125.0    85 months ago                t
#
#         availability_30  availability_60  availability_90  availability_365  \
# id
# 381741               11               20               37               310
# 388743               30               60               90               365
# 396100               16               37               61               123
# 400441               30               60               90               365
# 423592               30               60               90               365
#
#         number_of_reviews  number_of_reviews_ltm first_review last_review  \
# id
# 381741                  7                      0   2012-06-10  2013-01-02
# 388743                  0                      0          NaN         NaN
# 396100                 20                      4   2017-04-04  2019-01-04
# 400441                  0                      0          NaN         NaN
# 423592                  0                      0          NaN         NaN
#
#         review_scores_rating  review_scores_accuracy  \
# id
# 381741                 100.0                     9.0
# 388743                   NaN                     NaN
# 396100                  99.0                    10.0
# 400441                   NaN                     NaN
# 423592                   NaN                     NaN
#
#         review_scores_cleanliness  review_scores_checkin  \
# id
# 381741                        9.0                    9.0
# 388743                        NaN                    NaN
# 396100                       10.0                   10.0
# 400441                        NaN                    NaN
# 423592                        NaN                    NaN
#
#         review_scores_communication  review_scores_location  \
# id
# 381741                         10.0                     8.0
# 388743                          NaN                     NaN
# 396100                         10.0                     9.0
# 400441                          NaN                     NaN
# 423592                          NaN                     NaN
#
#         review_scores_value requires_license instant_bookable  \
# id
# 381741                  9.0                f                f
# 388743                  NaN                f                f
# 396100                  9.0                f                f
# 400441                  NaN                f                f
# 423592                  NaN                f                f
#
#        is_business_travel_ready          cancellation_policy  \
# id
# 381741                        f  strict_14_with_grace_period
# 388743                        f                     flexible
# 396100                        f                     flexible
# 400441                        f                     moderate
# 423592                        f                     flexible
#
#        require_guest_profile_picture require_guest_phone_verification  \
# id
# 381741                             f                                f
# 388743                             f                                f
# 396100                             f                                f
# 400441                             f                                f
# 423592                             f                                f
#
#         calculated_host_listings_count  \
# id
# 381741                               1
# 388743                               1
# 396100                               6
# 400441                               1
# 423592                               1
#
#         calculated_host_listings_count_entire_homes  \
# id
# 381741                                            1
# 388743                                            0
# 396100                                            0
# 400441                                            0
# 423592                                            0
#
#         calculated_host_listings_count_private_rooms  \
# id
# 381741                                             0
# 388743                                             1
# 396100                                             6
# 400441                                             1
# 423592                                             1
#
#         calculated_host_listings_count_shared_rooms  reviews_per_month
# id
# 381741                                            0               0.08
# 388743                                            0                NaN
# 396100                                            0               0.81
# 400441                                            0                NaN
# 423592                                            0                NaN

# %%
df.drop(['host_total_listings_count', 'calculated_host_listings_count', 'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_shared_rooms'], axis=1, inplace=True)

# %% [markdown]
# There are multiple columns for property location, including an attempt by the site that originally scraped the data to clean up the neighbourhood locations. Some of these columns can be dropped. Because all of the listings are in London, columns relating to city and country can be dropped. One columns for area (borough) will be kept - 'neighboorhood_cleansed'. Latitude and longitude will be saved in a dataframe for later use (see modelling section below).

# %%
lat_long = df[['latitude', 'longitude']]

# %%
df.drop(['zipcode', 'latitude', 'longitude', 'street', 'neighbourhood', 'city', 'state', 'market', 'smart_location', 'country_code', 'country', 'is_location_exact'], axis=1, inplace=True)

# %% [markdown]
# There are multiple columns for minimum and maximum night stays, but the two main ones will be used as there are few differences between e.g. minimum_nights and minimum_minimum_nights. The latter presumably refers to the fact that min/max night stays can vary over the year. The default (i.e. most frequently applied) min/max night stay values will be used instead.

# %%
sum((df.minimum_nights == df.minimum_minimum_nights) == False)
# Out:
# 4698

# %%
df.drop(['minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm'], axis=1, inplace=True)

# %% [markdown]
# Checking whether boolean and categorical features contain sufficient numbers of instances in each category to make them worth including:

# %%
# Replacing columns with f/t with 0/1
df.replace({'f': 0, 't': 1}, inplace=True)

# Plotting the distribution of numerical and boolean categories
df.hist(figsize=(20,20));

# %% [markdown]
# From the above, it can be seen that several columns only contain one category and can be dropped:

# %%
df.drop(['has_availability', 'host_has_profile_pic', 'is_business_travel_ready', 'require_guest_phone_verification', 'require_guest_profile_picture', 'requires_license'], axis=1, inplace=True)

# %% [markdown]
# ### Description of each column:
# - experiences_offered - slightly unclear as it does not appear to directly relate to Airbnb Experiences, but this seems to be the main recommended category of travel type, e.g. business
# - host_since - date that the host first joined Airbnb
# - host_response_time - average amount of time the host takes to reply to messages
# - host_response_rate - proportion of messages that the host replies to
# - host_is_superhost - whether or not the host is a superhost, which is a mark of quality for the top-rated and most experienced hosts, and can increase your search ranking on Airbnb
# - host_listings_count - how many listings the host has in total
# - host_identity_verified - whether or not the host has been verified with id
# - neighbourhood_cleansed - the London borough the property is in
# - property_type - type of property, e.g. house or flat
# - room_type - type of listing, e.g. entire home, private room or shared room
# - accommodates - how many people the property accommodates
# - bathrooms - number of bathrooms
# - bedrooms - number of bedrooms
# - beds - number of beds
# - bed_type - type of bed, e.g. real bed or sofa-bed
# - amenities - list of amenities
# - price - nightly advertised price (the target variable)
# - security_deposit - the amount required as a security deposit
# - cleaning_fee - the amount of the cleaning fee (a fixed amount paid per booking)
# - guests_included - the number of guests included in the booking fee
# - extra_people - the price per additional guest above the guests_included price
# - minimum_nights - the minimum length of stay
# - maximum_nights - the maximum length of stay
# - calendar_updated - when the host last updated the calendar
# - availability_30 - how many nights are available to be booked in the next 30 days
# - availability_60 - how many nights are available to be booked in the next 60 days
# - availability_90 - how many nights are available to be booked in the next 90 days
# - availability_365 - how many nights are available to be booked in the next 365 days
# - number_of_reviews - the number of reviews left for the property
# - number_of_reviews_ltm - the number of reviews left for the property in the last twelve months
# - first_review - the date of the first review
# - last_review - the date of the most recent review
# - review_scores_rating - guests can score properties overall from 1 to 5 stars
# - review_scores_accuracy - guests can score the accuracy of a property's description from 1 to 5 stars
# - review_scores_cleanliness - guests can score a property's cleanliness from 1 to 5 stars
# - review_scores_checkin - guests can score their check-in from 1 to 5 stars
# - review_scores_communication - guests can score a host's communication from 1 to 5 stars
# - review_scores_location - guests can score a property's location from 1 to 5 stars
# - review_scores_value - guests can score a booking's value for money from 1 to 5 stars
# - instant_bookable - whether or not the property can be instant booked (i.e. booked straight away, without having to message the host first and wait to be accepted)
# - cancellation_policy - the type of cancellation policy, e.g. strict or moderate
# - reviews_per_month - calculated field of the average number of reviews left by guest each month

# %% [markdown]
# ### Cleaning individual columns

# %% [markdown]
# **experiences_offered**

# %% [markdown]
# Most listings offer no experiences so this feature can be dropped.

# %%
df.experiences_offered.value_counts()
# Out:
# none        77782
# business      636
# family        529
# social        485
# romantic      239
# Name: experiences_offered, dtype: int64

# %%
df.drop('experiences_offered', axis=1, inplace=True)

# %% [markdown]
# **host_since**
#
# This is a datetime column, and will be converted into a measure of the number of days that a host has been on the platform, measured from the date that the data was scraped (9 April 2019). The original column will be left in initially for EDA, and dropped later.

# %%
# Converting to datetime
df.host_since = pd.to_datetime(df.host_since) 

# Calculating the number of days
df['host_days_active'] = (datetime(2019, 4, 9) - df.host_since).astype('timedelta64[D]')

# Printing mean and median
print("Mean days as host:", round(df['host_days_active'].mean(),0))
print("Median days as host:", df['host_days_active'].median())

# Replacing null values with the median
df.host_days_active.fillna(df.host_days_active.median(), inplace=True)
# Out:
# Mean days as host: 1336.0
# Median days as host: 1328.0

# %% [markdown]
# **host_response_time**

# %% [markdown]
# About a third of rows don't have a value for host_response_time, and the majority of these have also not yet been reviewed. Therefore this section of the dataset consists primarily of properties which have not yet had a completed stay (most likely properties which have not yet had a booking, although may also include properties that have a booking currently occuring). Although this is a considerable proportion of the dataset, these listings will be retained in the data because they are still legitimate properties with advertised prices, and are still part of the comparative market when considering the price for which to advertise your Airbnb listing. However, if the dataset being used had the actual average price paid as its target, it would be necessary to drop these rows because they would not have a value, as they have not yet been booked.
#
# It is worth noting, however, that this group of listings probably also contains a large number of 'inactive' listings. These are properties which have been speculatively listed on Airbnb but either have their calendars closed (so no stays can be booked), or have prices which are notably higher than other properties in their area. The latter occurs in some cases when people who regularly live in a property put their property on Airbnb at a high price just to see if anyone is willing to book at that price (some Airbnb listings are indeed booked at very high prices). Then if their property is booked, they will decamp to a cheaper hotel for those dates, and pocket the difference in price.
#
# Because host_response_time is unknown for so many listings, it will be retained as its own category, 'unknown'.

# %%
print("Null values:", df.host_response_time.isna().sum())
print(f"Proportion: {round((df.host_response_time.isna().sum()/len(df))*100, 1)}%")

# Number of rows without a value for host_response_time which have also not yet had a review
len(df[df.loc[ :,['host_response_time ', 'first_review'] ].isnull().sum(axis=1) == 2])
# Out:
# Null values: 25699
# Proportion: 32.3%
# C:\Users\Laura\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
# 20342

# %%
df.host_response_time.fillna("unknown", inplace=True)
df.host_response_time.value_counts(normalize=True)
# Out:
# within an hour        0.423943
# unknown               0.322564
# within a few hours    0.134001
# within a day          0.098430
# a few days or more    0.021062
# Name: host_response_time, dtype: float64

# %%
df.host_response_time.value_counts(normalize=True)
# Out:
# within an hour        0.423943
# unknown               0.322564
# within a few hours    0.134001
# within a day          0.098430
# a few days or more    0.021062
# Name: host_response_time, dtype: float64

# %% [markdown]
# **host_response_rate**

# %% [markdown]
# A similar story is true for host_response_rate, with about a third of values being null. This will also be kept as its own category, after grouping other values into meaningful groups (i.e. transforming this into a categorical feature, rather than a numerical one). Because about 70% of hosts respond 100% of the time, this will be kept as its own category, and other values will be grouped into bins.

# %%
print("Null values:", df.host_response_rate.isna().sum())
print(f"Proportion: {round((df.host_response_rate.isna().sum()/len(df))*100, 1)}%")
# Out:
# Null values: 25699
# Proportion: 32.3%

# %%
# Removing the % sign from the host_response_rate string and converting to an integer
df.host_response_rate = df.host_response_rate.str[:-1].astype('float64')

print("Mean host response rate:", round(df['host_response_rate'].mean(),0))
print("Median host response rate:", df['host_response_rate'].median())
print(f"Proportion of 100% host response rates: {round(((df.host_response_rate == 100.0).sum()/df.host_response_rate.count())*100,1)}%")
# Out:
# Mean host response rate: 93.0
# Median host response rate: 100.0
# Proportion of 100% host response rates: 69.9%

# %%
# Bin into four categories
df.host_response_rate = pd.cut(df.host_response_rate, bins=[0, 50, 90, 99, 100], labels=['0-49%', '50-89%', '90-99%', '100%'], include_lowest=True)

# Converting to string
df.host_response_rate = df.host_response_rate.astype('str')

# Replace nulls with 'unknown'
df.host_response_rate.replace('nan', 'unknown', inplace=True)

# Category counts
df.host_response_rate.value_counts()
# Out:
# 100%       37730
# unknown    25699
# 50-89%      7346
# 90-99%      6519
# 0-49%       2377
# Name: host_response_rate, dtype: int64

# %% [markdown]
# **host_is_superhost**

# %% [markdown]
# There are 248 rows lacking values for each of five different host-related features. These rows will be dropped.

# %%
# Number of rows without a value for multiple host-related columns
len(df[df.loc[ :,['host_since ', 'host_is_superhost', 'host_listings_count', 'host_has_profile_pic', 'host_identity_verified'] ].isnull().sum(axis=1) == 5])
# Out:
# C:\Users\Laura\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
# 248

# %%
df.dropna(subset=['host_since'], inplace=True)

# %% [markdown]
# **property_type**

# %% [markdown]
# Some cleaning of property types is required as there are a large number of categories with only a few listings. The categories 'apartment', 'house' and 'other' will be used, as most properties can be classified as either apartments or houses.

# %%
df.property_type.value_counts()
# Out:
# Apartment                 53857
# House                     16116
# Townhouse                  2913
# Serviced apartment         2144
# Bed and breakfast           890
# Condominium                 888
# Loft                        718
# Guest suite                 323
# Guesthouse                  254
# Other                       219
# Hostel                      214
# Boutique hotel              209
# Bungalow                    125
# Hotel                       112
# Cottage                      86
# Aparthotel                   62
# Villa                        54
# Boat                         53
# Tiny house                   38
# Cabin                        24
# Houseboat                    24
# Casa particular (Cuba)       20
# Camper/RV                    19
# Hut                           9
# Earth house                   9
# Chalet                        7
# Barn                          7
# Farm stay                     5
# Yurt                          4
# Treehouse                     3
# Dome house                    3
# Nature lodge                  3
# Campsite                      2
# Lighthouse                    1
# In-law                        1
# Resort                        1
# Ryokan (Japan)                1
# Parking Space                 1
# Island                        1
# Bus                           1
# Tent                          1
# Plane                         1
# Name: property_type, dtype: int64

# %%
# Replacing categories that are types of houses or apartments
df.property_type.replace({
    'Townhouse': 'House',
    'Serviced apartment': 'Apartment',
    'Loft': 'Apartment',
    'Bungalow': 'House',
    'Cottage': 'House',
    'Villa': 'House',
    'Tiny house': 'House',
    'Earth house': 'House',
    'Chalet': 'House'  
    }, inplace=True)

# Replacing other categories with 'other'
df.loc[~df.property_type.isin(['House', 'Apartment']), 'property_type'] = 'Other'

# %% [markdown]
# **bathrooms, bedrooms and beds**

# %% [markdown]
# Missing values will be replaced with the median (to avoid strange fractions).

# %%
for col in ['bathrooms', 'bedrooms', 'beds']:
    df[col].fillna(df[col].median(), inplace=True)

# %% [markdown]
# **bed_type**

# %% [markdown]
# Most listings have the same bed type so this feature can be dropped.

# %%
df.bed_type.value_counts()
# Out:
# Real Bed         78656
# Pull-out Sofa      448
# Futon              195
# Couch               74
# Airbed              50
# Name: bed_type, dtype: int64

# %%
df.drop('bed_type', axis=1, inplace=True)

# %% [markdown]
# **amenities**

# %% [markdown]
# Amenities is a list of additional features in the property, e.g. whether it has a TV or parking. Examples are below:

# %%
# Example of amenities listed
df.amenities[:1].values
# Out:
# array(['{TV,"Cable TV",Wifi,Kitchen,"Paid parking off premises","Smoking allowed","Free street parking","Buzzer/wireless intercom",Heating,"Family/kid friendly",Washer,Dryer,"Smoke detector","Carbon monoxide detector","Fire extinguisher",Essentials,Shampoo,"Lock on bedroom door",Hangers,"Hair dryer",Iron,"Laptop friendly workspace","Outlet covers",Bathtub,"Children’s books and toys","Babysitter recommendations",Crib,"Pack ’n Play/travel crib","Room-darkening shades","Children’s dinnerware","Hot water","Bed linens","Extra pillows and blankets","Ethernet connection","Coffee maker",Refrigerator,"Dishes and silverware","Cooking basics",Oven,Stove,"Patio or balcony","Luggage dropoff allowed","Long term stays allowed","Step-free access","Wide doorway","Wide clearance to bed","Accessible-height bed","Step-free access","Wide doorway","Bathtub with bath chair","Accessible-height toilet","Host greets you","Handheld shower head","Roll-in shower"}'],
#       dtype=object)

# %%
# Creating a set of all possible amenities
amenities_list = list(df.amenities)
amenities_list_string = " ".join(amenities_list)
amenities_list_string = amenities_list_string.replace('{', '')
amenities_list_string = amenities_list_string.replace('}', ',')
amenities_list_string = amenities_list_string.replace('"', '')
amenities_set = [x.strip() for x in amenities_list_string.split(',')]
amenities_set = set(amenities_set)
amenities_set
# Out:
# {'',
#  '24-hour check-in',
#  'Accessible-height bed',
#  'Accessible-height toilet',
#  'Air conditioning',
#  'Air purifier',
#  'Alfresco bathtub',
#  'Amazon Echo',
#  'Apple TV',
#  'BBQ grill',
#  'Baby bath',
#  'Baby monitor',
#  'Babysitter recommendations',
#  'Balcony',
#  'Bath towel',
#  'Bathroom essentials',
#  'Bathtub',
#  'Bathtub with bath chair',
#  'Beach essentials',
#  'Beach view',
#  'Beachfront',
#  'Bed linens',
#  'Bedroom comforts',
#  'Bidet',
#  'Body soap',
#  'Breakfast',
#  'Breakfast bar',
#  'Breakfast table',
#  'Building staff',
#  'Buzzer/wireless intercom',
#  'Cable TV',
#  'Carbon monoxide detector',
#  'Cat(s)',
#  'Ceiling fan',
#  'Ceiling hoist',
#  'Central air conditioning',
#  'Changing table',
#  "Chef's kitchen",
#  'Children’s books and toys',
#  'Children’s dinnerware',
#  'Cleaning before checkout',
#  'Coffee maker',
#  'Convection oven',
#  'Cooking basics',
#  'Crib',
#  'DVD player',
#  'Day bed',
#  'Dining area',
#  'Disabled parking spot',
#  'Dishes and silverware',
#  'Dishwasher',
#  'Dog(s)',
#  'Doorman',
#  'Double oven',
#  'Dryer',
#  'EV charger',
#  'Electric profiling bed',
#  'Elevator',
#  'En suite bathroom',
#  'Espresso machine',
#  'Essentials',
#  'Ethernet connection',
#  'Exercise equipment',
#  'Extra pillows and blankets',
#  'Family/kid friendly',
#  'Fax machine',
#  'Fire extinguisher',
#  'Fire pit',
#  'Fireplace guards',
#  'Firm mattress',
#  'First aid kit',
#  'Fixed grab bars for shower',
#  'Fixed grab bars for toilet',
#  'Flat path to front door',
#  'Formal dining area',
#  'Free parking on premises',
#  'Free street parking',
#  'Full kitchen',
#  'Game console',
#  'Garden or backyard',
#  'Gas oven',
#  'Ground floor access',
#  'Gym',
#  'HBO GO',
#  'Hair dryer',
#  'Hammock',
#  'Handheld shower head',
#  'Hangers',
#  'Heat lamps',
#  'Heated floors',
#  'Heated towel rack',
#  'Heating',
#  'High chair',
#  'High-resolution computer monitor',
#  'Host greets you',
#  'Hot tub',
#  'Hot water',
#  'Hot water kettle',
#  'Indoor fireplace',
#  'Internet',
#  'Iron',
#  'Ironing Board',
#  'Jetted tub',
#  'Keypad',
#  'Kitchen',
#  'Kitchenette',
#  'Lake access',
#  'Laptop friendly workspace',
#  'Lock on bedroom door',
#  'Lockbox',
#  'Long term stays allowed',
#  'Luggage dropoff allowed',
#  'Memory foam mattress',
#  'Microwave',
#  'Mini fridge',
#  'Mobile hoist',
#  'Mountain view',
#  'Mudroom',
#  'Murphy bed',
#  'Netflix',
#  'Office',
#  'Other',
#  'Other pet(s)',
#  'Outdoor kitchen',
#  'Outdoor parking',
#  'Outdoor seating',
#  'Outlet covers',
#  'Oven',
#  'Pack ’n Play/travel crib',
#  'Paid parking off premises',
#  'Paid parking on premises',
#  'Patio or balcony',
#  'Pets allowed',
#  'Pets live on this property',
#  'Pillow-top mattress',
#  'Pocket wifi',
#  'Pool',
#  'Pool cover',
#  'Pool with pool hoist',
#  'Printer',
#  'Private bathroom',
#  'Private entrance',
#  'Private gym',
#  'Private hot tub',
#  'Private living room',
#  'Private pool',
#  'Projector and screen',
#  'Propane barbeque',
#  'Rain shower',
#  'Refrigerator',
#  'Roll-in shower',
#  'Room-darkening shades',
#  'Safe',
#  'Safety card',
#  'Sauna',
#  'Security system',
#  'Self check-in',
#  'Shampoo',
#  'Shared gym',
#  'Shared hot tub',
#  'Shared pool',
#  'Shower chair',
#  'Single level home',
#  'Ski-in/Ski-out',
#  'Smart TV',
#  'Smart lock',
#  'Smoke detector',
#  'Smoking allowed',
#  'Soaking tub',
#  'Sound system',
#  'Stair gates',
#  'Stand alone steam shower',
#  'Standing valet',
#  'Steam oven',
#  'Step-free access',
#  'Stove',
#  'Suitable for events',
#  'Sun loungers',
#  'TV',
#  'Table corner guards',
#  'Tennis court',
#  'Terrace',
#  'Toilet paper',
#  'Touchless faucets',
#  'Walk-in shower',
#  'Warming drawer',
#  'Washer',
#  'Washer / Dryer',
#  'Waterfront',
#  'Well-lit path to entrance',
#  'Wheelchair accessible',
#  'Wide clearance to bed',
#  'Wide clearance to shower',
#  'Wide doorway',
#  'Wide entryway',
#  'Wide hallway clearance',
#  'Wifi',
#  'Window guards',
#  'Wine cooler',
#  'toilet',
#  'translation missing: en.hosting_amenity_49',
#  'translation missing: en.hosting_amenity_50'}

# %% [markdown]
# In the list above, some amenities are more important than others (e.g. a balcony is more likely to increase price than a fax machine), and some are likely to be fairly uncommon (e.g. 'Electric profiling bed'). Based on previous experience working in the Airbnb property management industry, and research into which amenities are considered by guests to be more important, a selection of the more important amenities will be extracted. These will be further investigated in the EDA section. For example, if it turns out that almost all properties have/do not have a particular amenity, that feature will not be very useful in helping explain differences in prices.
#
# The amenities chosen are (slashes indicate separate categories that can be combined):
# - 24-hour check-in
# - Air conditioning/central air conditioning
# - Amazon Echo/Apple TV/DVD player/game console/Netflix/projector and screen/smart TV (i.e. non-basic electronics)
# - BBQ grill/fire pit/propane barbeque
# - Balcony/patio or balcony
# - Beach view/beachfront/lake access/mountain view/ski-in ski-out/waterfront (i.e. great location/views)
# - Bed linens
# - Breakfast
# - Cable TV/TV
# - Coffee maker/espresso machine
# - Cooking basics
# - Dishwasher/Dryer/Washer/Washer and dryer
# - Elevator
# - Exercise equipment/gym/private gym/shared gym
# - Family/kid friendly, or anything containing 'children'
# - Free parking on premises/free street parking/outdoor parking/paid parking off premises/paid parking on premises
# - Garden or backyard/outdoor seating/sun loungers/terrace
# - Host greets you
# - Hot tub/jetted tub/private hot tub/sauna/shared hot tub/pool/private pool/shared pool
# - Internet/pocket wifi/wifi
# - Long term stays allowed
# - Pets allowed/cat(s)/dog(s)/pets live on this property/other pet(s)
# - Private entrance
# - Safe/security system
# - Self check-in
# - Smoking allowed
# - Step-free access/wheelchair accessible, or anything containing 'accessible'
# - Suitable for events

# %%
df.loc[df['amenities'].str.contains('24-hour check-in'), 'check_in_24h'] = 1
df.loc[df['amenities'].str.contains('Air conditioning|Central air conditioning'), 'air_conditioning'] = 1
df.loc[df['amenities'].str.contains('Amazon Echo|Apple TV|Game console|Netflix|Projector and screen|Smart TV'), 'high_end_electronics'] = 1
df.loc[df['amenities'].str.contains('BBQ grill|Fire pit|Propane barbeque'), 'bbq'] = 1
df.loc[df['amenities'].str.contains('Balcony|Patio'), 'balcony'] = 1
df.loc[df['amenities'].str.contains('Beach view|Beachfront|Lake access|Mountain view|Ski-in/Ski-out|Waterfront'), 'nature_and_views'] = 1
df.loc[df['amenities'].str.contains('Bed linens'), 'bed_linen'] = 1
df.loc[df['amenities'].str.contains('Breakfast'), 'breakfast'] = 1
df.loc[df['amenities'].str.contains('TV'), 'tv'] = 1
df.loc[df['amenities'].str.contains('Coffee maker|Espresso machine'), 'coffee_machine'] = 1
df.loc[df['amenities'].str.contains('Cooking basics'), 'cooking_basics'] = 1
df.loc[df['amenities'].str.contains('Dishwasher|Dryer|Washer'), 'white_goods'] = 1
df.loc[df['amenities'].str.contains('Elevator'), 'elevator'] = 1
df.loc[df['amenities'].str.contains('Exercise equipment|Gym|gym'), 'gym'] = 1
df.loc[df['amenities'].str.contains('Family/kid friendly|Children|children'), 'child_friendly'] = 1
df.loc[df['amenities'].str.contains('parking'), 'parking'] = 1
df.loc[df['amenities'].str.contains('Garden|Outdoor|Sun loungers|Terrace'), 'outdoor_space'] = 1
df.loc[df['amenities'].str.contains('Host greets you'), 'host_greeting'] = 1
df.loc[df['amenities'].str.contains('Hot tub|Jetted tub|hot tub|Sauna|Pool|pool'), 'hot_tub_sauna_or_pool'] = 1
df.loc[df['amenities'].str.contains('Internet|Pocket wifi|Wifi'), 'internet'] = 1
df.loc[df['amenities'].str.contains('Long term stays allowed'), 'long_term_stays'] = 1
df.loc[df['amenities'].str.contains('Pets|pet|Cat(s)|Dog(s)'), 'pets_allowed'] = 1
df.loc[df['amenities'].str.contains('Private entrance'), 'private_entrance'] = 1
df.loc[df['amenities'].str.contains('Safe|Security system'), 'secure'] = 1
df.loc[df['amenities'].str.contains('Self check-in'), 'self_check_in'] = 1
df.loc[df['amenities'].str.contains('Smoking allowed'), 'smoking_allowed'] = 1
df.loc[df['amenities'].str.contains('Step-free access|Wheelchair|Accessible'), 'accessible'] = 1
df.loc[df['amenities'].str.contains('Suitable for events'), 'event_suitable'] = 1
# Out:
# C:\Users\Laura\Anaconda3\envs\learn-env\lib\site-packages\ipykernel_launcher.py:22: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.

# %% [markdown]
# One way to reduce the number of features (to avoid the curse of dimensionality) is to remove the amenities which add relatively little information, or are relatively unhelpful in differentiating between different listings. Amenity features where either the true or the false category contains fewer than 10% of listings will be removed.

# %%
# Replacing nulls with zeros for new columns
cols_to_replace_nulls = df.iloc[:,41:].columns
df[cols_to_replace_nulls] = df[cols_to_replace_nulls].fillna(0)

# Produces a list of amenity features where one category (true or false) contains fewer than 10% of listings
infrequent_amenities = []
for col in df.iloc[:,41:].columns:
    if df[col].sum() < len(df)/10:
        infrequent_amenities.append(col)
print(infrequent_amenities)

# Dropping infrequent amenity features
df.drop(infrequent_amenities, axis=1, inplace=True)

# Dropping the original amenity feature
df.drop('amenities', axis=1, inplace=True)
# Out:
# ['check_in_24h', 'air_conditioning', 'high_end_electronics', 'bbq', 'nature_and_views', 'gym', 'hot_tub_sauna_or_pool', 'smoking_allowed', 'accessible', 'event_suitable']

# %%
df.columns[40:]
# Out:
# Index(['balcony', 'bed_linen', 'breakfast', 'tv', 'coffee_machine',
#        'cooking_basics', 'white_goods', 'elevator', 'child_friendly',
#        'parking', 'outdoor_space', 'host_greeting', 'internet',
#        'long_term_stays', 'pets_allowed', 'private_entrance', 'secure',
#        'self_check_in'],
#       dtype='object')

# %% [markdown]
# **price**

# %% [markdown]
# Price will be converted to an integer - currently it is a string because there is a currency sign.

# %%
df.price = df.price.str[1:-3]
df.price = df.price.str.replace(",", "")
df.price = df.price.astype('int64')

# %% [markdown]
# **security_deposit**

# %% [markdown]
# As with price, this will be converted to an integer - currently it is a string because there is a currency sign.
#
# Having a missing value for security deposit is functionally the same as having a security deposit of £0, so missing values will be replaced with 0.

# %%
df.security_deposit.isna().sum()
# Out:
# 28197

# %%
df.security_deposit = df.security_deposit.str[1:-3]
df.security_deposit = df.security_deposit.str.replace(",", "")
df.security_deposit.fillna(0, inplace=True)
df.security_deposit = df.security_deposit.astype('int64')

# %% [markdown]
# **cleaning_fee**

# %% [markdown]
# As with price, this will be converted to an integer - currently it is a string because there is a currency sign.
#
# As with security deposit, having a missing value for cleaning fee is functionally the same as having a cleaning fee of £0, so missing values will be replaced with 0.

# %%
df.cleaning_fee.isna().sum()
# Out:
# 20969

# %%
df.cleaning_fee = df.cleaning_fee.str[1:-3]
df.cleaning_fee = df.cleaning_fee.str.replace(",", "")
df.cleaning_fee.fillna(0, inplace=True)
df.cleaning_fee = df.cleaning_fee.astype('int64')

# %% [markdown]
# **extra_people**

# %% [markdown]
# As with price, this will be converted to an integer - currently it is a string because there is a currency sign.
#
# As with security deposit, having a missing value for extra people is functionally the same as having an extra people fee of £0, so missing values will be replaced with 0.

# %%
df.extra_people = df.extra_people.str[1:-3]
df.extra_people = df.extra_people.str.replace(",", "")
df.extra_people.fillna(0, inplace=True)
df.extra_people = df.extra_people.astype('int64')

# %% [markdown]
# **calendar_updated**

# %% [markdown]
# There are 96 unique categories for calendar_updated, and it is not entirely clear what this feature is adding to the model (a host might update their calendar for multiple different reasons). Therefore this column will be dropped.

# %%
print("Number of categories:", df.calendar_updated.nunique())
print("\nTop five categories:")
df.calendar_updated.value_counts()[:5]
# Out:
# Number of categories: 96
#
# Top five categories:
# today           20032
# a week ago       4612
# 2 weeks ago      4141
# yesterday        3511
# 2 months ago     3194
# Name: calendar_updated, dtype: int64

# %%
df.drop('calendar_updated', axis=1, inplace=True)

# %% [markdown]
# **availability**

# %% [markdown]
# There are multiple different measures of availability, which will be highly correlated with each other. Only one will be retained - for 90 days. This is because in London it is illegal to have short-term (e.g. Airbnb) guests paying to stay in your property for more than 90 days each calendar year, so this is the maximum that should theoretically be possible.

# %%
df.drop(['availability_30', 'availability_60', 'availability_365'], axis=1, inplace=True)

# %% [markdown]
# **first_review and last_review**

# %% [markdown]
# About a quarter of listings have not had a review written for them. This is too large a proportion of the dataset to drop, and dropping the columns would lose a lot of useful information - reviews are very important in people's decisions to book, and therefore price.
#
# This is also too large a proportion of the dataset to simply replace with median/mean values, as this would skew the distribution substantially. Also, the missing values here are not really missing values, as the fact that they are NaNs is meaningful - it tells us that these are new or previously unbooked listings that have not had reviews yet. In order to make the resulting model work able to predict prices for any Airbnb listing, including brand new listings, is is actually beneficial to keep them in. Therefore, these will be kept as an 'unknown' category, and the feature will have to be treated as categorical (and therefore one-hot encoded) rather than numerical.

# %%
print(f"Null values in 'first_review': {round(100*df.first_review.isna().sum()/len(df),1)}%")
print(f"Null values in 'review_scores_rating': {round(100*df.review_scores_rating .isna().sum()/len(df),1)}%")
# Out:
# Null values in 'first_review': 25.4%
# Null values in 'review_scores_rating': 27.5%

# %%
df.first_review = pd.to_datetime(df.first_review) # Converting to datetime

# Calculating the number of days between the first review and the date the data was scraped
df['time_since_first_review'] = (datetime(2019, 4, 9) - df.first_review).astype('timedelta64[D]')

# %%
# Distribution of the number of days since first review
df.time_since_first_review.hist(figsize=(15,5), bins=30);

# %%
def bin_column(col, bins, labels, na_label='unknown'):
    """
    Takes in a column name, bin cut points and labels, replaces the original column with a
    binned version, and replaces nulls (with 'unknown' if unspecified).
    """
    df[col] = pd.cut(df[col], bins=bins, labels=labels, include_lowest=True)
    df[col] = df[col].astype('str')
    df[col].fillna(na_label, inplace=True)

# %%
# Binning time since first review
bin_column('time_since_first_review',
           bins=[0, 182, 365, 730, 1460, max(df.time_since_first_review)],
           labels=['0-6 months',
                   '6-12 months',
                   '1-2 years',
                   '2-3 years',
                   '4+ years'],
           na_label='no reviews')

# %% [markdown]
# The same process will be followed for last_review:

# %%
df.last_review = pd.to_datetime(df.last_review) # Converting to datetime

# Calculating the number of days between the most recent review and the date the data was scraped
df['time_since_last_review'] = (datetime(2019, 4, 9) - df.last_review).astype('timedelta64[D]')

# %%
# Distribution of the number of days since last review
df.time_since_last_review.hist(figsize=(15,5), bins=30);

# %%
# Binning time since last review
bin_column('time_since_last_review',
           bins=[0, 14, 60, 182, 365, max(df.time_since_last_review)],
           labels=['0-2 weeks',
                   '2-8 weeks',
                   '2-6 months',
                   '6-12 months',
                   '1+ year'],
           na_label='no reviews')

# %%
# Dropping last_review - first_review will be kept for EDA and dropped later
df.drop('last_review', axis=1, inplace=True)

# %% [markdown]
# **review ratings columns**

# %% [markdown]
# As above, listings without reviews will be kept and replaced with 'unknown'. Other ratings will be grouped into bins. The histograms below were produced in order to decide on useful bins. The majority of ratings are 9 or 10 out of 10, as also seen in the value count below. Therefore for these columns, 9/10 and 10/10 will be kept as separate groups, and 1-8/10 will be binned together (as this is, by Airbnb standards, a 'low' rating).

# %%
# Checking the distributions of the review ratings columns
variables_to_plot = list(df.columns[df.columns.str.startswith("review_scores") == True])
fig = plt.figure(figsize=(12,8))
for i, var_name in enumerate(variables_to_plot):
    ax = fig.add_subplot(3,3,i+1)
    df[var_name].hist(bins=10,ax=ax)
    ax.set_title(var_name)
fig.tight_layout()
plt.show()

# %%
# Creating a list of all review columns that are scored out of 10
variables_to_plot.pop(0)
# Out:
# 'review_scores_rating'

# %%
# Binning for all columns scored out of 10
for col in variables_to_plot:
    bin_column(col,
               bins=[0, 8, 9, 10],
               labels=['0-8/10', '9/10', '10/10'],
               na_label='no reviews')

# %%
# Binning column scored out of 100
bin_column('review_scores_rating',
           bins=[0, 80, 95, 100],
           labels=['0-79/100', '80-94/100', '95-100/100'],
           na_label='no reviews')

# %% [markdown]
# **cancellation_policy**

# %% [markdown]
# Some cleaning of cancellation policy types is required, in order to categorise the four very small categories into the three larger categories (e.g. the super strict options are only available to long-term Airbnb hosts, and is invitation only).

# %%
df.cancellation_policy.value_counts()
# Out:
# strict_14_with_grace_period    33601
# flexible                       25872
# moderate                       19066
# super_strict_30                  448
# super_strict_60                  419
# strict                             9
# luxury_moderate                    8
# Name: cancellation_policy, dtype: int64

# %%
# Replacing categories
df.cancellation_policy.replace({
    'super_strict_30': 'strict_14_with_grace_period',
    'super_strict_60': 'strict_14_with_grace_period',
    'strict': 'strict_14_with_grace_period',
    'luxury_moderate': 'moderate'
    }, inplace=True)

# %% [markdown]
# **number_of_reviews_ltm and reviews_per_month**

# %% [markdown]
# These will be highly correlated with number_of_reviews and so will be dropped.

# %%
df.drop(['number_of_reviews_ltm', 'reviews_per_month'], axis=1, inplace=True)

# %% [markdown]
# ***

# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# ### Time series

# %% [markdown]
# *Question: how long have hosts been listing properties on Airbnb in London?*
#
# Answer: the oldest London listing that is currently live on Airbnb was first listed on the site in August 2008. From 2011 onwards, the number of listings started increasing considerably. However, growth in the number of new hosts (of those currently listing on the site) has been decreasing since 2015, when the UK government introduced a law in 2015 making it illegal to let short-term residential properties for more than 90 nights a year.
#
# A high level of seasonality is evident, with notable peaks in the summer when people put properties online to take advantage of the increased number of tourists in the summer holidays.
#
# There is a big peak in the number of hosts joining Airbnb in 2015. This could be a response to the government legislation, as existing hosts may have created new accounts in order to re-list their properties and get around the 90 day limit.

# %%
print(f"Of the Airbnb hosts that are still listing on the site, the first joined on {min(df.host_since).strftime('%d %B %Y')}, and the most recent joined on {max(df.host_since).strftime('%d %B %Y')}.")
# Out:
# Of the Airbnb hosts that are still listing on the site, the first joined on 14 August 2008, and the most recent joined on 08 April 2019.

# %%
plt.figure(figsize=(15,5))
df.set_index('host_since').resample('MS').size().plot(label='Hosts joining Airbnb', color='orange')
df.set_index('first_review').resample('MS').size().plot(label='Listings getting their first review', color='green')
plt.title('London hosts joining Airbnb and listings getting their first review in each month')
plt.legend()
plt.xlim('2008-08-01', '2019-03-31') # Limiting to whole months
plt.xlabel('')
plt.ylabel('')
plt.show()

# %%
# Creating dataframes for time series analysis
ts_host_since = pd.DataFrame(df.set_index('host_since').resample('MS').size())
ts_first_review = pd.DataFrame(df.set_index('first_review').resample('MS').size())

# Renaming columns
ts_host_since = ts_host_since.rename(columns={0: 'hosts'})
ts_host_since.index.rename('month', inplace=True)
ts_first_review = ts_first_review.rename(columns={0: 'reviews'})
ts_first_review.index.rename('month', inplace=True)

# %%
def decompose_time_series(df, title=''):
    """
    Plots the original time series and its decomposition into trend, seasonal and residual.
    """
    # Decomposing the time series
    decomposition = seasonal_decompose(df)
    
    # Getting the trend, seasonality and noise
    trend = decomposition.trend
    seasonal = decomposition.seasonal
    residual = decomposition.resid
    
    # Plotting the original time series and the decomposition
    plt.figure(figsize=(12,8))
    plt.suptitle(title, fontsize=14, y=1)
    plt.subplots_adjust(top=0.80)
    plt.subplot(411)
    plt.plot(df, label='Original')
    plt.legend(loc='upper left')
    plt.subplot(412)
    plt.plot(trend, label='Trend')
    plt.legend(loc='upper left')
    plt.subplot(413)
    plt.plot(seasonal,label='Seasonality')
    plt.legend(loc='upper left')
    plt.subplot(414)
    plt.plot(residual, label='Residuals')
    plt.legend(loc='upper left')
    plt.tight_layout()

# %%
decompose_time_series(ts_host_since, title='Number of hosts joining Airbnb each month')

# %%
decompose_time_series(ts_first_review, title='Number of Airbnb listings getting their first review each month')

# %% [markdown]
# *Question: are the different patterns in the growth in the number of hosts and the number of listings due to hosts increasingly owning multiple properties?*
#
# Answer: there are a number of professional Airbnb management companies which host a large number of listings under a single host profile, particularly from 2013 onwards. The largest manages 1654 listings and is aa management company based in Liverpool operating under the name 'Jp', while the second largest is the management company Veeve, managing 1304 listings.
#
# However, there is no consistent upwards trend in the average number of properties managed by each host.

# %%
plt.figure(figsize=(16,6))
sns.boxplot(df.host_since.dt.year, np.log(df.host_listings_count))
plt.xlabel('Year that the host joined Airbnb', fontsize=12)
plt.ylabel('Number of listings per host (log-transformed)', fontsize=12)
plt.title('Change per year in the number of listings per host on Airbnb in London', fontsize=16)
plt.show()
# Out:
# C:\Users\Laura\Anaconda3\envs\learn-env\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log

# %%
print("Average number of listings per host per year on Airbnb in London:")
print(round(df.set_index('host_since').host_listings_count.resample('YS').mean(),2))
# Out:
# Average number of listings per host per year on Airbnb in London:
# host_since
# 2008-01-01      4.33
# 2009-01-01     24.10
# 2010-01-01      4.29
# 2011-01-01     18.70
# 2012-01-01      6.56
# 2013-01-01      4.00
# 2014-01-01     12.42
# 2015-01-01    100.15
# 2016-01-01      7.19
# 2017-01-01     27.36
# 2018-01-01     10.25
# 2019-01-01      5.53
# Freq: AS-JAN, Name: host_listings_count, dtype: float64

# %%
# List of the largest host_listings_count and the year the host joined Airbnb
df.sort_values('host_listings_count').drop_duplicates('host_listings_count',keep='last').tail(10)[['host_since', 'host_listings_count']]
# Out:
#          host_since  host_listings_count
# id
# 22750548 2015-11-04                189.0
# 19617790 2015-03-05                217.0
# 20977631 2012-11-13                246.0
# 30525581 2017-10-25                457.0
# 32398252 2018-03-12                571.0
# 22005669 2015-04-25                586.0
# 13229041 2013-02-12                829.0
# 24917631 2014-02-14               1145.0
# 18203920 2015-05-21               1304.0
# 23929554 2016-12-22               1654.0

# %% [markdown]
# *Question: how have prices changed over time?*
#
# Answer: the average price per night for Airbnb listings in London has increased slightly over the last 10 years. In particular, the top end of property prices has increased, resulting in a larger increase in the mean price compared to the median - e.g. the mean price in 2015 was £95.90, whereas the mean price in 2018 (the last complete year of data) was £111.14.

# %%
plt.figure(figsize=(16,6))
sns.boxplot(df.first_review.dt.year, np.log(df.price))
plt.xlabel('Year that the listing had its first review', fontsize=12)
plt.ylabel('Nightly price (log-transformed)', fontsize=12)
plt.title('Change per year in the nightly price of Airbnb listings in London', fontsize=16)
plt.show()
# Out:
# C:\Users\Laura\Anaconda3\envs\learn-env\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log

# %%
print("Mean nightly price of listings in each year on Airbnb in London:")
print(round(df.set_index('first_review').price.resample('YS').mean(),2))
# Out:
# Mean nightly price of listings in each year on Airbnb in London:
# first_review
# 2009-01-01    100.00
# 2010-01-01     85.04
# 2011-01-01     93.97
# 2012-01-01     86.28
# 2013-01-01    101.35
# 2014-01-01    101.54
# 2015-01-01     95.90
# 2016-01-01     96.19
# 2017-01-01    100.41
# 2018-01-01    111.14
# 2019-01-01    124.30
# Name: price, dtype: float64

# %%
# Dropping host_since and first_review as they are no longer needed
df.drop(['host_since', 'first_review'], axis=1, inplace=True)

# %% [markdown]
# ### Numerical features

# %%
df.describe()
# Out:
#        host_is_superhost  host_listings_count  host_identity_verified  \
# count        79423.00000         79423.000000            79423.000000
# mean             0.14910            29.815482                0.358851
# std              0.35619           159.114327                0.479666
# min              0.00000             0.000000                0.000000
# 25%              0.00000             1.000000                0.000000
# 50%              0.00000             2.000000                0.000000
# 75%              0.00000             5.000000                1.000000
# max              1.00000          1654.000000                1.000000
#
#        accommodates     bathrooms      bedrooms          beds         price  \
# count  79423.000000  79423.000000  79423.000000  79423.000000  79423.000000
# mean       3.175201      1.290892      1.407162      1.738728    116.720333
# std        1.996260      0.605444      0.904378      1.266215    208.965892
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        2.000000      1.000000      1.000000      1.000000     45.000000
# 50%        2.000000      1.000000      1.000000      1.000000     80.000000
# 75%        4.000000      1.500000      2.000000      2.000000    135.000000
# max       16.000000     17.000000     16.000000     23.000000  13700.000000
#
#        security_deposit  cleaning_fee  guests_included  extra_people  \
# count      79423.000000  79423.000000     79423.000000  79423.000000
# mean         133.148118     30.664178         1.569709      7.414452
# std          276.610258     41.850741         1.293974     13.893068
# min            0.000000      0.000000         1.000000      0.000000
# 25%            0.000000      0.000000         1.000000      0.000000
# 50%            0.000000     20.000000         1.000000      0.000000
# 75%          200.000000     45.000000         2.000000     10.000000
# max         4098.000000    614.000000        16.000000    235.000000
#
#        minimum_nights  maximum_nights  availability_90  number_of_reviews  \
# count    79423.000000    7.942300e+04     79423.000000       79423.000000
# mean         4.096345    4.198981e+04        30.062337          15.978004
# std         15.373230    8.413339e+06        33.329813          33.756707
# min          1.000000    1.000000e+00         0.000000           0.000000
# 25%          1.000000    3.100000e+01         0.000000           0.000000
# 50%          2.000000    1.125000e+03        15.000000           4.000000
# 75%          3.000000    1.125000e+03        60.000000          16.000000
# max       1125.000000    2.147484e+09        90.000000         630.000000
#
#        instant_bookable  host_days_active       balcony     bed_linen  \
# count      79423.000000      79423.000000  79423.000000  79423.000000
# mean           0.408861       1335.540309      0.101306      0.304748
# std            0.491627        745.679201      0.301735      0.460304
# min            0.000000          1.000000      0.000000      0.000000
# 25%            0.000000        744.000000      0.000000      0.000000
# 50%            0.000000       1328.000000      0.000000      0.000000
# 75%            1.000000       1835.000000      0.000000      1.000000
# max            1.000000       3890.000000      1.000000      1.000000
#
#           breakfast            tv  coffee_machine  cooking_basics  \
# count  79423.000000  79423.000000    79423.000000    79423.000000
# mean       0.144555      0.696058        0.152714        0.268222
# std        0.351654      0.459961        0.359714        0.443037
# min        0.000000      0.000000        0.000000        0.000000
# 25%        0.000000      0.000000        0.000000        0.000000
# 50%        0.000000      1.000000        0.000000        0.000000
# 75%        0.000000      1.000000        0.000000        1.000000
# max        1.000000      1.000000        1.000000        1.000000
#
#         white_goods      elevator  child_friendly       parking  \
# count  79423.000000  79423.000000    79423.000000  79423.000000
# mean       0.864624      0.233081        0.351800      0.405009
# std        0.342127      0.422796        0.477535      0.490897
# min        0.000000      0.000000        0.000000      0.000000
# 25%        1.000000      0.000000        0.000000      0.000000
# 50%        1.000000      0.000000        0.000000      0.000000
# 75%        1.000000      0.000000        1.000000      1.000000
# max        1.000000      1.000000        1.000000      1.000000
#
#        outdoor_space  host_greeting      internet  long_term_stays  \
# count   79423.000000   79423.000000  79423.000000     79423.000000
# mean        0.100802       0.213175      0.964129         0.210795
# std         0.301068       0.409553      0.185970         0.407876
# min         0.000000       0.000000      0.000000         0.000000
# 25%         0.000000       0.000000      1.000000         0.000000
# 50%         0.000000       0.000000      1.000000         0.000000
# 75%         0.000000       0.000000      1.000000         0.000000
# max         1.000000       1.000000      1.000000         1.000000
#
#        pets_allowed  private_entrance        secure  self_check_in
# count  79423.000000      79423.000000  79423.000000   79423.000000
# mean       0.114274          0.203052      0.105184       0.162031
# std        0.318146          0.402273      0.306792       0.368482
# min        0.000000          0.000000      0.000000       0.000000
# 25%        0.000000          0.000000      0.000000       0.000000
# 50%        0.000000          0.000000      0.000000       0.000000
# 75%        0.000000          0.000000      0.000000       0.000000
# max        1.000000          1.000000      1.000000       1.000000

# %% [markdown]
# **Price**

# %% [markdown]
# *Question: what is the overall distribution of prices?*
#
# Answer: nightly advertised prices range from £0 to £13,700. The extreme ends of the range are due to hosts not understanding how to use Airbnb advertised prices (sometimes called 'sticker' prices) correctly. The advertised prices can be set to any arbitrary amount, and these are the prices that show when dates are not entered on the site.
#
# A model is only as good as its data, and unfortunately this model will be predicting advertised prices rather than the prices actually paid. Nevertheless, some cleaning of the particularly unhelpful values will be done. Very small values under £10 will be increased to £10.
#
# There are notable drop-offs in nightly prices at £200 (first graph, orange line), £500 (second graph, orange line) and £1,000 (second graph, red line). Values above £1,000 will  be reduced to £1,000.

# %%
print(f"Nightly advertised prices range from £{min(df.price)} to £{max(df.price)}.")
# Out:
# Nightly advertised prices range from £0 to £13700.

# %%
# Distribution of prices from £0 to £1000
plt.figure(figsize=(20,4))
df.price.hist(bins=100, range=(0,1000))
plt.margins(x=0)
plt.axvline(200, color='orange', linestyle='--')
plt.title("Airbnb advertised nightly prices in London up to £1000", fontsize=16)
plt.xlabel("Price (£)")
plt.ylabel("Number of listings")
plt.show()

# %%
# Distribution of prices from £200 upwards
plt.figure(figsize=(20,4))
df.price.hist(bins=100, range=(200, max(df.price)))
plt.margins(x=0)
plt.axvline(500, color='orange', linestyle='--')
plt.axvline(1000, color='red', linestyle='--')
plt.title("Airbnb advertised nightly prices in London up to £1000", fontsize=16)
plt.xlabel("Price (£)")
plt.ylabel("Number of listings")
plt.show()

# %%
# Replacing values under £10 with £10
df.loc[df.price <= 10, 'price'] = 10

# Replacing values over £1000 with £1000
df.loc[df.price >= 1000, 'price'] = 1000

# %% [markdown]
# **Host listings count**

# %% [markdown]
# *Question: how many listings do hosts have on average? How many multi-listing hosts are there?*
#
# Answer: the median number of listings that the host of each listing has is 2, i.e. on average (median) each listing is hosted by a host who also manages one other listing. The mean is much higher (30 in total) due to some hosts managing large numbers of listings (as discussed above in the Time Series section). About half of listings are from hosts with one listing, and half are from multi-listing hosts.
#
# Two difficulties in discerning how many listings hosts have on average are:
# - this number is only known on the level of the listing, so hosts with more listings are represented more frequently (e.g a host with 10 listings may be represented up to 10 times in the dataset)
# - a host's other listings may not be in London, so some multi-listing hosts may appear multiple times in the dataset, and others may appear only once

# %%
print("Median number of listings per host:", int(df.host_listings_count.median()))
print("Mean number of listings per host:", int(round(df.host_listings_count.mean())))
print(f"{int(round(100*len(df[df.host_listings_count == 1])/len(df)))}% of listings are from hosts with one listing.")
# Out:
# Median number of listings per host: 2
# Mean number of listings per host: 30
# 49% of listings are from hosts with one listing.

# %% [markdown]
# **Number of people accommodated, bathrooms, bedrooms and beds**

# %% [markdown]
# *Question: what are the average number of people accommodated, bathrooms, bedrooms and beds in Airbnb listings in London, and how do prices differ?*
#
# Answer: the most common property setup sleeps two people in one bed in one bedroom, with one bathroom. Unsurprisingly, properties that accommodate more people achieve noticeably higher nightly rates, with diminishing returns coming after about 10 people.
#
# Some properties have very high looking values for some features (e.g. one property claims to have 17 bathrooms), but these will be left for now in the interests of time (as double-checking them would be time-consuming).

# %%
plt.figure(figsize=(10,5))
df.groupby('accommodates').price.median().plot(kind='bar')
plt.title('Median price of Airbnbs accommodating different number of guests', fontsize=14)
plt.xlabel('Number of guests accommodated', fontsize=13)
plt.ylabel('Median price (£)', fontsize=13)
plt.xticks(rotation=0)
plt.xlim(left=0.5)
plt.show()

# %%
df[['accommodates', 'bathrooms', 'bedrooms', 'beds']].hist(figsize=(8,6));

# %% [markdown]
# ### Categorical features

# %% [markdown]
# Categorical features will be explored and plotted, to gain insights and to determine whether or not they should be included in the final model.

# %% [markdown]
# **Neighbourhood**

# %% [markdown]
# *Question: which areas have the most Airbnb properties, and which are the most expensive?*
#
# Answer: Westminster (west central London) has the most Airbnb properties, followed by Tower Hamlets (east central London). Inner London boroughs have significantly more listings than outer London boroughs.
#
# However, the pattern with prices is slightly different. Kensington and Chelsea (to the west of Westminster) is the most expensive area - this is a famously expensive area to live, with some of the highest house prices in the world. Although inner London is generally more expensive than outer London, there are also some more expensive listings spread out to the west of the city along the Thames (which has some very beautiful areas).
#
# There are very few listings in the very centre of London (there is relatively little residential property here), but as a result they are very expensive.

# %%
# Renaming the neighbourhood column
df.rename(columns={'neighbourhood_cleansed': 'borough'}, inplace=True)

# Importing the London borough boundary GeoJSON file as a dataframe in geopandas
map_df = gpd.read_file('data/neighbourhoods.geojson')
map_df.head()
# Out:
#           neighbourhood neighbourhood_group  \
# 0  Kingston upon Thames                None
# 1               Croydon                None
# 2               Bromley                None
# 3              Hounslow                None
# 4                Ealing                None
#
#                                             geometry
# 0  (POLYGON ((-0.330679 51.329011, -0.330594 51.3...
# 1  (POLYGON ((-0.06402099999999999 51.318638, -0....
# 2  (POLYGON ((0.012131 51.299599, 0.011962 51.299...
# 3  (POLYGON ((-0.244562 51.488702, -0.24468 51.48...
# 4  (POLYGON ((-0.411833 51.534084, -0.411883 51.5...

# %%
# Dropping the empty column
map_df.drop('neighbourhood_group', axis=1, inplace=True)

# Creating a dataframe of listing counts and median price by borough
borough_df = pd.DataFrame(df.groupby('borough').size())
borough_df.rename(columns={0: 'number_of_listings'}, inplace=True)
borough_df['median_price'] = df.groupby('borough').price.median().values

# Joining the dataframes
borough_map_df = map_df.set_index('neighbourhood').join(borough_df)

# %%
# Plotting the number of listings in each borough
fig1, ax1 = plt.subplots(1, figsize=(15, 6))
borough_map_df.plot(column='number_of_listings', cmap='Blues', ax=ax1)
ax1.axis('off')
ax1.set_title('Number of Airbnb listings in each London borough', fontsize=14)
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=0, vmax=9000))
sm._A = [] # Creates an empty array for the data range
cbar = fig1.colorbar(sm)
plt.show()

# Plotting the median price of listings in each borough
fig2, ax2 = plt.subplots(1, figsize=(15, 6))
borough_map_df.plot(column='median_price', cmap='Blues', ax=ax2)
ax2.axis('off')
ax2.set_title('Median price of Airbnb listings in each London borough', fontsize=14)
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=min(borough_map_df.median_price), vmax=max(borough_map_df.median_price)))
sm._A = [] # Creates an empty array for the data range
cbar = fig2.colorbar(sm)
plt.show()

# %% [markdown]
# **Property and room types**

# %% [markdown]
# *Question: what are the most common property and room types?*
#
# Answer: about 70% of properties are apartments. The remainder are houses or more uncommon property types (e.g. 'bed and breakfast' or 'yurt').
#
# About 55% of listings are entire homes (i.e. you are renting the entire property on your own). Most of the remainder are private rooms (i.e. you are renting a bedroom and possibly also a bathroom, but there will be other people in the property). Fewer than 1% are shared rooms (i.e. you are sharing a room with either the property owner or other guests).

# %%
def category_count_plot(col, figsize=(8,4)):
    """
    Plots a simple bar chart of the total count for each category in the column specified.
    A figure size can optionally be specified.
    """
    plt.figure(figsize=figsize)
    df[col].value_counts().plot(kind='bar')
    plt.title(col)
    plt.xticks(rotation=0)
    plt.show()

# %%
for col in ['property_type', 'room_type']:
    category_count_plot(col, figsize=(4,3))
    print(df[col].value_counts(normalize=True))
# Out:
# Apartment    0.714138
# House        0.243607
# Other        0.042255
# Name: property_type, dtype: float64
# Entire home/apt    0.559120
# Private room       0.431600
# Shared room        0.009279
# Name: room_type, dtype: float64

# %% [markdown]
# **Reviews**

# %% [markdown]
# *Question: what is the distribution of reviews like?*
#
# Answer: for  every review category, the majority of listings that have had a review have received a 10/10 rating for that category (or 95-100/100 overall) - clearly people love their Airbnbs. Ratings or 8 or below are rare. Guests seem to be most positive about communication, check-ins and accuracy. As noted previously, about a quarter of listings have not yet been reviewed.

# %%
fig, ax = plt.subplots(1, 1, figsize=(8,5))
ax.set_title('Overall listing rating', fontsize=14)
df['review_scores_rating'].value_counts().sort_index(ascending=False).plot(kind='bar', color=['silver', 'darkgreen', 'yellowgreen', '#d1f28a' ], ax=ax)
ax.set_xticklabels(labels=['no reviews', '95-100%', '80-94%', '0-79%'], rotation=0)
ax.set_xlabel('')
ax.set_ylabel('Number of properties', fontsize=13)
plt.show()

# %%
for col in list(df.columns[df.columns.str.startswith("review_scores") == True]):
    category_count_plot(col, figsize=(5,3))

# %% [markdown]
# **First and last reviews**

# %% [markdown]
# *Question: how long have listings been on the site, and how many listings have been reviewed recently?*
#
# Answer: the most common time period in which currently live Airbnb listings had their first review is 2-3 years. This means that a lot of listings on the site have been active for at least a couple of years. Relatively few have been active for more than four years, however.
#
# The most common category for the time since a listing received its last review is 2-8 weeks. This means that a lot of listings have been reviewed relatively recently. However, there are still over 10,000 listings which have not had a review for more than a year. The majority of these are probably what are sometimes referred to 'inactive' listings, because although they are technically live on the site, they do not have their calendards open and are not available to book.

# %%
for col in ['time_since_first_review', 'time_since_last_review']:
    category_count_plot(col)

# %% [markdown]
# ### Boolean (true or false) features

# %% [markdown]
# Many features (e.g. for amenities) can be true or false. This section compares the proportions of these features that are true or false (to explore the data and also to ascertain whether the feature is worth retaining), and the median price of each category (to explore the relationship between the category and price).

# %%
def binary_count_and_price_plot(col, figsize=(8,3)):
    """
    Plots a simple bar chart of the counts of true and false categories in the column specified,
    next to a bar chart of the median price for each category.
    A figure size can optionally be specified.
    """
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=figsize)
    fig.suptitle(col, fontsize=16, y=1)
    plt.subplots_adjust(top=0.80) # So that the suptitle does not overlap with the ax plot titles
    
    df.groupby(col).size().plot(kind='bar', ax=ax1, color=['firebrick', 'seagreen'])
    ax1.set_xticklabels(labels=['false', 'true'], rotation=0)
    ax1.set_title('Category count')
    ax1.set_xlabel('')
    
    df.groupby(col).price.median().plot(kind='bar', ax=ax2, color=['firebrick', 'seagreen'])
    ax2.set_xticklabels(labels=['false', 'true'], rotation=0)
    ax2.set_title('Median price (£)')
    ax2.set_xlabel('')
    
    plt.show()

# %% [markdown]
# **Superhosts**

# %% [markdown]
# *Question: what proportion of Airbnb hosts are superhosts, and is it worth being one? (a question often asked by hosts)*
#
# Answer: about 15% of hosts are superhosts. However, it does not seem to improve the median price per night of their Airbnb listings, so it is arguable whether or not it is worth it (from a purely financial perspective).

# %%
binary_count_and_price_plot('host_is_superhost')
print(df.host_is_superhost.value_counts(normalize=True))
# Out:
# 0.0    0.8509
# 1.0    0.1491
# Name: host_is_superhost, dtype: float64

# %% [markdown]
# **Host verification**

# %% [markdown]
# *Question: how many hosts are verified, and is it worth it? (a question often asked by hosts)*
#
# Answer: only about 35% of hosts are verified (e.g. by providing ID and verifying your phone number and email address), although it is something that hosts often think they are expected to do. Interestingly, however, despite the fact that one might expect the additional trust commanded by verified hosts to result in higher nightly prices, there is no discernable difference between the median nightly prices of listings with verified and unverified hosts. This column will be left in the dataframe, however, in case it has any useful interactions with other features.

# %%
df.host_identity_verified.value_counts(normalize=True)
# Out:
# 0.0    0.641149
# 1.0    0.358851
# Name: host_identity_verified, dtype: float64

# %%
binary_count_and_price_plot('host_identity_verified')

# %% [markdown]
# **Instant booking**

# %% [markdown]
# *Question: how many properties are instant bookable (i.e. able to be booked without messaging the host first), and is it worth it?*
#
# Answer: only about 40% of properties are instant bookable. However, the added convenience does not seem to have any effect on the median price per night.

# %%
binary_count_and_price_plot('instant_bookable')
print(df.instant_bookable.value_counts(normalize=True))
# Out:
# 0    0.591139
# 1    0.408861
# Name: instant_bookable, dtype: float64

# %% [markdown]
# **Amenities**

# %% [markdown]
# *Question: which amenities are common, and which increase the price of an Airbnb listing?*
#
# Answer: amenities can be split into four main groups:
#
# Uncommon, but properties with it have a higher median price:
# - Balcony
# - Bed linen
# - Coffee machine
# - Basic cooking equipment
# - Elevator
# - Child friendly
# - Outdoor space
# - Long term stays allowed
# - Private entrance
# - Safe or security system
# - Self check-in
#
# Most properties have it, and properties with it have a higher median price:
# - TV
# - Washer, dryer and/or dishwasher
#
# Most properties have it, and there is no major difference in price between properties with and without it:
# - Internet
#
# Uncommon, and properties with it have a lower median price:
# - Breakfast (probably because these are bed & breakfasts and therefore single rooms rather than entire homes)
# - Parking (presumably because these are less likely to be central properties)
# - Greeted by host (surprisingly!)
# - Pets allowed
#
# The takeaway from this is that there are some things that Airbnb hosts can do to try and improve their listing's price, although there is often not a simple causative relationship (e.g. having a parking space might improve your price, but listings with parking spaces are cheaper on average because they are less likely to be in central London, and location is a more important factor than parking space):
# - **Make sure you have the necessities that your competitors also have**, e.g. internet, a TV and white goods (a washer, dryer and/or dishwasher).
# - If you can, **include some extras to make your property stand out and achieve a higher price**. For example, you could buy a coffee machine, allow self check-in and long-term stays, and make your property child-friendly.
# - **Avoid pets** as the additional wear and tear to your property might harm its financial performance.

# %%
for col in df.iloc[:,31:-2].columns:
    binary_count_and_price_plot(col, figsize=(6,2))

# %% [markdown]
# # Preparing the data for modeling

# %% [markdown]
# **Dropping columns and assessing multi-collinearity**

# %% [markdown]
# Categorical variables will now be one-hot encoded:

# %%
transformed_df = pd.get_dummies(df)

# %% [markdown]
# The dataset can now be assessed for multi-collinearity.

# %%
def multi_collinearity_heatmap(df, figsize=(11,9)):
    
    """
    Creates a heatmap of correlations between features in the df. A figure size can optionally be set.
    """
    
    # Set the style of the visualization
    sns.set(style="white")

    # Create a covariance matrix
    corr = df.corr()

    # Generate a mask the size of our covariance matrix
    mask = np.zeros_like(corr, dtype=np.bool)
    mask[np.triu_indices_from(mask)] = True

    # Set up the matplotlib figure
    f, ax = plt.subplots(figsize=figsize)

    # Generate a custom diverging colormap
    cmap = sns.diverging_palette(220, 10, as_cmap=True)

    # Draw the heatmap with the mask and correct aspect ratio
    sns.heatmap(corr, mask=mask, cmap=cmap, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5}, vmax=corr[corr != 1.0].max().max());

# %%
multi_collinearity_heatmap(transformed_df, figsize=(20,20))

# %% [markdown]
# It doesn't look like there are any significant collinear relationships with boroughs, so these will temporarily be dropped to produce a clearer heatmap for the remaining features:

# %%
multi_collinearity_heatmap(transformed_df.drop(list(transformed_df.columns[transformed_df.columns.str.startswith('borough')]), axis=1), figsize=(25,22))

# %% [markdown]
# Areas of multi-collinearity:
#
# - Beds, bedrooms, guests included and the number of people that a property accommodates are highly correlated. The number of people accommodated has traditionally been a more high priority search parameter on Airbnb, as it is more relevant for private and shared rooms than the number of bedrooms (and is still the second highest priority parameter when searching on the site, after dates (when read from left to right on the search page)).
# - Unsurprisingly, there are perfect correlations between NaN reviews (i.e. listings that are not reviewed yet) for different review categories, and first and last review times. NaN categories can therefore be dropped.
# - The same is true of unknown host response rates and times. One of these (rate) will be dropped.
# - There is a correlation between a 0-49% response rate, and an average response time of a few days or more. One of these (rate) will be dropped.
# - There are strong negative correlations between houses and apartments, and between private rooms and entire homes (as these were the main two categories of their features before they were one-hot encoded). Although these are important categories, one of each will be dropped in order to reduce multi-collinearity (apartments and private rooms, as these are the second most common categories).

# %%
# Dropping collinear features
to_drop = ['beds',
           'bedrooms',
           'guests_included', 
           'host_response_rate_unknown',
           'host_response_rate_0-49%',
           'property_type_Apartment',
           'room_type_Private room']
to_drop.extend(list(transformed_df.columns[transformed_df.columns.str.endswith('nan')]))

transformed_df.drop(to_drop, axis=1, inplace=True)

# %%
# Final assessment of multi-collinearity
multi_collinearity_heatmap(transformed_df.drop(list(transformed_df.columns[transformed_df.columns.str.startswith('borough')]), axis=1), figsize=(25,22))

# %% [markdown]
# There are still some fairly strong correlations between highly rated properties of different reviews categories - i.e. if a property gets a 10/10 for one category, it is likely to get a 10/10 for other categories. However, these will be left in for now and can be experimented with later to see if removing them improves the model.

# %% [markdown]
# **Standardising and normalising**

# %% [markdown]
# Other than availability_90 and host_days_active, the remaining numerical features are all postively skewed and could benefit from log transformation.

# %%
numerical_columns = ['accommodates', 'availability_90', 'bathrooms', 'cleaning_fee', 'extra_people', 'host_days_active', 'host_listings_count', 'maximum_nights', 'minimum_nights', 'number_of_reviews', 'price', 'security_deposit']

# %%
transformed_df[numerical_columns].hist(figsize=(10,11));

# %%
# Log transforming columns
numerical_columns = [i for i in numerical_columns if i not in ['availability_90', 'host_days_active']] # Removing items not to be transformed

for col in numerical_columns:
    transformed_df[col] = transformed_df[col].astype('float64').replace(0.0, 0.01) # Replacing 0s with 0.01
    transformed_df[col] = np.log(transformed_df[col])

# %% [markdown]
# This appears to have helped some of the distributions, although some (e.g. cleaning fee, extra people fee and security fee) contain a large number of 0s, which means these features are not normally distributed. Most importantly, however, the target variable price now appears much more normally distributed.

# %%
transformed_df[numerical_columns].hist(figsize=(10,11));

# %% [markdown]
# Finally, the predictive features X and the target feature y can be separated, and X will be scaled. StandardScaler from sklearn will be used, but the type of scaling used could be experimented with later to see if alternative versions yield better results.

# %%
# Separating X and y
X = transformed_df.drop('price', axis=1)
y = transformed_df.price

# Scaling
scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=list(X.columns))
# Out:
# C:\Users\Laura\Anaconda3\envs\learn-env\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype uint8, int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\Laura\Anaconda3\envs\learn-env\lib\site-packages\sklearn\base.py:462: DataConversionWarning: Data with input dtype uint8, int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %% [markdown]
# ***

# %% [markdown]
# # Building a neural network

# %% [markdown]
# In this section several machine learning and deep learning models will be built in order to predict an Airbnb listing's price.
#
# The evaluation metrics used will be mean squared error (for loss) and r squared (for accuracy).

# %%
# Splitting into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %% [markdown]
# ### Model 1: XGBoost

# %% [markdown]
# Before building a neural network, a vanilla XGBoost model will be used to predict price, in order to provide a baseline level of accuracy and a measure of feature importance. This most likely provides the best achievable accuracy using machine learning models (other than possible small accuracy increases from hyper-parameter tuning) due to XGBoost's superior performance.

# %%
xgb_reg_start = time.time()

xgb_reg = xgb.XGBRegressor()
xgb_reg.fit(X_train, y_train)
training_preds_xgb_reg = xgb_reg.predict(X_train)
val_preds_xgb_reg = xgb_reg.predict(X_test)

xgb_reg_end = time.time()

print(f"Time taken to run: {round((xgb_reg_end - xgb_reg_start)/60,1)} minutes")
print("\nTraining MSE:", round(mean_squared_error(y_train, training_preds_xgb_reg),4))
print("Validation MSE:", round(mean_squared_error(y_test, val_preds_xgb_reg),4))
print("\nTraining r2:", round(r2_score(y_train, training_preds_xgb_reg),4))
print("Validation r2:", round(r2_score(y_test, val_preds_xgb_reg),4))
# Out:
# Time taken to run: 0.2 minutes
#
# Training MSE: 0.1576
# Validation MSE: 0.159
#
# Training r2: 0.7321
# Validation r2: 0.7274

# %%
ft_weights_xgb_reg = pd.DataFrame(xgb_reg.feature_importances_, columns=['weight'], index=X_train.columns)
ft_weights_xgb_reg.sort_values('weight', inplace=True)
ft_weights_xgb_reg
# Out:
#                                                    weight
# borough_Havering                                 0.000000
# host_response_rate_100%                          0.000000
# borough_Hackney                                  0.000000
# time_since_last_review_2-8 weeks                 0.000000
# borough_Hounslow                                 0.000000
# borough_Kingston upon Thames                     0.000000
# borough_Lambeth                                  0.000000
# borough_Merton                                   0.000000
# borough_Newham                                   0.000000
# borough_Richmond upon Thames                     0.000000
# borough_Sutton                                   0.000000
# borough_Tower Hamlets                            0.000000
# borough_Wandsworth                               0.000000
# review_scores_rating_0-79/100                    0.000000
# review_scores_accuracy_9/10                      0.000000
# review_scores_checkin_0-8/10                     0.000000
# review_scores_checkin_10/10                      0.000000
# review_scores_checkin_9/10                       0.000000
# time_since_last_review_2-6 months                0.000000
# time_since_last_review_0-2 weeks                 0.000000
# time_since_first_review_6-12 months              0.000000
# time_since_first_review_4+ years                 0.000000
# time_since_first_review_2-3 years                0.000000
# time_since_first_review_1-2 years                0.000000
# host_response_time_within a few hours            0.000000
# time_since_first_review_0-6 months               0.000000
# cancellation_policy_moderate                     0.000000
# cancellation_policy_flexible                     0.000000
# review_scores_value_9/10                         0.000000
# review_scores_communication_9/10                 0.000000
# review_scores_communication_10/10                0.000000
# review_scores_communication_0-8/10               0.000000
# cancellation_policy_strict_14_with_grace_period  0.000000
# host_response_time_within a day                  0.000000
# time_since_last_review_6-12 months               0.000000
# host_response_time_a few days or more            0.000000
# self_check_in                                    0.000000
# host_identity_verified                           0.000000
# instant_bookable                                 0.000000
# balcony                                          0.000000
# bed_linen                                        0.000000
# private_entrance                                 0.000000
# host_greeting                                    0.000000
# outdoor_space                                    0.000000
# borough_Hillingdon                               0.001435
# long_term_stays                                  0.001435
# internet                                         0.001435
# review_scores_cleanliness_10/10                  0.001435
# review_scores_accuracy_0-8/10                    0.001435
# review_scores_value_0-8/10                       0.001435
# ...                                                   ...
# pets_allowed                                     0.002869
# review_scores_cleanliness_9/10                   0.002869
# review_scores_accuracy_10/10                     0.002869
# borough_Southwark                                0.002869
# review_scores_value_10/10                        0.004304
# borough_Bexley                                   0.004304
# breakfast                                        0.004304
# cooking_basics                                   0.004304
# coffee_machine                                   0.004304
# secure                                           0.004304
# borough_Greenwich                                0.004304
# borough_Enfield                                  0.005739
# borough_Barnet                                   0.005739
# borough_City of London                           0.005739
# host_response_time_unknown                       0.007174
# property_type_House                              0.007174
# review_scores_rating_80-94/100                   0.007174
# borough_Bromley                                  0.007174
# borough_Redbridge                                0.007174
# review_scores_cleanliness_0-8/10                 0.008608
# review_scores_location_10/10                     0.008608
# review_scores_location_0-8/10                    0.008608
# maximum_nights                                   0.008608
# borough_Islington                                0.008608
# borough_Haringey                                 0.010043
# parking                                          0.010043
# child_friendly                                   0.010043
# white_goods                                      0.010043
# borough_Waltham Forest                           0.010043
# borough_Croydon                                  0.011478
# borough_Lewisham                                 0.011478
# elevator                                         0.011478
# tv                                               0.012912
# review_scores_location_9/10                      0.012912
# borough_Camden                                   0.014347
# property_type_Other                              0.018651
# borough_Kensington and Chelsea                   0.024390
# host_days_active                                 0.028694
# room_type_Shared room                            0.028694
# room_type_Entire home/apt                        0.031564
# minimum_nights                                   0.032999
# borough_Westminster                              0.032999
# security_deposit                                 0.034433
# bathrooms                                        0.034433
# number_of_reviews                                0.035868
# extra_people                                     0.054519
# availability_90                                  0.070301
# host_listings_count                              0.086083
# cleaning_fee                                     0.094692
# accommodates                                     0.101865
#
# [111 rows x 1 columns]

# %%
# Plotting feature importances
plt.figure(figsize=(8,20))
plt.barh(ft_weights_xgb_reg.index, ft_weights_xgb_reg.weight, align='center') 
plt.title("Feature importances in the XGBoost model", fontsize=14)
plt.xlabel("Feature importance")
plt.margins(y=0.01)
plt.show()

# %% [markdown]
# About a third of features have a feature importance of 0 in this XGBoost regression model, and could potentially be removed (although they will not be for the deep learning modeling part of this project, as they may have interactions with other features).
#
# **The top 10 most important features are:**
# - How many people the property accommodates
# - The cleaning fee
# - How many other listings the host has (and whether they are a multi-listing host)
# - How many days are available to book out of the next 90
# - The fee per extra person
# - The number of reviews
# - The number of bathrooms
# - The security deposit
# - If the property is in Westminster
# - The minimum nights stay
#
# It is not surprising that the most important feature is how many people the property accommodates, as that's one of the main things you would use to search for properties with in the first place. It is also not surprising that features related to location and reviews are in the top ten.
#
# It is perhaps more surprising that **the third most important feature is related to how many other listings the host manages on Airbnb, rather than the listing itself**. However, this does not mean that a host that manages more properties will result in a listing gaining higher prices. Firstly, the data appears to be somewhat skewed by a few very large property managers. Secondly, the relationship is with the advertised prices set, rather than actual prices achieved, suggesting that if anything more experienced hosts tend to set (rather than necessarily achieve) higher prices. And thirdly, we cannot necessarily imply a causative relationship - it could be that more experienced multi-listing hosts (especially Airbnb property management companies) tend to take on more expensive properties (which is indeed the case for some, e.g. One Fine Stay).
#
# It is also notable that **three other fee types - cleaning, security and extra people - all make the top 10 feature list**. It is likely that these are positive relationships, and that when a host sets a higher price for the nightly stay they are also likely to set other prices high.

# %%
# Median price for different host listing counts
plt.figure()
df.groupby('host_listings_count').price.median().plot(figsize=(20,4), kind='bar')
plt.title('Median price of listings hosted by hosts who are responsible for other properties')
plt.xlabel('Number of properties managed by hosts')
plt.ylabel('Median price (£)');

# %% [markdown]
# ### Model 2: three layer neural network

# %% [markdown]
# For the initial version of the neural network, a relatively shallow three layer NN will be created. It will consist of densely-connected layers, and use a relu activation function for the hidden layers and a linear activation function for the output layer, as it is being used for a regression task. The loss function will be mean squared error (again, because this is for regression).

# %%
# Building the model
nn2 = models.Sequential()
nn2.add(layers.Dense(128, input_shape=(X_train.shape[1],), activation='relu'))
nn2.add(layers.Dense(256, activation='relu'))
nn2.add(layers.Dense(256, activation='relu'))
nn2.add(layers.Dense(1, activation='linear'))

# Compiling the model
nn2.compile(loss='mean_squared_error',
            optimizer='adam',
            metrics=['mean_squared_error'])

# Model summary
print(nn2.summary())

# Visualising the neural network
SVG(model_to_dot(nn2, show_layer_names=False, show_shapes=True).create(prog='dot', format='svg'))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               14336
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 113,409
# Trainable params: 113,409
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Training the model
nn2_start = time.time()

nn2_history = nn2.fit(X_train,
                  y_train,
                  epochs=100,
                  batch_size=256,
                  validation_split = 0.1)

nn2_end = time.time()

print(f"Time taken to run: {round((nn2_end - nn2_start)/60,1)} minutes")
# Out:
# Train on 57184 samples, validate on 6354 samples
# Epoch 1/100
# 57184/57184 [==============================] - 3s 51us/step - loss: 0.6164 - mean_squared_error: 0.6164 - val_loss: 0.2121 - val_mean_squared_error: 0.2121
# Epoch 2/100
# 57184/57184 [==============================] - 2s 32us/step - loss: 0.1889 - mean_squared_error: 0.1889 - val_loss: 0.1888 - val_mean_squared_error: 0.1888
# Epoch 3/100
# 57184/57184 [==============================] - 2s 33us/step - loss: 0.1656 - mean_squared_error: 0.1656 - val_loss: 0.1757 - val_mean_squared_error: 0.1757
# Epoch 4/100
# 57184/57184 [==============================] - 2s 31us/step - loss: 0.1531 - mean_squared_error: 0.1531 - val_loss: 0.1721 - val_mean_squared_error: 0.1721
# Epoch 5/100
# 57184/57184 [==============================] - 2s 33us/step - loss: 0.1462 - mean_squared_error: 0.1462 - val_loss: 0.1663 - val_mean_squared_error: 0.1663
# Epoch 6/100
# 57184/57184 [==============================] - 2s 33us/step - loss: 0.1405 - mean_squared_error: 0.1405 - val_loss: 0.1652 - val_mean_squared_error: 0.1652
# Epoch 7/100
# 57184/57184 [==============================] - 2s 32us/step - loss: 0.1365 - mean_squared_error: 0.1365 - val_loss: 0.1664 - val_mean_squared_error: 0.1664
# Epoch 8/100
# 57184/57184 [==============================] - 2s 32us/step - loss: 0.1301 - mean_squared_error: 0.1301 - val_loss: 0.1638 - val_mean_squared_error: 0.1638
# Epoch 9/100
# 57184/57184 [==============================] - 2s 32us/step - loss: 0.1272 - mean_squared_error: 0.1272 - val_loss: 0.1695 - val_mean_squared_error: 0.1695
# Epoch 10/100
# 57184/57184 [==============================] - 2s 32us/step - loss: 0.1231 - mean_squared_error: 0.1231 - val_loss: 0.1661 - val_mean_squared_error: 0.1661
# Epoch 11/100
# 57184/57184 [==============================] - 2s 32us/step - loss: 0.1207 - mean_squared_error: 0.1207 - val_loss: 0.2089 - val_mean_squared_error: 0.2089
# Epoch 12/100
# 57184/57184 [==============================] - 2s 31us/step - loss: 0.1164 - mean_squared_error: 0.1164 - val_loss: 0.1711 - val_mean_squared_error: 0.1711
# Epoch 13/100
# 57184/57184 [==============================] - 2s 32us/step - loss: 0.1122 - mean_squared_error: 0.1122 - val_loss: 0.1675 - val_mean_squared_error: 0.1675
# Epoch 14/100
# 57184/57184 [==============================] - 2s 32us/step - loss: 0.1090 - mean_squared_error: 0.1090 - val_loss: 0.1683 - val_mean_squared_error: 0.1683
# Epoch 15/100
# 57184/57184 [==============================] - 2s 32us/step - loss: 0.1029 - mean_squared_error: 0.1029 - val_loss: 0.1648 - val_mean_squared_error: 0.1648
# Epoch 16/100
# 57184/57184 [==============================] - 2s 31us/step - loss: 0.0989 - mean_squared_error: 0.0989 - val_loss: 0.1745 - val_mean_squared_error: 0.1745
# Epoch 17/100
# 57184/57184 [==============================] - 2s 33us/step - loss: 0.0975 - mean_squared_error: 0.0975 - val_loss: 0.1689 - val_mean_squared_error: 0.1689
# Epoch 18/100
# 57184/57184 [==============================] - 2s 32us/step - loss: 0.0937 - mean_squared_error: 0.0937 - val_loss: 0.1707 - val_mean_squared_error: 0.1707
# Epoch 19/100
# 57184/57184 [==============================] - 2s 30us/step - loss: 0.0907 - mean_squared_error: 0.0907 - val_loss: 0.1732 - val_mean_squared_error: 0.1732
# Epoch 20/100
# 57184/57184 [==============================] - 2s 33us/step - loss: 0.0865 - mean_squared_error: 0.0865 - val_loss: 0.1757 - val_mean_squared_error: 0.1757
# Epoch 21/100
# 57184/57184 [==============================] - 2s 43us/step - loss: 0.0817 - mean_squared_error: 0.0817 - val_loss: 0.1758 - val_mean_squared_error: 0.1758
# Epoch 22/100
# 57184/57184 [==============================] - 3s 46us/step - loss: 0.0785 - mean_squared_error: 0.0785 - val_loss: 0.2004 - val_mean_squared_error: 0.2004
# Epoch 23/100
# 57184/57184 [==============================] - 3s 44us/step - loss: 0.0780 - mean_squared_error: 0.0780 - val_loss: 0.1767 - val_mean_squared_error: 0.1767
# Epoch 24/100
# 57184/57184 [==============================] - 2s 38us/step - loss: 0.0721 - mean_squared_error: 0.0721 - val_loss: 0.1819 - val_mean_squared_error: 0.1819
# Epoch 25/100
# 57184/57184 [==============================] - 2s 38us/step - loss: 0.0695 - mean_squared_error: 0.0695 - val_loss: 0.1843 - val_mean_squared_error: 0.1843
# Epoch 26/100
# 57184/57184 [==============================] - 2s 37us/step - loss: 0.0658 - mean_squared_error: 0.0658 - val_loss: 0.1864 - val_mean_squared_error: 0.1864
# Epoch 27/100
# 57184/57184 [==============================] - 2s 33us/step - loss: 0.0624 - mean_squared_error: 0.0624 - val_loss: 0.1862 - val_mean_squared_error: 0.1862
# Epoch 28/100
# 57184/57184 [==============================] - 2s 32us/step - loss: 0.0606 - mean_squared_error: 0.0606 - val_loss: 0.1936 - val_mean_squared_error: 0.1936
# Epoch 29/100
# 57184/57184 [==============================] - 2s 33us/step - loss: 0.0586 - mean_squared_error: 0.0586 - val_loss: 0.1931 - val_mean_squared_error: 0.1931
# Epoch 30/100
# 57184/57184 [==============================] - 2s 34us/step - loss: 0.0558 - mean_squared_error: 0.0558 - val_loss: 0.1973 - val_mean_squared_error: 0.1973
# Epoch 31/100
# 57184/57184 [==============================] - 2s 32us/step - loss: 0.0545 - mean_squared_error: 0.0545 - val_loss: 0.1992 - val_mean_squared_error: 0.1992
# Epoch 32/100
# 57184/57184 [==============================] - 2s 32us/step - loss: 0.0512 - mean_squared_error: 0.0512 - val_loss: 0.1997 - val_mean_squared_error: 0.1997
# Epoch 33/100
# 57184/57184 [==============================] - 2s 32us/step - loss: 0.0477 - mean_squared_error: 0.0477 - val_loss: 0.2022 - val_mean_squared_error: 0.2022
# Epoch 34/100
# 57184/57184 [==============================] - 2s 32us/step - loss: 0.0470 - mean_squared_error: 0.0470 - val_loss: 0.1971 - val_mean_squared_error: 0.1971
# Epoch 35/100
# 57184/57184 [==============================] - 2s 32us/step - loss: 0.0448 - mean_squared_error: 0.0448 - val_loss: 0.2137 - val_mean_squared_error: 0.2137
# Epoch 36/100
# 57184/57184 [==============================] - 2s 32us/step - loss: 0.0438 - mean_squared_error: 0.0438 - val_loss: 0.2116 - val_mean_squared_error: 0.2116
# Epoch 37/100
# 57184/57184 [==============================] - 2s 33us/step - loss: 0.0429 - mean_squared_error: 0.0429 - val_loss: 0.2034 - val_mean_squared_error: 0.2034
# Epoch 38/100
# 57184/57184 [==============================] - 2s 33us/step - loss: 0.0400 - mean_squared_error: 0.0400 - val_loss: 0.2072 - val_mean_squared_error: 0.2072
# Epoch 39/100
# 57184/57184 [==============================] - 2s 32us/step - loss: 0.0392 - mean_squared_error: 0.0392 - val_loss: 0.2079 - val_mean_squared_error: 0.2079
# Epoch 40/100
# 57184/57184 [==============================] - 2s 31us/step - loss: 0.0374 - mean_squared_error: 0.0374 - val_loss: 0.2060 - val_mean_squared_error: 0.2060
# Epoch 41/100
# 57184/57184 [==============================] - 2s 33us/step - loss: 0.0369 - mean_squared_error: 0.0369 - val_loss: 0.2192 - val_mean_squared_error: 0.2192
# Epoch 42/100
# 57184/57184 [==============================] - 2s 33us/step - loss: 0.0362 - mean_squared_error: 0.0362 - val_loss: 0.2167 - val_mean_squared_error: 0.2167
# Epoch 43/100
# 57184/57184 [==============================] - 2s 33us/step - loss: 0.0348 - mean_squared_error: 0.0348 - val_loss: 0.2113 - val_mean_squared_error: 0.2113
# Epoch 44/100
# 57184/57184 [==============================] - 2s 34us/step - loss: 0.0336 - mean_squared_error: 0.0336 - val_loss: 0.2087 - val_mean_squared_error: 0.2087
# Epoch 45/100
# 57184/57184 [==============================] - 2s 39us/step - loss: 0.0324 - mean_squared_error: 0.0324 - val_loss: 0.2180 - val_mean_squared_error: 0.2180
# Epoch 46/100
# 57184/57184 [==============================] - 2s 42us/step - loss: 0.0308 - mean_squared_error: 0.0308 - val_loss: 0.2090 - val_mean_squared_error: 0.2090
# Epoch 47/100
# 57184/57184 [==============================] - 2s 35us/step - loss: 0.0307 - mean_squared_error: 0.0307 - val_loss: 0.2127 - val_mean_squared_error: 0.2127
# Epoch 48/100
# 57184/57184 [==============================] - 2s 36us/step - loss: 0.0296 - mean_squared_error: 0.0296 - val_loss: 0.2148 - val_mean_squared_error: 0.2148
# Epoch 49/100
# 57184/57184 [==============================] - 2s 39us/step - loss: 0.0287 - mean_squared_error: 0.0287 - val_loss: 0.2164 - val_mean_squared_error: 0.2164
# Epoch 50/100
# 57184/57184 [==============================] - 2s 38us/step - loss: 0.0278 - mean_squared_error: 0.0278 - val_loss: 0.2124 - val_mean_squared_error: 0.2124
# Epoch 51/100
# 57184/57184 [==============================] - 2s 33us/step - loss: 0.0300 - mean_squared_error: 0.0300 - val_loss: 0.2146 - val_mean_squared_error: 0.2146
# Epoch 52/100
# 57184/57184 [==============================] - 2s 32us/step - loss: 0.0290 - mean_squared_error: 0.0290 - val_loss: 0.2146 - val_mean_squared_error: 0.2146
# Epoch 53/100
# 57184/57184 [==============================] - 2s 36us/step - loss: 0.0269 - mean_squared_error: 0.0269 - val_loss: 0.2160 - val_mean_squared_error: 0.2160
# Epoch 54/100
# 57184/57184 [==============================] - 2s 34us/step - loss: 0.0262 - mean_squared_error: 0.0262 - val_loss: 0.2182 - val_mean_squared_error: 0.2182
# Epoch 55/100
# 57184/57184 [==============================] - 2s 33us/step - loss: 0.0260 - mean_squared_error: 0.0260 - val_loss: 0.2192 - val_mean_squared_error: 0.2192
# Epoch 56/100
# 57184/57184 [==============================] - 2s 32us/step - loss: 0.0249 - mean_squared_error: 0.0249 - val_loss: 0.2201 - val_mean_squared_error: 0.2201
# Epoch 57/100
# 57184/57184 [==============================] - 2s 33us/step - loss: 0.0241 - mean_squared_error: 0.0241 - val_loss: 0.2138 - val_mean_squared_error: 0.2138
# Epoch 58/100
# 57184/57184 [==============================] - 2s 32us/step - loss: 0.0246 - mean_squared_error: 0.0246 - val_loss: 0.2181 - val_mean_squared_error: 0.2181
# Epoch 59/100
# 57184/57184 [==============================] - 2s 31us/step - loss: 0.0236 - mean_squared_error: 0.0236 - val_loss: 0.2170 - val_mean_squared_error: 0.2170
# Epoch 60/100
# 57184/57184 [==============================] - 2s 33us/step - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.2196 - val_mean_squared_error: 0.2196
# Epoch 61/100
# 57184/57184 [==============================] - 2s 32us/step - loss: 0.0233 - mean_squared_error: 0.0233 - val_loss: 0.2186 - val_mean_squared_error: 0.2186
# Epoch 62/100
# 57184/57184 [==============================] - 2s 32us/step - loss: 0.0243 - mean_squared_error: 0.0243 - val_loss: 0.2188 - val_mean_squared_error: 0.2188
# Epoch 63/100
# 57184/57184 [==============================] - 2s 32us/step - loss: 0.0221 - mean_squared_error: 0.0221 - val_loss: 0.2162 - val_mean_squared_error: 0.2162
# Epoch 64/100
# 57184/57184 [==============================] - 2s 31us/step - loss: 0.0215 - mean_squared_error: 0.0215 - val_loss: 0.2182 - val_mean_squared_error: 0.2182
# Epoch 65/100
# 57184/57184 [==============================] - 2s 32us/step - loss: 0.0216 - mean_squared_error: 0.0216 - val_loss: 0.2163 - val_mean_squared_error: 0.2163
# Epoch 66/100
# 57184/57184 [==============================] - 2s 31us/step - loss: 0.0218 - mean_squared_error: 0.0218 - val_loss: 0.2239 - val_mean_squared_error: 0.2239
# Epoch 67/100
# 57184/57184 [==============================] - 2s 32us/step - loss: 0.0208 - mean_squared_error: 0.0208 - val_loss: 0.2200 - val_mean_squared_error: 0.2200
# Epoch 68/100
# 57184/57184 [==============================] - 2s 32us/step - loss: 0.0207 - mean_squared_error: 0.0207 - val_loss: 0.2196 - val_mean_squared_error: 0.2196
# Epoch 69/100
# 57184/57184 [==============================] - 2s 32us/step - loss: 0.0197 - mean_squared_error: 0.0197 - val_loss: 0.2196 - val_mean_squared_error: 0.2196
# Epoch 70/100
# 57184/57184 [==============================] - 2s 33us/step - loss: 0.0201 - mean_squared_error: 0.0201 - val_loss: 0.2199 - val_mean_squared_error: 0.2199
# Epoch 71/100
# 57184/57184 [==============================] - 2s 35us/step - loss: 0.0192 - mean_squared_error: 0.0192 - val_loss: 0.2204 - val_mean_squared_error: 0.2204
# Epoch 72/100
# 57184/57184 [==============================] - 2s 33us/step - loss: 0.0207 - mean_squared_error: 0.0207 - val_loss: 0.2200 - val_mean_squared_error: 0.2200
# Epoch 73/100
# 57184/57184 [==============================] - 2s 37us/step - loss: 0.0199 - mean_squared_error: 0.0199 - val_loss: 0.2166 - val_mean_squared_error: 0.2166
# Epoch 74/100
# 57184/57184 [==============================] - 2s 32us/step - loss: 0.0186 - mean_squared_error: 0.0186 - val_loss: 0.2289 - val_mean_squared_error: 0.2289
# Epoch 75/100
# 57184/57184 [==============================] - 2s 36us/step - loss: 0.0181 - mean_squared_error: 0.0181 - val_loss: 0.2198 - val_mean_squared_error: 0.2198
# Epoch 76/100
# 57184/57184 [==============================] - 2s 35us/step - loss: 0.0191 - mean_squared_error: 0.0191 - val_loss: 0.2193 - val_mean_squared_error: 0.2193
# Epoch 77/100
# 57184/57184 [==============================] - 2s 33us/step - loss: 0.0180 - mean_squared_error: 0.0180 - val_loss: 0.2196 - val_mean_squared_error: 0.2196
# Epoch 78/100
# 57184/57184 [==============================] - 2s 32us/step - loss: 0.0177 - mean_squared_error: 0.0177 - val_loss: 0.2189 - val_mean_squared_error: 0.2189
# Epoch 79/100
# 57184/57184 [==============================] - 2s 34us/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.2182 - val_mean_squared_error: 0.2182
# Epoch 80/100
# 57184/57184 [==============================] - 2s 33us/step - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.2166 - val_mean_squared_error: 0.2166
# Epoch 81/100
# 57184/57184 [==============================] - 2s 35us/step - loss: 0.0182 - mean_squared_error: 0.0182 - val_loss: 0.2217 - val_mean_squared_error: 0.2217
# Epoch 82/100
# 57184/57184 [==============================] - 2s 33us/step - loss: 0.0176 - mean_squared_error: 0.0176 - val_loss: 0.2203 - val_mean_squared_error: 0.2203
# Epoch 83/100
# 57184/57184 [==============================] - 2s 34us/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.2182 - val_mean_squared_error: 0.2182
# Epoch 84/100
# 57184/57184 [==============================] - 2s 35us/step - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.2269 - val_mean_squared_error: 0.2269
# Epoch 85/100
# 57184/57184 [==============================] - 2s 42us/step - loss: 0.0168 - mean_squared_error: 0.0168 - val_loss: 0.2220 - val_mean_squared_error: 0.2220
# Epoch 86/100
# 57184/57184 [==============================] - 2s 42us/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.2274 - val_mean_squared_error: 0.2274
# Epoch 87/100
# 57184/57184 [==============================] - 2s 43us/step - loss: 0.0183 - mean_squared_error: 0.0183 - val_loss: 0.2200 - val_mean_squared_error: 0.2200
# Epoch 88/100
# 57184/57184 [==============================] - 2s 38us/step - loss: 0.0152 - mean_squared_error: 0.0152 - val_loss: 0.2180 - val_mean_squared_error: 0.2180
# Epoch 89/100
# 57184/57184 [==============================] - 2s 35us/step - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 0.2222 - val_mean_squared_error: 0.2222
# Epoch 90/100
# 57184/57184 [==============================] - 2s 34us/step - loss: 0.0154 - mean_squared_error: 0.0154 - val_loss: 0.2316 - val_mean_squared_error: 0.2316
# Epoch 91/100
# 57184/57184 [==============================] - 2s 32us/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.2218 - val_mean_squared_error: 0.2218
# Epoch 92/100
# 57184/57184 [==============================] - 2s 33us/step - loss: 0.0151 - mean_squared_error: 0.0151 - val_loss: 0.2168 - val_mean_squared_error: 0.2168
# Epoch 93/100
# 57184/57184 [==============================] - 2s 34us/step - loss: 0.0158 - mean_squared_error: 0.0158 - val_loss: 0.2195 - val_mean_squared_error: 0.2195
# Epoch 94/100
# 57184/57184 [==============================] - 2s 35us/step - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 0.2245 - val_mean_squared_error: 0.2245
# Epoch 95/100
# 57184/57184 [==============================] - 2s 31us/step - loss: 0.0154 - mean_squared_error: 0.0154 - val_loss: 0.2192 - val_mean_squared_error: 0.2192
# Epoch 96/100
# 57184/57184 [==============================] - 2s 31us/step - loss: 0.0151 - mean_squared_error: 0.0151 - val_loss: 0.2216 - val_mean_squared_error: 0.2216
# Epoch 97/100
# 57184/57184 [==============================] - 2s 32us/step - loss: 0.0146 - mean_squared_error: 0.0146 - val_loss: 0.2230 - val_mean_squared_error: 0.2230
# Epoch 98/100
# 57184/57184 [==============================] - 2s 30us/step - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.2204 - val_mean_squared_error: 0.2204
# Epoch 99/100
# 57184/57184 [==============================] - 2s 33us/step - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.2247 - val_mean_squared_error: 0.2247
# Epoch 100/100
# 57184/57184 [==============================] - 2s 31us/step - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 0.2227 - val_mean_squared_error: 0.2227
# Time taken to run: 3.2 minutes

# %%
def nn_model_evaluation(model, skip_epochs=0, X_train=X_train, X_test=X_test, y_train=y_train, y_test=y_test):
    """
    For a given neural network model that has already been fit, prints for the train and tests sets the MSE and r squared
    values, a line graph of the loss in each epoch, and a scatterplot of predicted vs. actual values with a line
    representing where predicted = actual values. Optionally, a value for skip_epoch can be provided, which skips that
    number of epochs in the line graph of losses (useful in cases where the loss in the first epoch is orders of magnitude
    larger than subsequent epochs). Training and test sets can also optionally be specified.
    """

    # MSE and r squared values
    y_test_pred = model.predict(X_test)
    y_train_pred = model.predict(X_train)
    print("Training MSE:", round(mean_squared_error(y_train, y_train_pred),4))
    print("Validation MSE:", round(mean_squared_error(y_test, y_test_pred),4))
    print("\nTraining r2:", round(r2_score(y_train, y_train_pred),4))
    print("Validation r2:", round(r2_score(y_test, y_test_pred),4))
    
    # Line graph of losses
    model_results = model.history.history
    plt.plot(list(range((skip_epochs+1),len(model_results['loss'])+1)), model_results['loss'][skip_epochs:], label='Train')
    plt.plot(list(range((skip_epochs+1),len(model_results['val_loss'])+1)), model_results['val_loss'][skip_epochs:], label='Test', color='green')
    plt.legend()
    plt.title('Training and test loss at each epoch', fontsize=14)
    plt.show()
    
    # Scatterplot of predicted vs. actual values
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
    fig.suptitle('Predicted vs. actual values', fontsize=14, y=1)
    plt.subplots_adjust(top=0.93, wspace=0)
    
    ax1.scatter(y_test, y_test_pred, s=2, alpha=0.7)
    ax1.plot(list(range(2,8)), list(range(2,8)), color='black', linestyle='--')
    ax1.set_title('Test set')
    ax1.set_xlabel('Actual values')
    ax1.set_ylabel('Predicted values')
    
    ax2.scatter(y_train, y_train_pred, s=2, alpha=0.7)
    ax2.plot(list(range(2,8)), list(range(2,8)), color='black', linestyle='--')
    ax2.set_title('Train set')
    ax2.set_xlabel('Actual values')
    ax2.set_ylabel('')
    ax2.set_yticklabels(labels='')
    
    plt.show()

# %%
nn_model_evaluation(nn2)
# Out:
# Training MSE: 0.0331
# Validation MSE: 0.2163
#
# Training r2: 0.9438
# Validation r2: 0.6292

# %% [markdown]
# Compared to the XGBoost model the neural network has performed worse. However, the training set had much better results in the neural network, indicating that overfitting is an issue.
#
# The line graph above highlights this point, showing the disparity between the train and test set MSE at each epoch. The scatterplot above further highlights this point, demonstrating that the values cluster more closely to a line form for the training set.
#
# Further iterations on the model will attempt to reduce overfitting.

# %% [markdown]
# ### Model 3: four-layer neural network with L1 regularization and more epochs

# %% [markdown]
# To try and reduce over-fitting, L1 regularization will be used. This acts to reduce parameter coefficients (or potentially remove them altogether by setting the coefficient to zero) in order to to reduce model complexity and overfitting. Unlike L2 regularization, L1 regularization performs penalised estimation and selection simultaneously, and so is preferred when the number of predictors is very high.
#
# An extra layer will also be added, to see whether it is able to increase model accuracy (r2).

# %%
# Building the model
nn3 = models.Sequential()
nn3.add(layers.Dense(128, input_shape=(X_train.shape[1],), kernel_regularizer=regularizers.l1(0.005), activation='relu'))
nn3.add(layers.Dense(256, kernel_regularizer=regularizers.l1(0.005), activation='relu'))
nn3.add(layers.Dense(256, kernel_regularizer=regularizers.l1(0.005), activation='relu'))
nn3.add(layers.Dense(512, kernel_regularizer=regularizers.l1(0.005), activation='relu'))
nn3.add(layers.Dense(1, activation='linear'))

# Compiling the model
nn3.compile(loss='mean_squared_error',
            optimizer='adam',
            metrics=['mean_squared_error'])

# Model summary
print(nn3.summary())

# Visualising the neural network
SVG(model_to_dot(nn3, show_layer_names=False, show_shapes=True).create(prog='dot', format='svg'))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 128)               14336
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_8 (Dense)              (None, 512)               131584
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 245,249
# Trainable params: 245,249
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Training the model
nn3_start = time.time()

nn3_history = nn3.fit(X_train,
                  y_train,
                  epochs=150,
                  batch_size=256,
                  validation_split = 0.1)

nn3_end = time.time()

print(f"Time taken to run: {round((nn3_end - nn3_start)/60,1)} minutes")
# Out:
# Train on 57184 samples, validate on 6354 samples
# Epoch 1/150
# 57184/57184 [==============================] - 4s 65us/step - loss: 24.6864 - mean_squared_error: 0.5700 - val_loss: 6.1273 - val_mean_squared_error: 0.2016.6936 - mean_squared_er
# Epoch 2/150
# 57184/57184 [==============================] - 5s 81us/step - loss: 2.8334 - mean_squared_error: 0.1844 - val_loss: 1.1930 - val_mean_squared_error: 0.1951
# Epoch 3/150
# 57184/57184 [==============================] - 4s 76us/step - loss: 0.7851 - mean_squared_error: 0.1918 - val_loss: 0.5476 - val_mean_squared_error: 0.1898
# Epoch 4/150
# 57184/57184 [==============================] - 4s 69us/step - loss: 0.4635 - mean_squared_error: 0.1830 - val_loss: 0.4161 - val_mean_squared_error: 0.1836
# Epoch 5/150
# 57184/57184 [==============================] - 4s 69us/step - loss: 0.3939 - mean_squared_error: 0.1786 - val_loss: 0.3869 - val_mean_squared_error: 0.1817
# Epoch 6/150
# 57184/57184 [==============================] - 3s 56us/step - loss: 0.3771 - mean_squared_error: 0.1776 - val_loss: 0.3765 - val_mean_squared_error: 0.1809
# Epoch 7/150
# 57184/57184 [==============================] - 3s 60us/step - loss: 0.3703 - mean_squared_error: 0.1764 - val_loss: 0.3707 - val_mean_squared_error: 0.1798
# Epoch 8/150
# 57184/57184 [==============================] - 4s 62us/step - loss: 0.3646 - mean_squared_error: 0.1754 - val_loss: 0.3650 - val_mean_squared_error: 0.1786
# Epoch 9/150
# 57184/57184 [==============================] - 4s 63us/step - loss: 0.3608 - mean_squared_error: 0.1748 - val_loss: 0.3641 - val_mean_squared_error: 0.1800
# Epoch 10/150
# 57184/57184 [==============================] - 3s 61us/step - loss: 0.3581 - mean_squared_error: 0.1747 - val_loss: 0.3611 - val_mean_squared_error: 0.1782
# Epoch 11/150
# 57184/57184 [==============================] - 3s 59us/step - loss: 0.3564 - mean_squared_error: 0.1741 - val_loss: 0.3596 - val_mean_squared_error: 0.1777
# Epoch 12/150
# 57184/57184 [==============================] - 3s 61us/step - loss: 0.3551 - mean_squared_error: 0.1739 - val_loss: 0.3593 - val_mean_squared_error: 0.1777
# Epoch 13/150
# 57184/57184 [==============================] - 4s 65us/step - loss: 0.3554 - mean_squared_error: 0.1739 - val_loss: 0.3614 - val_mean_squared_error: 0.1808
# Epoch 14/150
# 57184/57184 [==============================] - 4s 69us/step - loss: 0.3554 - mean_squared_error: 0.1739 - val_loss: 0.3579 - val_mean_squared_error: 0.1770
# Epoch 15/150
# 57184/57184 [==============================] - 3s 59us/step - loss: 0.3554 - mean_squared_error: 0.1739 - val_loss: 0.3600 - val_mean_squared_error: 0.1780
# Epoch 16/150
# 57184/57184 [==============================] - 3s 56us/step - loss: 0.3545 - mean_squared_error: 0.1735 - val_loss: 0.3582 - val_mean_squared_error: 0.1773
# Epoch 17/150
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.3543 - mean_squared_error: 0.1735 - val_loss: 0.3586 - val_mean_squared_error: 0.1783
# Epoch 18/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.3538 - mean_squared_error: 0.1733 - val_loss: 0.3577 - val_mean_squared_error: 0.1767
# Epoch 19/150
# 57184/57184 [==============================] - 3s 48us/step - loss: 0.3541 - mean_squared_error: 0.1732 - val_loss: 0.3571 - val_mean_squared_error: 0.1769
# Epoch 20/150
# 57184/57184 [==============================] - 3s 48us/step - loss: 0.3534 - mean_squared_error: 0.1730 - val_loss: 0.3565 - val_mean_squared_error: 0.1770
# Epoch 21/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.3535 - mean_squared_error: 0.1734 - val_loss: 0.3572 - val_mean_squared_error: 0.1775
# Epoch 22/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.3535 - mean_squared_error: 0.1735 - val_loss: 0.3561 - val_mean_squared_error: 0.1766
# Epoch 23/150
# 57184/57184 [==============================] - 3s 48us/step - loss: 0.3526 - mean_squared_error: 0.1733 - val_loss: 0.3560 - val_mean_squared_error: 0.1774
# Epoch 24/150
# 57184/57184 [==============================] - 3s 47us/step - loss: 0.3516 - mean_squared_error: 0.1730 - val_loss: 0.3557 - val_mean_squared_error: 0.1774
# Epoch 25/150
# 57184/57184 [==============================] - 3s 47us/step - loss: 0.3512 - mean_squared_error: 0.1733 - val_loss: 0.3535 - val_mean_squared_error: 0.1761
# Epoch 26/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.3515 - mean_squared_error: 0.1734 - val_loss: 0.3549 - val_mean_squared_error: 0.1771
# Epoch 27/150
# 57184/57184 [==============================] - 3s 57us/step - loss: 0.3512 - mean_squared_error: 0.1732 - val_loss: 0.3557 - val_mean_squared_error: 0.1782
# Epoch 28/150
# 57184/57184 [==============================] - 3s 57us/step - loss: 0.3511 - mean_squared_error: 0.1731 - val_loss: 0.3544 - val_mean_squared_error: 0.1778
# Epoch 29/150
# 57184/57184 [==============================] - 3s 51us/step - loss: 0.3513 - mean_squared_error: 0.1734 - val_loss: 0.3562 - val_mean_squared_error: 0.1778
# Epoch 30/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.3508 - mean_squared_error: 0.1732 - val_loss: 0.3549 - val_mean_squared_error: 0.1777
# Epoch 31/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.3506 - mean_squared_error: 0.1732 - val_loss: 0.3556 - val_mean_squared_error: 0.1783
# Epoch 32/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.3504 - mean_squared_error: 0.1732 - val_loss: 0.3536 - val_mean_squared_error: 0.1765
# Epoch 33/150
# 57184/57184 [==============================] - 3s 47us/step - loss: 0.3504 - mean_squared_error: 0.1732 - val_loss: 0.3575 - val_mean_squared_error: 0.1789
# Epoch 34/150
# 57184/57184 [==============================] - 3s 48us/step - loss: 0.3503 - mean_squared_error: 0.1730 - val_loss: 0.3546 - val_mean_squared_error: 0.1771
# Epoch 35/150
# 57184/57184 [==============================] - 3s 48us/step - loss: 0.3499 - mean_squared_error: 0.1731 - val_loss: 0.3541 - val_mean_squared_error: 0.1774
# Epoch 36/150
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.3500 - mean_squared_error: 0.1730 - val_loss: 0.3555 - val_mean_squared_error: 0.1780
# Epoch 37/150
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.3502 - mean_squared_error: 0.1733 - val_loss: 0.3547 - val_mean_squared_error: 0.1775
# Epoch 38/150
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.3498 - mean_squared_error: 0.1733 - val_loss: 0.3540 - val_mean_squared_error: 0.1778
# Epoch 39/150
# 57184/57184 [==============================] - 3s 56us/step - loss: 0.3497 - mean_squared_error: 0.1733 - val_loss: 0.3534 - val_mean_squared_error: 0.1774
# Epoch 40/150
# 57184/57184 [==============================] - 3s 54us/step - loss: 0.3497 - mean_squared_error: 0.1734 - val_loss: 0.3520 - val_mean_squared_error: 0.1760
# Epoch 41/150
# 57184/57184 [==============================] - 3s 58us/step - loss: 0.3500 - mean_squared_error: 0.1736 - val_loss: 0.3521 - val_mean_squared_error: 0.1762
# Epoch 42/150
# 57184/57184 [==============================] - 3s 56us/step - loss: 0.3489 - mean_squared_error: 0.1732 - val_loss: 0.3535 - val_mean_squared_error: 0.1782
# Epoch 43/150
# 57184/57184 [==============================] - 3s 52us/step - loss: 0.3488 - mean_squared_error: 0.1730 - val_loss: 0.3542 - val_mean_squared_error: 0.1783
# Epoch 44/150
# 57184/57184 [==============================] - 3s 48us/step - loss: 0.3487 - mean_squared_error: 0.1730 - val_loss: 0.3534 - val_mean_squared_error: 0.1773
# Epoch 45/150
# 57184/57184 [==============================] - 3s 47us/step - loss: 0.3491 - mean_squared_error: 0.1734 - val_loss: 0.3501 - val_mean_squared_error: 0.1753
# Epoch 46/150
# 57184/57184 [==============================] - 3s 47us/step - loss: 0.3485 - mean_squared_error: 0.1733 - val_loss: 0.3512 - val_mean_squared_error: 0.1760
# Epoch 47/150
# 57184/57184 [==============================] - 3s 46us/step - loss: 0.3484 - mean_squared_error: 0.1733 - val_loss: 0.3514 - val_mean_squared_error: 0.1762
# Epoch 48/150
# 57184/57184 [==============================] - 3s 47us/step - loss: 0.3478 - mean_squared_error: 0.1730 - val_loss: 0.3504 - val_mean_squared_error: 0.1758
# Epoch 49/150
# 57184/57184 [==============================] - 3s 48us/step - loss: 0.3481 - mean_squared_error: 0.1733 - val_loss: 0.3519 - val_mean_squared_error: 0.1770
# Epoch 50/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.3475 - mean_squared_error: 0.1728 - val_loss: 0.3531 - val_mean_squared_error: 0.1777
# Epoch 51/150
# 57184/57184 [==============================] - 3s 56us/step - loss: 0.3476 - mean_squared_error: 0.1729 - val_loss: 0.3520 - val_mean_squared_error: 0.1769
# Epoch 52/150
# 57184/57184 [==============================] - 3s 55us/step - loss: 0.3479 - mean_squared_error: 0.1732 - val_loss: 0.3514 - val_mean_squared_error: 0.1771
# Epoch 53/150
# 57184/57184 [==============================] - 3s 52us/step - loss: 0.3475 - mean_squared_error: 0.1730 - val_loss: 0.3524 - val_mean_squared_error: 0.1778
# Epoch 54/150
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.3473 - mean_squared_error: 0.1730 - val_loss: 0.3518 - val_mean_squared_error: 0.1766
# Epoch 55/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.3472 - mean_squared_error: 0.1730 - val_loss: 0.3505 - val_mean_squared_error: 0.1760
# Epoch 56/150
# 57184/57184 [==============================] - 3s 48us/step - loss: 0.3475 - mean_squared_error: 0.1734 - val_loss: 0.3518 - val_mean_squared_error: 0.1780
# Epoch 57/150
# 57184/57184 [==============================] - 3s 47us/step - loss: 0.3468 - mean_squared_error: 0.1730 - val_loss: 0.3512 - val_mean_squared_error: 0.1772
# Epoch 58/150
# 57184/57184 [==============================] - 4s 62us/step - loss: 0.3468 - mean_squared_error: 0.1731 - val_loss: 0.3515 - val_mean_squared_error: 0.1780
# Epoch 59/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.3466 - mean_squared_error: 0.1731 - val_loss: 0.3514 - val_mean_squared_error: 0.1777
# Epoch 60/150
# 57184/57184 [==============================] - 3s 61us/step - loss: 0.3468 - mean_squared_error: 0.1730 - val_loss: 0.3523 - val_mean_squared_error: 0.1777
# Epoch 61/150
# 57184/57184 [==============================] - 3s 54us/step - loss: 0.3464 - mean_squared_error: 0.1731 - val_loss: 0.3507 - val_mean_squared_error: 0.1774
# Epoch 62/150
# 57184/57184 [==============================] - 3s 46us/step - loss: 0.3464 - mean_squared_error: 0.1731 - val_loss: 0.3507 - val_mean_squared_error: 0.1776
# Epoch 63/150
# 57184/57184 [==============================] - 3s 48us/step - loss: 0.3463 - mean_squared_error: 0.1730 - val_loss: 0.3510 - val_mean_squared_error: 0.1777
# Epoch 64/150
# 57184/57184 [==============================] - 4s 66us/step - loss: 0.3462 - mean_squared_error: 0.1730 - val_loss: 0.3508 - val_mean_squared_error: 0.1777
# Epoch 65/150
# 57184/57184 [==============================] - 4s 64us/step - loss: 0.3461 - mean_squared_error: 0.1729 - val_loss: 0.3500 - val_mean_squared_error: 0.1766
# Epoch 66/150
# 57184/57184 [==============================] - 3s 52us/step - loss: 0.3459 - mean_squared_error: 0.1731 - val_loss: 0.3504 - val_mean_squared_error: 0.1771
# Epoch 67/150
# 57184/57184 [==============================] - 3s 54us/step - loss: 0.3457 - mean_squared_error: 0.1730 - val_loss: 0.3480 - val_mean_squared_error: 0.1757
# Epoch 68/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.3459 - mean_squared_error: 0.1732 - val_loss: 0.3496 - val_mean_squared_error: 0.1773
# Epoch 69/150
# 57184/57184 [==============================] - 3s 51us/step - loss: 0.3457 - mean_squared_error: 0.1731 - val_loss: 0.3527 - val_mean_squared_error: 0.1802
# Epoch 70/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.3456 - mean_squared_error: 0.1731 - val_loss: 0.3497 - val_mean_squared_error: 0.1771
# Epoch 71/150
# 57184/57184 [==============================] - 3s 47us/step - loss: 0.3456 - mean_squared_error: 0.1732 - val_loss: 0.3491 - val_mean_squared_error: 0.1765
# Epoch 72/150
# 57184/57184 [==============================] - 3s 46us/step - loss: 0.3458 - mean_squared_error: 0.1735 - val_loss: 0.3490 - val_mean_squared_error: 0.1767
# Epoch 73/150
# 57184/57184 [==============================] - 3s 48us/step - loss: 0.3453 - mean_squared_error: 0.1731 - val_loss: 0.3487 - val_mean_squared_error: 0.1765
# Epoch 74/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.3452 - mean_squared_error: 0.1730 - val_loss: 0.3477 - val_mean_squared_error: 0.1759
# Epoch 75/150
# 57184/57184 [==============================] - 3s 46us/step - loss: 0.3451 - mean_squared_error: 0.1730 - val_loss: 0.3499 - val_mean_squared_error: 0.1773
# Epoch 76/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.3451 - mean_squared_error: 0.1730 - val_loss: 0.3482 - val_mean_squared_error: 0.1763
# Epoch 77/150
# 57184/57184 [==============================] - 4s 70us/step - loss: 0.3454 - mean_squared_error: 0.1735 - val_loss: 0.3484 - val_mean_squared_error: 0.1764
# Epoch 78/150
# 57184/57184 [==============================] - 4s 67us/step - loss: 0.3448 - mean_squared_error: 0.1730 - val_loss: 0.3486 - val_mean_squared_error: 0.1767
# Epoch 79/150
# 57184/57184 [==============================] - 4s 61us/step - loss: 0.3451 - mean_squared_error: 0.1732 - val_loss: 0.3477 - val_mean_squared_error: 0.1763
# Epoch 80/150
# 57184/57184 [==============================] - 3s 51us/step - loss: 0.3449 - mean_squared_error: 0.1732 - val_loss: 0.3495 - val_mean_squared_error: 0.1775
# Epoch 81/150
# 57184/57184 [==============================] - 3s 55us/step - loss: 0.3452 - mean_squared_error: 0.1735 - val_loss: 0.3492 - val_mean_squared_error: 0.1775
# Epoch 82/150
# 57184/57184 [==============================] - 3s 46us/step - loss: 0.3449 - mean_squared_error: 0.1734 - val_loss: 0.3488 - val_mean_squared_error: 0.1776
# Epoch 83/150
# 57184/57184 [==============================] - 3s 47us/step - loss: 0.3450 - mean_squared_error: 0.1734 - val_loss: 0.3500 - val_mean_squared_error: 0.1786
# Epoch 84/150
# 57184/57184 [==============================] - 3s 46us/step - loss: 0.3447 - mean_squared_error: 0.1732 - val_loss: 0.3487 - val_mean_squared_error: 0.1768
# Epoch 85/150
# 57184/57184 [==============================] - 3s 45us/step - loss: 0.3448 - mean_squared_error: 0.1733 - val_loss: 0.3483 - val_mean_squared_error: 0.1769
# Epoch 86/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.3446 - mean_squared_error: 0.1731 - val_loss: 0.3491 - val_mean_squared_error: 0.1776
# Epoch 87/150
# 57184/57184 [==============================] - 3s 48us/step - loss: 0.3446 - mean_squared_error: 0.1732 - val_loss: 0.3474 - val_mean_squared_error: 0.1759
# Epoch 88/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.3444 - mean_squared_error: 0.1731 - val_loss: 0.3477 - val_mean_squared_error: 0.1764
# Epoch 89/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.3444 - mean_squared_error: 0.1731 - val_loss: 0.3487 - val_mean_squared_error: 0.1776
# Epoch 90/150
# 57184/57184 [==============================] - 3s 47us/step - loss: 0.3444 - mean_squared_error: 0.1731 - val_loss: 0.3494 - val_mean_squared_error: 0.1777
# Epoch 91/150
# 57184/57184 [==============================] - 3s 46us/step - loss: 0.3443 - mean_squared_error: 0.1730 - val_loss: 0.3468 - val_mean_squared_error: 0.1756
# Epoch 92/150
# 57184/57184 [==============================] - 3s 46us/step - loss: 0.3436 - mean_squared_error: 0.1724 - val_loss: 0.3493 - val_mean_squared_error: 0.1782
# Epoch 93/150
# 57184/57184 [==============================] - 3s 45us/step - loss: 0.3434 - mean_squared_error: 0.1723 - val_loss: 0.3469 - val_mean_squared_error: 0.1755
# Epoch 94/150
# 57184/57184 [==============================] - 3s 46us/step - loss: 0.3431 - mean_squared_error: 0.1720 - val_loss: 0.3475 - val_mean_squared_error: 0.1766
# Epoch 95/150
# 57184/57184 [==============================] - 3s 45us/step - loss: 0.3430 - mean_squared_error: 0.1719 - val_loss: 0.3472 - val_mean_squared_error: 0.1759
# Epoch 96/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.3431 - mean_squared_error: 0.1719 - val_loss: 0.3481 - val_mean_squared_error: 0.1775
# Epoch 97/150
# 57184/57184 [==============================] - 3s 46us/step - loss: 0.3434 - mean_squared_error: 0.1725 - val_loss: 0.3477 - val_mean_squared_error: 0.1768
# Epoch 98/150
# 57184/57184 [==============================] - 3s 48us/step - loss: 0.3432 - mean_squared_error: 0.1721 - val_loss: 0.3486 - val_mean_squared_error: 0.17780.3440
# Epoch 99/150
# 57184/57184 [==============================] - 3s 55us/step - loss: 0.3428 - mean_squared_error: 0.1719 - val_loss: 0.3478 - val_mean_squared_error: 0.1764
# Epoch 100/150
# 57184/57184 [==============================] - 3s 52us/step - loss: 0.3429 - mean_squared_error: 0.1721 - val_loss: 0.3476 - val_mean_squared_error: 0.1771
# Epoch 101/150
# 57184/57184 [==============================] - 3s 47us/step - loss: 0.3430 - mean_squared_error: 0.1721 - val_loss: 0.3484 - val_mean_squared_error: 0.1775
# Epoch 102/150
# 57184/57184 [==============================] - 3s 47us/step - loss: 0.3427 - mean_squared_error: 0.1718 - val_loss: 0.3485 - val_mean_squared_error: 0.1771
# Epoch 103/150
# 57184/57184 [==============================] - 3s 47us/step - loss: 0.3425 - mean_squared_error: 0.1718 - val_loss: 0.3472 - val_mean_squared_error: 0.1765
# Epoch 104/150
# 57184/57184 [==============================] - 3s 45us/step - loss: 0.3428 - mean_squared_error: 0.1720 - val_loss: 0.3474 - val_mean_squared_error: 0.1769
# Epoch 105/150
# 57184/57184 [==============================] - 3s 45us/step - loss: 0.3425 - mean_squared_error: 0.1719 - val_loss: 0.3468 - val_mean_squared_error: 0.1760
# Epoch 106/150
# 57184/57184 [==============================] - 3s 45us/step - loss: 0.3425 - mean_squared_error: 0.1719 - val_loss: 0.3473 - val_mean_squared_error: 0.1767
# Epoch 107/150
# 57184/57184 [==============================] - 3s 45us/step - loss: 0.3424 - mean_squared_error: 0.1718 - val_loss: 0.3470 - val_mean_squared_error: 0.1764
# Epoch 108/150
# 57184/57184 [==============================] - 3s 45us/step - loss: 0.3422 - mean_squared_error: 0.1718 - val_loss: 0.3468 - val_mean_squared_error: 0.1762
# Epoch 109/150
# 57184/57184 [==============================] - 3s 46us/step - loss: 0.3427 - mean_squared_error: 0.1722 - val_loss: 0.3451 - val_mean_squared_error: 0.1750
# Epoch 110/150
# 57184/57184 [==============================] - 3s 48us/step - loss: 0.3426 - mean_squared_error: 0.1722 - val_loss: 0.3465 - val_mean_squared_error: 0.1762
# Epoch 111/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.3421 - mean_squared_error: 0.1719 - val_loss: 0.3477 - val_mean_squared_error: 0.1771
# Epoch 112/150
# 57184/57184 [==============================] - 3s 51us/step - loss: 0.3426 - mean_squared_error: 0.1722 - val_loss: 0.3458 - val_mean_squared_error: 0.1758
# Epoch 113/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.3421 - mean_squared_error: 0.1719 - val_loss: 0.3457 - val_mean_squared_error: 0.1760
# Epoch 114/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.3423 - mean_squared_error: 0.1721 - val_loss: 0.3467 - val_mean_squared_error: 0.1764
# Epoch 115/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.3422 - mean_squared_error: 0.1720 - val_loss: 0.3467 - val_mean_squared_error: 0.1765
# Epoch 116/150
# 57184/57184 [==============================] - 3s 45us/step - loss: 0.3419 - mean_squared_error: 0.1718 - val_loss: 0.3464 - val_mean_squared_error: 0.1765
# Epoch 117/150
# 57184/57184 [==============================] - 3s 45us/step - loss: 0.3419 - mean_squared_error: 0.1720 - val_loss: 0.3467 - val_mean_squared_error: 0.1763
# Epoch 118/150
# 57184/57184 [==============================] - 3s 46us/step - loss: 0.3418 - mean_squared_error: 0.1719 - val_loss: 0.3467 - val_mean_squared_error: 0.1771
# Epoch 119/150
# 57184/57184 [==============================] - 3s 45us/step - loss: 0.3419 - mean_squared_error: 0.1720 - val_loss: 0.3459 - val_mean_squared_error: 0.1762
# Epoch 120/150
# 57184/57184 [==============================] - 3s 45us/step - loss: 0.3418 - mean_squared_error: 0.1721 - val_loss: 0.3463 - val_mean_squared_error: 0.1762
# Epoch 121/150
# 57184/57184 [==============================] - 3s 46us/step - loss: 0.3415 - mean_squared_error: 0.1718 - val_loss: 0.3490 - val_mean_squared_error: 0.1794
# Epoch 122/150
# 57184/57184 [==============================] - 3s 47us/step - loss: 0.3414 - mean_squared_error: 0.1719 - val_loss: 0.3443 - val_mean_squared_error: 0.1749
# Epoch 123/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.3414 - mean_squared_error: 0.1719 - val_loss: 0.3490 - val_mean_squared_error: 0.1790
# Epoch 124/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.3416 - mean_squared_error: 0.1721 - val_loss: 0.3465 - val_mean_squared_error: 0.1772
# Epoch 125/150
# 57184/57184 [==============================] - 3s 48us/step - loss: 0.3414 - mean_squared_error: 0.1721 - val_loss: 0.3451 - val_mean_squared_error: 0.1754
# Epoch 126/150
# 57184/57184 [==============================] - 3s 46us/step - loss: 0.3412 - mean_squared_error: 0.1718 - val_loss: 0.3451 - val_mean_squared_error: 0.1758
# Epoch 127/150
# 57184/57184 [==============================] - 3s 46us/step - loss: 0.3412 - mean_squared_error: 0.1720 - val_loss: 0.3453 - val_mean_squared_error: 0.1765
# Epoch 128/150
# 57184/57184 [==============================] - 3s 45us/step - loss: 0.3411 - mean_squared_error: 0.1719 - val_loss: 0.3443 - val_mean_squared_error: 0.1755
# Epoch 129/150
# 57184/57184 [==============================] - 3s 52us/step - loss: 0.3412 - mean_squared_error: 0.1721 - val_loss: 0.3451 - val_mean_squared_error: 0.1753
# Epoch 130/150
# 57184/57184 [==============================] - 3s 47us/step - loss: 0.3408 - mean_squared_error: 0.1718 - val_loss: 0.3458 - val_mean_squared_error: 0.1770
# Epoch 131/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.3406 - mean_squared_error: 0.1718 - val_loss: 0.3463 - val_mean_squared_error: 0.1775
# Epoch 132/150
# 57184/57184 [==============================] - 3s 47us/step - loss: 0.3406 - mean_squared_error: 0.1717 - val_loss: 0.3452 - val_mean_squared_error: 0.1758
# Epoch 133/150
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.3409 - mean_squared_error: 0.1721 - val_loss: 0.3451 - val_mean_squared_error: 0.1761
# Epoch 134/150
# 57184/57184 [==============================] - 3s 54us/step - loss: 0.3403 - mean_squared_error: 0.1715 - val_loss: 0.3442 - val_mean_squared_error: 0.1757
# Epoch 135/150
# 57184/57184 [==============================] - 3s 51us/step - loss: 0.3404 - mean_squared_error: 0.1718 - val_loss: 0.3454 - val_mean_squared_error: 0.1766
# Epoch 136/150
# 57184/57184 [==============================] - 3s 48us/step - loss: 0.3404 - mean_squared_error: 0.1719 - val_loss: 0.3434 - val_mean_squared_error: 0.1752
# Epoch 137/150
# 57184/57184 [==============================] - 3s 46us/step - loss: 0.3404 - mean_squared_error: 0.1719 - val_loss: 0.3426 - val_mean_squared_error: 0.1743
# Epoch 138/150
# 57184/57184 [==============================] - 3s 47us/step - loss: 0.3402 - mean_squared_error: 0.1718 - val_loss: 0.3466 - val_mean_squared_error: 0.1780
# Epoch 139/150
# 57184/57184 [==============================] - 3s 46us/step - loss: 0.3401 - mean_squared_error: 0.1717 - val_loss: 0.3434 - val_mean_squared_error: 0.1754
# Epoch 140/150
# 57184/57184 [==============================] - 3s 47us/step - loss: 0.3398 - mean_squared_error: 0.1717 - val_loss: 0.3438 - val_mean_squared_error: 0.1755
# Epoch 141/150
# 57184/57184 [==============================] - 3s 47us/step - loss: 0.3399 - mean_squared_error: 0.1718 - val_loss: 0.3441 - val_mean_squared_error: 0.1755
# Epoch 142/150
# 57184/57184 [==============================] - 3s 46us/step - loss: 0.3398 - mean_squared_error: 0.1717 - val_loss: 0.3436 - val_mean_squared_error: 0.1756
# Epoch 143/150
# 57184/57184 [==============================] - 3s 47us/step - loss: 0.3403 - mean_squared_error: 0.1724 - val_loss: 0.3425 - val_mean_squared_error: 0.1748 - mean_squared_err
# Epoch 144/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.3395 - mean_squared_error: 0.1717 - val_loss: 0.3443 - val_mean_squared_error: 0.1763
# Epoch 145/150
# 57184/57184 [==============================] - 3s 51us/step - loss: 0.3395 - mean_squared_error: 0.1718 - val_loss: 0.3443 - val_mean_squared_error: 0.1768
# Epoch 146/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.3397 - mean_squared_error: 0.1721 - val_loss: 0.3430 - val_mean_squared_error: 0.1753
# Epoch 147/150
# 57184/57184 [==============================] - 3s 48us/step - loss: 0.3394 - mean_squared_error: 0.1720 - val_loss: 0.3438 - val_mean_squared_error: 0.1761
# Epoch 148/150
# 57184/57184 [==============================] - 3s 51us/step - loss: 0.3392 - mean_squared_error: 0.1720 - val_loss: 0.3432 - val_mean_squared_error: 0.1763
# Epoch 149/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.3386 - mean_squared_error: 0.1715 - val_loss: 0.3430 - val_mean_squared_error: 0.1762
# Epoch 150/150
# 57184/57184 [==============================] - 3s 52us/step - loss: 0.3387 - mean_squared_error: 0.1717 - val_loss: 0.3439 - val_mean_squared_error: 0.1771
# Time taken to run: 7.3 minutes

# %%
# Evaluating the model
nn_model_evaluation(nn3, skip_epochs=2)
# Out:
# Training MSE: 0.1722
# Validation MSE: 0.1688
#
# Training r2: 0.7072
# Validation r2: 0.7106

# %% [markdown]
# This NN has performed better than the previous model, and about as well as the XGBoost model. It has also removed the overfitting issue, as train and test sets are performing the same. However, for some reason y values less than 3 are not being predicted.
#
# Now that bias has been reduced, further iterations will attempt to increase accuracy.

# %% [markdown]
# ### Model 4: neural network with SGD optimizer

# %% [markdown]
# This NN is mostly the same as model 3, but uses an SGD (stochastic gradient descent) optimizer instead of Adam.

# %%
# Building the model
nn4 = models.Sequential()
nn4.add(layers.Dense(128, input_shape=(X_train.shape[1],), kernel_regularizer=regularizers.l1(0.005), activation='relu'))
nn4.add(layers.Dense(256, kernel_regularizer=regularizers.l1(0.005), activation='relu'))
nn4.add(layers.Dense(256, kernel_regularizer=regularizers.l1(0.005), activation='relu'))
nn4.add(layers.Dense(512, kernel_regularizer=regularizers.l1(0.005), activation='relu'))
nn4.add(layers.Dense(1, activation='linear'))

# Compiling the model
nn4.compile(loss='mean_squared_error',
            optimizer='SGD',
            metrics=['mean_squared_error'])

# Model summary
print(nn4.summary())

# Visualising the neural network
SVG(model_to_dot(nn4, show_layer_names=False, show_shapes=True).create(prog='dot', format='svg'))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 128)               14336
# _________________________________________________________________
# dense_11 (Dense)             (None, 256)               33024
# _________________________________________________________________
# dense_12 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_13 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 245,249
# Trainable params: 245,249
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Training the model
nn4_start = time.time()

nn4_history = nn4.fit(X_train,
                  y_train,
                  epochs=150,
                  batch_size=256,
                  validation_split = 0.1)

nn4_end = time.time()

print(f"Time taken to run: {round((nn4_end - nn4_start)/60,1)} minutes")
# Out:
# Train on 57184 samples, validate on 6354 samples
# Epoch 1/150
# 57184/57184 [==============================] - 3s 59us/step - loss: 56.5765 - mean_squared_error: 0.5328 - val_loss: 49.9538 - val_mean_squared_error: 0.2510
# Epoch 2/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 44.1913 - mean_squared_error: 0.2275 - val_loss: 38.6160 - val_mean_squared_error: 0.2140
# Epoch 3/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 33.6285 - mean_squared_error: 0.2008 - val_loss: 28.8400 - val_mean_squared_error: 0.1963
# Epoch 4/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 24.6174 - mean_squared_error: 0.1877 - val_loss: 20.6046 - val_mean_squared_error: 0.1911
# Epoch 5/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 17.1403 - mean_squared_error: 0.1815 - val_loss: 13.9030 - val_mean_squared_error: 0.1858
# Epoch 6/150
# 57184/57184 [==============================] - 3s 47us/step - loss: 11.2163 - mean_squared_error: 0.1808 - val_loss: 8.7617 - val_mean_squared_error: 0.1851
# Epoch 7/150
# 57184/57184 [==============================] - 3s 46us/step - loss: 6.8448 - mean_squared_error: 0.1834 - val_loss: 5.1603 - val_mean_squared_error: 0.1884
# Epoch 8/150
# 57184/57184 [==============================] - 3s 46us/step - loss: 3.9717 - mean_squared_error: 0.1853 - val_loss: 3.0054 - val_mean_squared_error: 0.1899
# Epoch 9/150
# 57184/57184 [==============================] - 3s 44us/step - loss: 2.3423 - mean_squared_error: 0.1856 - val_loss: 1.7804 - val_mean_squared_error: 0.1909
# Epoch 10/150
# 57184/57184 [==============================] - 3s 52us/step - loss: 1.4065 - mean_squared_error: 0.1859 - val_loss: 1.1177 - val_mean_squared_error: 0.1901
# Epoch 11/150
# 57184/57184 [==============================] - 3s 46us/step - loss: 0.9210 - mean_squared_error: 0.1860 - val_loss: 0.7657 - val_mean_squared_error: 0.1890
# Epoch 12/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.6614 - mean_squared_error: 0.1860 - val_loss: 0.5785 - val_mean_squared_error: 0.1904
# Epoch 13/150
# 57184/57184 [==============================] - 3s 54us/step - loss: 0.5121 - mean_squared_error: 0.1856 - val_loss: 0.4621 - val_mean_squared_error: 0.1882
# Epoch 14/150
# 57184/57184 [==============================] - 3s 51us/step - loss: 0.4235 - mean_squared_error: 0.1845 - val_loss: 0.3987 - val_mean_squared_error: 0.1868
# Epoch 15/150
# 57184/57184 [==============================] - 3s 54us/step - loss: 0.3792 - mean_squared_error: 0.1828 - val_loss: 0.3717 - val_mean_squared_error: 0.1862
# Epoch 16/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.3561 - mean_squared_error: 0.1808 - val_loss: 0.3529 - val_mean_squared_error: 0.1839
# Epoch 17/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.3408 - mean_squared_error: 0.1791 - val_loss: 0.3372 - val_mean_squared_error: 0.1807
# Epoch 18/150
# 57184/57184 [==============================] - 2s 43us/step - loss: 0.3292 - mean_squared_error: 0.1775 - val_loss: 0.3330 - val_mean_squared_error: 0.1842
# Epoch 19/150
# 57184/57184 [==============================] - 3s 51us/step - loss: 0.3204 - mean_squared_error: 0.1766 - val_loss: 0.3185 - val_mean_squared_error: 0.1784
# Epoch 20/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.3126 - mean_squared_error: 0.1756 - val_loss: 0.3118 - val_mean_squared_error: 0.1781
# Epoch 21/150
# 57184/57184 [==============================] - 3s 48us/step - loss: 0.3059 - mean_squared_error: 0.1751 - val_loss: 0.3086 - val_mean_squared_error: 0.1797
# Epoch 22/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.2999 - mean_squared_error: 0.1746 - val_loss: 0.3000 - val_mean_squared_error: 0.1773
# Epoch 23/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.2946 - mean_squared_error: 0.1743 - val_loss: 0.2956 - val_mean_squared_error: 0.1769
# Epoch 24/150
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.2902 - mean_squared_error: 0.1740 - val_loss: 0.2919 - val_mean_squared_error: 0.1775
# Epoch 25/150
# 57184/57184 [==============================] - 3s 54us/step - loss: 0.2860 - mean_squared_error: 0.1735 - val_loss: 0.2874 - val_mean_squared_error: 0.1771
# Epoch 26/150
# 57184/57184 [==============================] - 3s 54us/step - loss: 0.2821 - mean_squared_error: 0.1730 - val_loss: 0.2842 - val_mean_squared_error: 0.1763
# Epoch 27/150
# 57184/57184 [==============================] - 3s 51us/step - loss: 0.2789 - mean_squared_error: 0.1727 - val_loss: 0.2815 - val_mean_squared_error: 0.1764
# Epoch 28/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.2762 - mean_squared_error: 0.1725 - val_loss: 0.2782 - val_mean_squared_error: 0.1755
# Epoch 29/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2737 - mean_squared_error: 0.1722 - val_loss: 0.2767 - val_mean_squared_error: 0.1761
# Epoch 30/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2714 - mean_squared_error: 0.1721 - val_loss: 0.2743 - val_mean_squared_error: 0.1758
# Epoch 31/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2690 - mean_squared_error: 0.1719 - val_loss: 0.2722 - val_mean_squared_error: 0.1762
# Epoch 32/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2669 - mean_squared_error: 0.1718 - val_loss: 0.2700 - val_mean_squared_error: 0.1757
# Epoch 33/150
# 57184/57184 [==============================] - 3s 48us/step - loss: 0.2649 - mean_squared_error: 0.1716 - val_loss: 0.2705 - val_mean_squared_error: 0.1780
# Epoch 34/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2632 - mean_squared_error: 0.1717 - val_loss: 0.2678 - val_mean_squared_error: 0.1768
# Epoch 35/150
# 57184/57184 [==============================] - 3s 51us/step - loss: 0.2615 - mean_squared_error: 0.1716 - val_loss: 0.2659 - val_mean_squared_error: 0.1761
# Epoch 36/150
# 57184/57184 [==============================] - 3s 54us/step - loss: 0.2602 - mean_squared_error: 0.1716 - val_loss: 0.2671 - val_mean_squared_error: 0.1785
# Epoch 37/150
# 57184/57184 [==============================] - 3s 54us/step - loss: 0.2590 - mean_squared_error: 0.1717 - val_loss: 0.2622 - val_mean_squared_error: 0.1753
# Epoch 38/150
# 57184/57184 [==============================] - 3s 51us/step - loss: 0.2576 - mean_squared_error: 0.1713 - val_loss: 0.2617 - val_mean_squared_error: 0.1760
# Epoch 39/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.2567 - mean_squared_error: 0.1713 - val_loss: 0.2633 - val_mean_squared_error: 0.1776
# Epoch 40/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2559 - mean_squared_error: 0.1713 - val_loss: 0.2600 - val_mean_squared_error: 0.1759
# Epoch 41/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2551 - mean_squared_error: 0.1713 - val_loss: 0.2589 - val_mean_squared_error: 0.1753
# Epoch 42/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2543 - mean_squared_error: 0.1714 - val_loss: 0.2629 - val_mean_squared_error: 0.1795
# Epoch 43/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2534 - mean_squared_error: 0.1712 - val_loss: 0.2575 - val_mean_squared_error: 0.1758
# Epoch 44/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2527 - mean_squared_error: 0.1713 - val_loss: 0.2570 - val_mean_squared_error: 0.1757
# Epoch 45/150
# 57184/57184 [==============================] - 3s 51us/step - loss: 0.2521 - mean_squared_error: 0.1712 - val_loss: 0.2570 - val_mean_squared_error: 0.1767
# Epoch 46/150
# 57184/57184 [==============================] - 3s 56us/step - loss: 0.2513 - mean_squared_error: 0.1712 - val_loss: 0.2555 - val_mean_squared_error: 0.1757
# Epoch 47/150
# 57184/57184 [==============================] - 3s 56us/step - loss: 0.2509 - mean_squared_error: 0.1714 - val_loss: 0.2541 - val_mean_squared_error: 0.1748
# Epoch 48/150
# 57184/57184 [==============================] - 3s 51us/step - loss: 0.2503 - mean_squared_error: 0.1713 - val_loss: 0.2559 - val_mean_squared_error: 0.1770
# Epoch 49/150
# 57184/57184 [==============================] - 3s 58us/step - loss: 0.2497 - mean_squared_error: 0.1712 - val_loss: 0.2536 - val_mean_squared_error: 0.1754
# Epoch 50/150
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.2492 - mean_squared_error: 0.1712 - val_loss: 0.2573 - val_mean_squared_error: 0.1787
# Epoch 51/150
# 57184/57184 [==============================] - 3s 59us/step - loss: 0.2489 - mean_squared_error: 0.1713 - val_loss: 0.2549 - val_mean_squared_error: 0.1773
# Epoch 52/150
# 57184/57184 [==============================] - 4s 62us/step - loss: 0.2487 - mean_squared_error: 0.1714 - val_loss: 0.2543 - val_mean_squared_error: 0.1768
# Epoch 53/150
# 57184/57184 [==============================] - 3s 58us/step - loss: 0.2484 - mean_squared_error: 0.1715 - val_loss: 0.2520 - val_mean_squared_error: 0.1753
# Epoch 54/150
# 57184/57184 [==============================] - 3s 44us/step - loss: 0.2480 - mean_squared_error: 0.1715 - val_loss: 0.2553 - val_mean_squared_error: 0.1777
# Epoch 55/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.2478 - mean_squared_error: 0.1716 - val_loss: 0.2533 - val_mean_squared_error: 0.1772
# Epoch 56/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.2476 - mean_squared_error: 0.1717 - val_loss: 0.2516 - val_mean_squared_error: 0.1758
# Epoch 57/150
# 57184/57184 [==============================] - 3s 57us/step - loss: 0.2472 - mean_squared_error: 0.1716 - val_loss: 0.2516 - val_mean_squared_error: 0.1762
# Epoch 58/150
# 57184/57184 [==============================] - 3s 54us/step - loss: 0.2470 - mean_squared_error: 0.1717 - val_loss: 0.2518 - val_mean_squared_error: 0.1762
# Epoch 59/150
# 57184/57184 [==============================] - 3s 54us/step - loss: 0.2466 - mean_squared_error: 0.1715 - val_loss: 0.2509 - val_mean_squared_error: 0.1759
# Epoch 60/150
# 57184/57184 [==============================] - 3s 52us/step - loss: 0.2465 - mean_squared_error: 0.1716 - val_loss: 0.2505 - val_mean_squared_error: 0.1759
# Epoch 61/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.2464 - mean_squared_error: 0.1718 - val_loss: 0.2507 - val_mean_squared_error: 0.1763
# Epoch 62/150
# 57184/57184 [==============================] - 3s 54us/step - loss: 0.2462 - mean_squared_error: 0.1718 - val_loss: 0.2550 - val_mean_squared_error: 0.1797
# Epoch 63/150
# 57184/57184 [==============================] - 3s 51us/step - loss: 0.2460 - mean_squared_error: 0.1718 - val_loss: 0.2503 - val_mean_squared_error: 0.17602461 - mean_squared
# Epoch 64/150
# 57184/57184 [==============================] - 3s 51us/step - loss: 0.2456 - mean_squared_error: 0.1716 - val_loss: 0.2531 - val_mean_squared_error: 0.1787
# Epoch 65/150
# 57184/57184 [==============================] - 3s 51us/step - loss: 0.2455 - mean_squared_error: 0.1717 - val_loss: 0.2488 - val_mean_squared_error: 0.1751
# Epoch 66/150
# 57184/57184 [==============================] - 3s 52us/step - loss: 0.2451 - mean_squared_error: 0.1716 - val_loss: 0.2491 - val_mean_squared_error: 0.1754
# Epoch 67/150
# 57184/57184 [==============================] - 3s 56us/step - loss: 0.2451 - mean_squared_error: 0.1719 - val_loss: 0.2512 - val_mean_squared_error: 0.1772
# Epoch 68/150
# 57184/57184 [==============================] - 3s 59us/step - loss: 0.2452 - mean_squared_error: 0.1721 - val_loss: 0.2490 - val_mean_squared_error: 0.1759
# Epoch 69/150
# 57184/57184 [==============================] - 3s 54us/step - loss: 0.2446 - mean_squared_error: 0.1717 - val_loss: 0.2488 - val_mean_squared_error: 0.1762
# Epoch 70/150
# 57184/57184 [==============================] - 3s 51us/step - loss: 0.2445 - mean_squared_error: 0.1720 - val_loss: 0.2506 - val_mean_squared_error: 0.1780
# Epoch 71/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2443 - mean_squared_error: 0.1719 - val_loss: 0.2491 - val_mean_squared_error: 0.1765
# Epoch 72/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2438 - mean_squared_error: 0.1717 - val_loss: 0.2512 - val_mean_squared_error: 0.1789- loss: 0.2438 - mean_squ
# Epoch 73/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.2436 - mean_squared_error: 0.1717 - val_loss: 0.2482 - val_mean_squared_error: 0.1764
# Epoch 74/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.2433 - mean_squared_error: 0.1716 - val_loss: 0.2477 - val_mean_squared_error: 0.1761
# Epoch 75/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.2435 - mean_squared_error: 0.1720 - val_loss: 0.2467 - val_mean_squared_error: 0.1749
# Epoch 76/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.2432 - mean_squared_error: 0.1718 - val_loss: 0.2463 - val_mean_squared_error: 0.1750
# Epoch 77/150
# 57184/57184 [==============================] - 3s 52us/step - loss: 0.2429 - mean_squared_error: 0.1719 - val_loss: 0.2501 - val_mean_squared_error: 0.1788
# Epoch 78/150
# 57184/57184 [==============================] - 4s 70us/step - loss: 0.2427 - mean_squared_error: 0.1718 - val_loss: 0.2463 - val_mean_squared_error: 0.1757ss: 0.2423 - me
# Epoch 79/150
# 57184/57184 [==============================] - 4s 65us/step - loss: 0.2423 - mean_squared_error: 0.1716 - val_loss: 0.2451 - val_mean_squared_error: 0.1749
# Epoch 80/150
# 57184/57184 [==============================] - 4s 61us/step - loss: 0.2422 - mean_squared_error: 0.1717 - val_loss: 0.2461 - val_mean_squared_error: 0.1758
# Epoch 81/150
# 57184/57184 [==============================] - 3s 52us/step - loss: 0.2419 - mean_squared_error: 0.1716 - val_loss: 0.2519 - val_mean_squared_error: 0.1806
# Epoch 82/150
# 57184/57184 [==============================] - 2s 43us/step - loss: 0.2417 - mean_squared_error: 0.1717 - val_loss: 0.2456 - val_mean_squared_error: 0.1752
# Epoch 83/150
# 57184/57184 [==============================] - 2s 44us/step - loss: 0.2413 - mean_squared_error: 0.1715 - val_loss: 0.2488 - val_mean_squared_error: 0.1784
# Epoch 84/150
# 57184/57184 [==============================] - 3s 45us/step - loss: 0.2415 - mean_squared_error: 0.1717 - val_loss: 0.2465 - val_mean_squared_error: 0.1769
# Epoch 85/150
# 57184/57184 [==============================] - 3s 51us/step - loss: 0.2415 - mean_squared_error: 0.1719 - val_loss: 0.2467 - val_mean_squared_error: 0.1771
# Epoch 86/150
# 57184/57184 [==============================] - 3s 59us/step - loss: 0.2412 - mean_squared_error: 0.1718 - val_loss: 0.2455 - val_mean_squared_error: 0.1762
# Epoch 87/150
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.2411 - mean_squared_error: 0.1718 - val_loss: 0.2486 - val_mean_squared_error: 0.1788
# Epoch 88/150
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.2411 - mean_squared_error: 0.1719 - val_loss: 0.2460 - val_mean_squared_error: 0.1767
# Epoch 89/150
# 57184/57184 [==============================] - 3s 52us/step - loss: 0.2407 - mean_squared_error: 0.1717 - val_loss: 0.2450 - val_mean_squared_error: 0.1762
# Epoch 90/150
# 57184/57184 [==============================] - 3s 51us/step - loss: 0.2405 - mean_squared_error: 0.1717 - val_loss: 0.2471 - val_mean_squared_error: 0.1779
# Epoch 91/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2404 - mean_squared_error: 0.1718 - val_loss: 0.2443 - val_mean_squared_error: 0.1758
# Epoch 92/150
# 57184/57184 [==============================] - 3s 48us/step - loss: 0.2406 - mean_squared_error: 0.1721 - val_loss: 0.2495 - val_mean_squared_error: 0.1809
# Epoch 93/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2401 - mean_squared_error: 0.1717 - val_loss: 0.2441 - val_mean_squared_error: 0.1759
# Epoch 94/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2398 - mean_squared_error: 0.1717 - val_loss: 0.2491 - val_mean_squared_error: 0.1805
# Epoch 95/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2399 - mean_squared_error: 0.1719 - val_loss: 0.2440 - val_mean_squared_error: 0.1759
# Epoch 96/150
# 57184/57184 [==============================] - 3s 51us/step - loss: 0.2397 - mean_squared_error: 0.1719 - val_loss: 0.2484 - val_mean_squared_error: 0.1799
# Epoch 97/150
# 57184/57184 [==============================] - 3s 55us/step - loss: 0.2394 - mean_squared_error: 0.1717 - val_loss: 0.2438 - val_mean_squared_error: 0.1766
# Epoch 98/150
# 57184/57184 [==============================] - 3s 59us/step - loss: 0.2393 - mean_squared_error: 0.1718 - val_loss: 0.2419 - val_mean_squared_error: 0.1748
# Epoch 99/150
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.2391 - mean_squared_error: 0.1718 - val_loss: 0.2442 - val_mean_squared_error: 0.1765
# Epoch 100/150
# 57184/57184 [==============================] - 3s 54us/step - loss: 0.2389 - mean_squared_error: 0.1717 - val_loss: 0.2473 - val_mean_squared_error: 0.1795
# Epoch 101/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.2389 - mean_squared_error: 0.1719 - val_loss: 0.2431 - val_mean_squared_error: 0.1762
# Epoch 102/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.2387 - mean_squared_error: 0.1719 - val_loss: 0.2425 - val_mean_squared_error: 0.1759
# Epoch 103/150
# 57184/57184 [==============================] - 3s 51us/step - loss: 0.2387 - mean_squared_error: 0.1721 - val_loss: 0.2451 - val_mean_squared_error: 0.1786
# Epoch 104/150
# 57184/57184 [==============================] - 3s 52us/step - loss: 0.2386 - mean_squared_error: 0.1721 - val_loss: 0.2422 - val_mean_squared_error: 0.1759
# Epoch 105/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.2380 - mean_squared_error: 0.1718 - val_loss: 0.2410 - val_mean_squared_error: 0.1748
# Epoch 106/150
# 57184/57184 [==============================] - 3s 52us/step - loss: 0.2379 - mean_squared_error: 0.1717 - val_loss: 0.2429 - val_mean_squared_error: 0.1767
# Epoch 107/150
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.2381 - mean_squared_error: 0.1720 - val_loss: 0.2420 - val_mean_squared_error: 0.1758
# Epoch 108/150
# 57184/57184 [==============================] - 3s 52us/step - loss: 0.2376 - mean_squared_error: 0.1717 - val_loss: 0.2434 - val_mean_squared_error: 0.1773
# Epoch 109/150
# 57184/57184 [==============================] - 3s 51us/step - loss: 0.2374 - mean_squared_error: 0.1717 - val_loss: 0.2446 - val_mean_squared_error: 0.1790
# Epoch 110/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.2377 - mean_squared_error: 0.1722 - val_loss: 0.2418 - val_mean_squared_error: 0.1763
# Epoch 111/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.2373 - mean_squared_error: 0.1719 - val_loss: 0.2442 - val_mean_squared_error: 0.1784
# Epoch 112/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2373 - mean_squared_error: 0.1720 - val_loss: 0.2418 - val_mean_squared_error: 0.1768
# Epoch 113/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.2370 - mean_squared_error: 0.1719 - val_loss: 0.2411 - val_mean_squared_error: 0.1759
# Epoch 114/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2371 - mean_squared_error: 0.1721 - val_loss: 0.2401 - val_mean_squared_error: 0.1753
# Epoch 115/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.2368 - mean_squared_error: 0.1719 - val_loss: 0.2420 - val_mean_squared_error: 0.1765
# Epoch 116/150
# 57184/57184 [==============================] - 3s 51us/step - loss: 0.2367 - mean_squared_error: 0.1719 - val_loss: 0.2426 - val_mean_squared_error: 0.1776
# Epoch 117/150
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.2368 - mean_squared_error: 0.1721 - val_loss: 0.2413 - val_mean_squared_error: 0.1767
# Epoch 118/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.2367 - mean_squared_error: 0.1721 - val_loss: 0.2440 - val_mean_squared_error: 0.1792
# Epoch 119/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2366 - mean_squared_error: 0.1722 - val_loss: 0.2438 - val_mean_squared_error: 0.1791
# Epoch 120/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.2366 - mean_squared_error: 0.1723 - val_loss: 0.2406 - val_mean_squared_error: 0.1761
# Epoch 121/150
# 57184/57184 [==============================] - 3s 52us/step - loss: 0.2362 - mean_squared_error: 0.1720 - val_loss: 0.2402 - val_mean_squared_error: 0.1762
# Epoch 122/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2360 - mean_squared_error: 0.1720 - val_loss: 0.2418 - val_mean_squared_error: 0.1778
# Epoch 123/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2360 - mean_squared_error: 0.1722 - val_loss: 0.2395 - val_mean_squared_error: 0.1756
# Epoch 124/150
# 57184/57184 [==============================] - 3s 48us/step - loss: 0.2358 - mean_squared_error: 0.1720 - val_loss: 0.2387 - val_mean_squared_error: 0.1753
# Epoch 125/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.2358 - mean_squared_error: 0.1721 - val_loss: 0.2406 - val_mean_squared_error: 0.1771
# Epoch 126/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.2356 - mean_squared_error: 0.1722 - val_loss: 0.2401 - val_mean_squared_error: 0.1764
# Epoch 127/150
# 57184/57184 [==============================] - 3s 52us/step - loss: 0.2353 - mean_squared_error: 0.1719 - val_loss: 0.2398 - val_mean_squared_error: 0.1765
# Epoch 128/150
# 57184/57184 [==============================] - 3s 51us/step - loss: 0.2352 - mean_squared_error: 0.1720 - val_loss: 0.2387 - val_mean_squared_error: 0.1756
# Epoch 129/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.2355 - mean_squared_error: 0.1724 - val_loss: 0.2428 - val_mean_squared_error: 0.1792
# Epoch 130/150
# 57184/57184 [==============================] - 3s 48us/step - loss: 0.2351 - mean_squared_error: 0.1721 - val_loss: 0.2409 - val_mean_squared_error: 0.1780
# Epoch 131/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2352 - mean_squared_error: 0.1723 - val_loss: 0.2386 - val_mean_squared_error: 0.1758
# Epoch 132/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2349 - mean_squared_error: 0.1722 - val_loss: 0.2381 - val_mean_squared_error: 0.1752
# Epoch 133/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2348 - mean_squared_error: 0.1721 - val_loss: 0.2413 - val_mean_squared_error: 0.1787
# Epoch 134/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2349 - mean_squared_error: 0.1723 - val_loss: 0.2392 - val_mean_squared_error: 0.1768
# Epoch 135/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2347 - mean_squared_error: 0.1723 - val_loss: 0.2385 - val_mean_squared_error: 0.1760
# Epoch 136/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.2351 - mean_squared_error: 0.1728 - val_loss: 0.2392 - val_mean_squared_error: 0.1769
# Epoch 137/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.2350 - mean_squared_error: 0.1728 - val_loss: 0.2405 - val_mean_squared_error: 0.1783
# Epoch 138/150
# 57184/57184 [==============================] - 3s 57us/step - loss: 0.2347 - mean_squared_error: 0.1725 - val_loss: 0.2381 - val_mean_squared_error: 0.1762
# Epoch 139/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.2344 - mean_squared_error: 0.1724 - val_loss: 0.2388 - val_mean_squared_error: 0.1768
# Epoch 140/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2343 - mean_squared_error: 0.1725 - val_loss: 0.2371 - val_mean_squared_error: 0.1753
# Epoch 141/150
# 57184/57184 [==============================] - 3s 48us/step - loss: 0.2342 - mean_squared_error: 0.1725 - val_loss: 0.2460 - val_mean_squared_error: 0.1836
# Epoch 142/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2342 - mean_squared_error: 0.1726 - val_loss: 0.2367 - val_mean_squared_error: 0.1753
# Epoch 143/150
# 57184/57184 [==============================] - 3s 48us/step - loss: 0.2340 - mean_squared_error: 0.1725 - val_loss: 0.2432 - val_mean_squared_error: 0.1813
# Epoch 144/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2341 - mean_squared_error: 0.1728 - val_loss: 0.2374 - val_mean_squared_error: 0.1764
# Epoch 145/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2338 - mean_squared_error: 0.1727 - val_loss: 0.2372 - val_mean_squared_error: 0.1760
# Epoch 146/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.2335 - mean_squared_error: 0.1725 - val_loss: 0.2425 - val_mean_squared_error: 0.1813
# Epoch 147/150
# 57184/57184 [==============================] - 3s 51us/step - loss: 0.2334 - mean_squared_error: 0.1725 - val_loss: 0.2392 - val_mean_squared_error: 0.1787
# Epoch 148/150
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.2333 - mean_squared_error: 0.1727 - val_loss: 0.2382 - val_mean_squared_error: 0.1775
# Epoch 149/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2336 - mean_squared_error: 0.1730 - val_loss: 0.2389 - val_mean_squared_error: 0.1784
# Epoch 150/150
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2332 - mean_squared_error: 0.1728 - val_loss: 0.2386 - val_mean_squared_error: 0.1783
# Time taken to run: 7.3 minutes

# %%
nn_model_evaluation(nn4, skip_epochs=10) # This model took several epochs before the loss was in a similar range to other models
# Out:
# Training MSE: 0.1739
# Validation MSE: 0.1705
#
# Training r2: 0.7043
# Validation r2: 0.7077

# %% [markdown]
# The SGD optimizer performs slightly worse than the Adam optimizer. Also, y values less than 3 are still not being predicted.

# %% [markdown]
# ### Model 5: neural network with dropout regularization at 50%

# %% [markdown]
# This model will be similar to Model 3, but will use dropout regularization instead. A dropout rate of 50% will be used. The number of epochs will be reduced to 50 as it does not seem to take as many as 150 epochs to reach optimum loss minimisation.

# %%
# Building the model
nn5 = models.Sequential()
nn5.add(layers.Dropout(0.5, input_shape=(X_train.shape[1],)))
nn5.add(layers.Dense(128, activation='relu'))
nn5.add(layers.Dropout(0.5))
nn5.add(layers.Dense(256, activation='relu'))
nn5.add(layers.Dropout(0.5))
nn5.add(layers.Dense(512, activation='relu'))
nn5.add(layers.Dropout(0.5))
nn5.add(layers.Dense(1, activation='linear'))

# Compiling the model
nn5.compile(loss='mean_squared_error',
            optimizer='adam',
            metrics=['mean_squared_error'])

# Model summary
print(nn5.summary())

# Visualising the neural network
SVG(model_to_dot(nn5, show_layer_names=False, show_shapes=True).create(prog='dot', format='svg'))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dropout_1 (Dropout)          (None, 111)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 128)               14336
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 256)               33024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 179,457
# Trainable params: 179,457
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Training the model
nn5_start = time.time()

nn5_history = nn5.fit(X_train,
                  y_train,
                  epochs=50,
                  batch_size=256,
                  validation_split = 0.1)

nn5_end = time.time()

print(f"Time taken to run: {round((nn5_end - nn5_start)/60,1)} minutes")
# Out:
# Train on 57184 samples, validate on 6354 samples
# Epoch 1/50
# 57184/57184 [==============================] - 4s 76us/step - loss: 1.9185 - mean_squared_error: 1.9185 - val_loss: 6.3212 - val_mean_squared_error: 6.3212
# Epoch 2/50
# 57184/57184 [==============================] - 4s 62us/step - loss: 0.8858 - mean_squared_error: 0.8858 - val_loss: 4.0273 - val_mean_squared_error: 4.0273
# Epoch 3/50
# 57184/57184 [==============================] - 3s 60us/step - loss: 0.6477 - mean_squared_error: 0.6477 - val_loss: 1.9192 - val_mean_squared_error: 1.9192
# Epoch 4/50
# 57184/57184 [==============================] - 3s 57us/step - loss: 0.5274 - mean_squared_error: 0.5274 - val_loss: 0.8490 - val_mean_squared_error: 0.8490
# Epoch 5/50
# 57184/57184 [==============================] - 3s 58us/step - loss: 0.4770 - mean_squared_error: 0.4770 - val_loss: 0.6484 - val_mean_squared_error: 0.6484
# Epoch 6/50
# 57184/57184 [==============================] - 3s 56us/step - loss: 0.4504 - mean_squared_error: 0.4504 - val_loss: 0.6005 - val_mean_squared_error: 0.6005
# Epoch 7/50
# 57184/57184 [==============================] - 3s 58us/step - loss: 0.4258 - mean_squared_error: 0.4258 - val_loss: 0.5259 - val_mean_squared_error: 0.5259
# Epoch 8/50
# 57184/57184 [==============================] - 3s 58us/step - loss: 0.4151 - mean_squared_error: 0.4151 - val_loss: 0.4262 - val_mean_squared_error: 0.4262
# Epoch 9/50
# 57184/57184 [==============================] - 3s 58us/step - loss: 0.3992 - mean_squared_error: 0.3992 - val_loss: 0.4394 - val_mean_squared_error: 0.4394
# Epoch 10/50
# 57184/57184 [==============================] - 3s 58us/step - loss: 0.3894 - mean_squared_error: 0.3894 - val_loss: 0.3861 - val_mean_squared_error: 0.3861
# Epoch 11/50
# 57184/57184 [==============================] - 3s 57us/step - loss: 0.3850 - mean_squared_error: 0.3850 - val_loss: 0.3506 - val_mean_squared_error: 0.3506
# Epoch 12/50
# 57184/57184 [==============================] - 3s 56us/step - loss: 0.3776 - mean_squared_error: 0.3776 - val_loss: 0.3318 - val_mean_squared_error: 0.3318
# Epoch 13/50
# 57184/57184 [==============================] - 4s 63us/step - loss: 0.3686 - mean_squared_error: 0.3686 - val_loss: 0.3608 - val_mean_squared_error: 0.3608
# Epoch 14/50
# 57184/57184 [==============================] - 5s 82us/step - loss: 0.3658 - mean_squared_error: 0.3658 - val_loss: 0.3141 - val_mean_squared_error: 0.3141
# Epoch 15/50
# 57184/57184 [==============================] - 4s 72us/step - loss: 0.3618 - mean_squared_error: 0.3618 - val_loss: 0.3264 - val_mean_squared_error: 0.3264
# Epoch 16/50
# 57184/57184 [==============================] - 4s 65us/step - loss: 0.3551 - mean_squared_error: 0.3551 - val_loss: 0.3149 - val_mean_squared_error: 0.3149
# Epoch 17/50
# 57184/57184 [==============================] - 5s 82us/step - loss: 0.3527 - mean_squared_error: 0.3527 - val_loss: 0.2826 - val_mean_squared_error: 0.2826
# Epoch 18/50
# 57184/57184 [==============================] - 4s 68us/step - loss: 0.3500 - mean_squared_error: 0.3500 - val_loss: 0.3267 - val_mean_squared_error: 0.3267
# Epoch 19/50
# 57184/57184 [==============================] - 3s 59us/step - loss: 0.3445 - mean_squared_error: 0.3445 - val_loss: 0.2825 - val_mean_squared_error: 0.2825
# Epoch 20/50
# 57184/57184 [==============================] - 3s 60us/step - loss: 0.3416 - mean_squared_error: 0.3416 - val_loss: 0.2916 - val_mean_squared_error: 0.2916
# Epoch 21/50
# 57184/57184 [==============================] - 3s 58us/step - loss: 0.3430 - mean_squared_error: 0.3430 - val_loss: 0.3164 - val_mean_squared_error: 0.3164
# Epoch 22/50
# 57184/57184 [==============================] - 4s 63us/step - loss: 0.3393 - mean_squared_error: 0.3393 - val_loss: 0.2802 - val_mean_squared_error: 0.2802
# Epoch 23/50
# 57184/57184 [==============================] - 3s 51us/step - loss: 0.3385 - mean_squared_error: 0.3385 - val_loss: 0.2738 - val_mean_squared_error: 0.2738
# Epoch 24/50
# 57184/57184 [==============================] - 4s 66us/step - loss: 0.3316 - mean_squared_error: 0.3316 - val_loss: 0.2816 - val_mean_squared_error: 0.2816
# Epoch 25/50
# 57184/57184 [==============================] - 4s 68us/step - loss: 0.3311 - mean_squared_error: 0.3311 - val_loss: 0.2991 - val_mean_squared_error: 0.2991
# Epoch 26/50
# 57184/57184 [==============================] - 4s 67us/step - loss: 0.3253 - mean_squared_error: 0.3253 - val_loss: 0.2851 - val_mean_squared_error: 0.2851
# Epoch 27/50
# 57184/57184 [==============================] - 4s 65us/step - loss: 0.3273 - mean_squared_error: 0.3273 - val_loss: 0.3031 - val_mean_squared_error: 0.3031
# Epoch 28/50
# 57184/57184 [==============================] - 4s 68us/step - loss: 0.3210 - mean_squared_error: 0.3210 - val_loss: 0.2875 - val_mean_squared_error: 0.2875
# Epoch 29/50
# 57184/57184 [==============================] - 4s 68us/step - loss: 0.3221 - mean_squared_error: 0.3221 - val_loss: 0.3213 - val_mean_squared_error: 0.3213
# Epoch 30/50
# 57184/57184 [==============================] - 4s 73us/step - loss: 0.3215 - mean_squared_error: 0.3215 - val_loss: 0.2646 - val_mean_squared_error: 0.2646
# Epoch 31/50
# 57184/57184 [==============================] - 4s 71us/step - loss: 0.3216 - mean_squared_error: 0.3216 - val_loss: 0.2423 - val_mean_squared_error: 0.2423
# Epoch 32/50
# 57184/57184 [==============================] - 4s 65us/step - loss: 0.3200 - mean_squared_error: 0.3200 - val_loss: 0.2977 - val_mean_squared_error: 0.2977
# Epoch 33/50
# 57184/57184 [==============================] - 4s 64us/step - loss: 0.3164 - mean_squared_error: 0.3164 - val_loss: 0.2704 - val_mean_squared_error: 0.2704
# Epoch 34/50
# 57184/57184 [==============================] - 4s 63us/step - loss: 0.3105 - mean_squared_error: 0.3105 - val_loss: 0.2769 - val_mean_squared_error: 0.2769
# Epoch 35/50
# 57184/57184 [==============================] - 4s 63us/step - loss: 0.3122 - mean_squared_error: 0.3122 - val_loss: 0.2740 - val_mean_squared_error: 0.2740
# Epoch 36/50
# 57184/57184 [==============================] - 4s 65us/step - loss: 0.3124 - mean_squared_error: 0.3124 - val_loss: 0.3070 - val_mean_squared_error: 0.3070
# Epoch 37/50
# 57184/57184 [==============================] - 4s 62us/step - loss: 0.3083 - mean_squared_error: 0.3083 - val_loss: 0.2775 - val_mean_squared_error: 0.2775
# Epoch 38/50
# 57184/57184 [==============================] - 4s 62us/step - loss: 0.3074 - mean_squared_error: 0.3074 - val_loss: 0.3175 - val_mean_squared_error: 0.3175
# Epoch 39/50
# 57184/57184 [==============================] - 4s 62us/step - loss: 0.3068 - mean_squared_error: 0.3068 - val_loss: 0.2885 - val_mean_squared_error: 0.2885
# Epoch 40/50
# 57184/57184 [==============================] - 4s 66us/step - loss: 0.3075 - mean_squared_error: 0.3075 - val_loss: 0.2633 - val_mean_squared_error: 0.2633
# Epoch 41/50
# 57184/57184 [==============================] - 4s 65us/step - loss: 0.3073 - mean_squared_error: 0.3073 - val_loss: 0.2674 - val_mean_squared_error: 0.2674
# Epoch 42/50
# 57184/57184 [==============================] - 4s 65us/step - loss: 0.3057 - mean_squared_error: 0.3057 - val_loss: 0.2498 - val_mean_squared_error: 0.2498
# Epoch 43/50
# 57184/57184 [==============================] - 4s 67us/step - loss: 0.3009 - mean_squared_error: 0.3009 - val_loss: 0.2548 - val_mean_squared_error: 0.2548
# Epoch 44/50
# 57184/57184 [==============================] - 4s 69us/step - loss: 0.2986 - mean_squared_error: 0.2986 - val_loss: 0.2592 - val_mean_squared_error: 0.2592
# Epoch 45/50
# 57184/57184 [==============================] - 3s 61us/step - loss: 0.3009 - mean_squared_error: 0.3009 - val_loss: 0.2559 - val_mean_squared_error: 0.2559
# Epoch 46/50
# 57184/57184 [==============================] - 4s 62us/step - loss: 0.3008 - mean_squared_error: 0.3008 - val_loss: 0.2383 - val_mean_squared_error: 0.2383
# Epoch 47/50
# 57184/57184 [==============================] - 3s 61us/step - loss: 0.2991 - mean_squared_error: 0.2991 - val_loss: 0.2513 - val_mean_squared_error: 0.2513
# Epoch 48/50
# 57184/57184 [==============================] - 4s 62us/step - loss: 0.2981 - mean_squared_error: 0.2981 - val_loss: 0.2537 - val_mean_squared_error: 0.2537
# Epoch 49/50
# 57184/57184 [==============================] - 4s 65us/step - loss: 0.2952 - mean_squared_error: 0.2952 - val_loss: 0.2529 - val_mean_squared_error: 0.2529
# Epoch 50/50
# 57184/57184 [==============================] - 4s 67us/step - loss: 0.2950 - mean_squared_error: 0.2950 - val_loss: 0.2695 - val_mean_squared_error: 0.2695
# Time taken to run: 3.1 minutes

# %%
nn_model_evaluation(nn5, skip_epochs=2)
# Out:
# Training MSE: 0.2695
# Validation MSE: 0.2662
#
# Training r2: 0.5418
# Validation r2: 0.5436

# %% [markdown]
# Using dropout validation has reduced the model performance substantially compared to L1 regularization.

# %% [markdown]
# ### Model 6: neural network with dropout regularization at 30% and a larger batch size

# %% [markdown]
# In order to confirm that dropout regularization is not the solution, it will be tried again using a lower dropout rate (30%), and the batch size will be increased.

# %%
# Building the model
nn6 = models.Sequential()
nn6.add(layers.Dropout(0.2, input_shape=(X_train.shape[1],)))
nn6.add(layers.Dense(128, activation='relu'))
nn6.add(layers.Dropout(0.2))
nn6.add(layers.Dense(256, activation='relu'))
nn6.add(layers.Dropout(0.2))
nn6.add(layers.Dense(512, activation='relu'))
nn6.add(layers.Dropout(0.2))
nn6.add(layers.Dense(1, activation='linear'))

# Compiling the model
nn6.compile(loss='mean_squared_error',
            optimizer='adam',
            metrics=['mean_squared_error'])

# Model summary
print(nn6.summary())

# Visualising the neural network
SVG(model_to_dot(nn6, show_layer_names=False, show_shapes=True).create(prog='dot', format='svg'))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dropout_5 (Dropout)          (None, 111)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 128)               14336
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 256)               33024
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 179,457
# Trainable params: 179,457
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Training the model
nn6_start = time.time()

nn6_history = nn6.fit(X_train,
                  y_train,
                  epochs=50,
                  batch_size=512,
                  validation_split = 0.1)

nn6_end = time.time()

print(f"Time taken to run: {round((nn6_end - nn6_start)/60,1)} minutes")
# Out:
# Train on 57184 samples, validate on 6354 samples
# Epoch 1/50
# 57184/57184 [==============================] - 4s 71us/step - loss: 1.3270 - mean_squared_error: 1.3270 - val_loss: 1.0778 - val_mean_squared_error: 1.0778
# Epoch 2/50
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.4882 - mean_squared_error: 0.4882 - val_loss: 1.1237 - val_mean_squared_error: 1.1237
# Epoch 3/50
# 57184/57184 [==============================] - 3s 51us/step - loss: 0.4013 - mean_squared_error: 0.4013 - val_loss: 1.2680 - val_mean_squared_error: 1.2680
# Epoch 4/50
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.3554 - mean_squared_error: 0.3554 - val_loss: 1.1385 - val_mean_squared_error: 1.1385
# Epoch 5/50
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.3264 - mean_squared_error: 0.3264 - val_loss: 1.1896 - val_mean_squared_error: 1.1896
# Epoch 6/50
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.3087 - mean_squared_error: 0.3087 - val_loss: 1.1966 - val_mean_squared_error: 1.1966
# Epoch 7/50
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2921 - mean_squared_error: 0.2921 - val_loss: 0.7894 - val_mean_squared_error: 0.7894
# Epoch 8/50
# 57184/57184 [==============================] - 3s 47us/step - loss: 0.2786 - mean_squared_error: 0.2786 - val_loss: 0.9445 - val_mean_squared_error: 0.9445
# Epoch 9/50
# 57184/57184 [==============================] - 3s 47us/step - loss: 0.2655 - mean_squared_error: 0.2655 - val_loss: 0.6957 - val_mean_squared_error: 0.6957
# Epoch 10/50
# 57184/57184 [==============================] - 3s 47us/step - loss: 0.2580 - mean_squared_error: 0.2580 - val_loss: 0.5497 - val_mean_squared_error: 0.5497
# Epoch 11/50
# 57184/57184 [==============================] - 3s 47us/step - loss: 0.2515 - mean_squared_error: 0.2515 - val_loss: 0.5062 - val_mean_squared_error: 0.5062
# Epoch 12/50
# 57184/57184 [==============================] - 3s 45us/step - loss: 0.2471 - mean_squared_error: 0.2471 - val_loss: 0.3785 - val_mean_squared_error: 0.3785
# Epoch 13/50
# 57184/57184 [==============================] - 4s 62us/step - loss: 0.2412 - mean_squared_error: 0.2412 - val_loss: 0.4940 - val_mean_squared_error: 0.4940
# Epoch 14/50
# 57184/57184 [==============================] - 4s 65us/step - loss: 0.2365 - mean_squared_error: 0.2365 - val_loss: 0.3680 - val_mean_squared_error: 0.3680
# Epoch 15/50
# 57184/57184 [==============================] - 3s 60us/step - loss: 0.2340 - mean_squared_error: 0.2340 - val_loss: 0.3836 - val_mean_squared_error: 0.3836
# Epoch 16/50
# 57184/57184 [==============================] - 3s 55us/step - loss: 0.2310 - mean_squared_error: 0.2310 - val_loss: 0.3058 - val_mean_squared_error: 0.3058
# Epoch 17/50
# 57184/57184 [==============================] - 3s 51us/step - loss: 0.2294 - mean_squared_error: 0.2294 - val_loss: 0.3665 - val_mean_squared_error: 0.3665
# Epoch 18/50
# 57184/57184 [==============================] - 3s 48us/step - loss: 0.2279 - mean_squared_error: 0.2279 - val_loss: 0.2659 - val_mean_squared_error: 0.2659
# Epoch 19/50
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2213 - mean_squared_error: 0.2213 - val_loss: 0.2857 - val_mean_squared_error: 0.2857
# Epoch 20/50
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.2229 - mean_squared_error: 0.2229 - val_loss: 0.2461 - val_mean_squared_error: 0.2461
# Epoch 21/50
# 57184/57184 [==============================] - 3s 46us/step - loss: 0.2197 - mean_squared_error: 0.2197 - val_loss: 0.2424 - val_mean_squared_error: 0.2424
# Epoch 22/50
# 57184/57184 [==============================] - 3s 60us/step - loss: 0.2182 - mean_squared_error: 0.2182 - val_loss: 0.2654 - val_mean_squared_error: 0.2654
# Epoch 23/50
# 57184/57184 [==============================] - 3s 51us/step - loss: 0.2183 - mean_squared_error: 0.2183 - val_loss: 0.2886 - val_mean_squared_error: 0.2886
# Epoch 24/50
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.2173 - mean_squared_error: 0.2173 - val_loss: 0.2848 - val_mean_squared_error: 0.2848
# Epoch 25/50
# 57184/57184 [==============================] - 3s 51us/step - loss: 0.2151 - mean_squared_error: 0.2151 - val_loss: 0.2685 - val_mean_squared_error: 0.2685
# Epoch 26/50
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.2133 - mean_squared_error: 0.2133 - val_loss: 0.2746 - val_mean_squared_error: 0.2746
# Epoch 27/50
# 57184/57184 [==============================] - 3s 51us/step - loss: 0.2115 - mean_squared_error: 0.2115 - val_loss: 0.2772 - val_mean_squared_error: 0.2772
# Epoch 28/50
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.2109 - mean_squared_error: 0.2109 - val_loss: 0.2958 - val_mean_squared_error: 0.2958
# Epoch 29/50
# 57184/57184 [==============================] - 3s 50us/step - loss: 0.2084 - mean_squared_error: 0.2084 - val_loss: 0.2441 - val_mean_squared_error: 0.2441
# Epoch 30/50
# 57184/57184 [==============================] - 3s 49us/step - loss: 0.2097 - mean_squared_error: 0.2097 - val_loss: 0.2573 - val_mean_squared_error: 0.2573
# Epoch 31/50
# 57184/57184 [==============================] - 3s 54us/step - loss: 0.2065 - mean_squared_error: 0.2065 - val_loss: 0.2342 - val_mean_squared_error: 0.2342
# Epoch 32/50
# 57184/57184 [==============================] - 3s 58us/step - loss: 0.2052 - mean_squared_error: 0.2052 - val_loss: 0.2109 - val_mean_squared_error: 0.2109
# Epoch 33/50
# 57184/57184 [==============================] - 4s 62us/step - loss: 0.2054 - mean_squared_error: 0.2054 - val_loss: 0.2183 - val_mean_squared_error: 0.2183
# Epoch 34/50
# 57184/57184 [==============================] - 3s 60us/step - loss: 0.2035 - mean_squared_error: 0.2035 - val_loss: 0.2134 - val_mean_squared_error: 0.2134
# Epoch 35/50
# 57184/57184 [==============================] - 3s 59us/step - loss: 0.2017 - mean_squared_error: 0.2017 - val_loss: 0.2212 - val_mean_squared_error: 0.2212
# Epoch 36/50
# 57184/57184 [==============================] - 3s 58us/step - loss: 0.2034 - mean_squared_error: 0.2034 - val_loss: 0.2313 - val_mean_squared_error: 0.2313
# Epoch 37/50
# 57184/57184 [==============================] - 3s 55us/step - loss: 0.2023 - mean_squared_error: 0.2023 - val_loss: 0.1951 - val_mean_squared_error: 0.1951
# Epoch 38/50
# 57184/57184 [==============================] - 3s 55us/step - loss: 0.2015 - mean_squared_error: 0.2015 - val_loss: 0.2584 - val_mean_squared_error: 0.2584
# Epoch 39/50
# 57184/57184 [==============================] - 3s 55us/step - loss: 0.2013 - mean_squared_error: 0.2013 - val_loss: 0.2143 - val_mean_squared_error: 0.2143
# Epoch 40/50
# 57184/57184 [==============================] - 3s 55us/step - loss: 0.2018 - mean_squared_error: 0.2018 - val_loss: 0.2099 - val_mean_squared_error: 0.2099
# Epoch 41/50
# 57184/57184 [==============================] - 3s 55us/step - loss: 0.1990 - mean_squared_error: 0.1990 - val_loss: 0.1957 - val_mean_squared_error: 0.1957
# Epoch 42/50
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.1980 - mean_squared_error: 0.1980 - val_loss: 0.2026 - val_mean_squared_error: 0.2026
# Epoch 43/50
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.1984 - mean_squared_error: 0.1984 - val_loss: 0.1888 - val_mean_squared_error: 0.1888
# Epoch 44/50
# 57184/57184 [==============================] - 3s 56us/step - loss: 0.1979 - mean_squared_error: 0.1979 - val_loss: 0.2109 - val_mean_squared_error: 0.2109
# Epoch 45/50
# 57184/57184 [==============================] - 3s 55us/step - loss: 0.1967 - mean_squared_error: 0.1967 - val_loss: 0.1844 - val_mean_squared_error: 0.1844
# Epoch 46/50
# 57184/57184 [==============================] - 3s 55us/step - loss: 0.1979 - mean_squared_error: 0.1979 - val_loss: 0.2308 - val_mean_squared_error: 0.2308
# Epoch 47/50
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.1964 - mean_squared_error: 0.1964 - val_loss: 0.1949 - val_mean_squared_error: 0.1949
# Epoch 48/50
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.1944 - mean_squared_error: 0.1944 - val_loss: 0.1950 - val_mean_squared_error: 0.1950
# Epoch 49/50
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.1937 - mean_squared_error: 0.1937 - val_loss: 0.2171 - val_mean_squared_error: 0.2171
# Epoch 50/50
# 57184/57184 [==============================] - 3s 52us/step - loss: 0.1927 - mean_squared_error: 0.1927 - val_loss: 0.1910 - val_mean_squared_error: 0.1910
# Time taken to run: 2.6 minutes

# %%
nn_model_evaluation(nn6)
# Out:
# Training MSE: 0.1789
# Validation MSE: 0.1898
#
# Training r2: 0.6958
# Validation r2: 0.6746

# %% [markdown]
# Although reducing the dropout rate has improved performance compared to the previous model, it is still not as good as using L1 regularization.

# %% [markdown]
# ### Model 7: removing excess review rating features

# %% [markdown]
# So far, a number of hyperparameters have been tuned in order to increase the performance of the NN. Adding extra layers can often increase the performance of a NN, at the cost of increasing computational requirements. Before experimenting further with additional layers, it is worth going back to consider whether the best possible features are being included.
#
# In the 'Preparing the data for modeling' section above, it was noted that a lot of the review columns are reasonably highly correlated with each other. They were left in to see whether they would be useful after all. However, the feature importances graph produced by the XGBoost model suggest that they were of relatively low importance.
#
# This model will drop review columns other than the overall review rating, and use the same NN structure as Model 3, in order to see whether this produces a better model.
#
# Columns will be dropped from the existing X_train and X_test split, for consistency.

# %%
all_review = list(X_train.columns[X_train.columns.str.startswith("review_scores")])
review_to_keep = list(X_train.columns[X_train.columns.str.startswith("review_scores_rating")])
review_to_drop = [x for x in all_review if x not in review_to_keep]

X_train_short = X_train.drop(review_to_drop, axis=1)
X_test_short = X_test.drop(review_to_drop, axis=1)

# %%
# Building the model
nn7 = models.Sequential()
nn7.add(layers.Dense(128, input_shape=(X_train_short.shape[1],), kernel_regularizer=regularizers.l1(0.005), activation='relu'))
nn7.add(layers.Dense(256, kernel_regularizer=regularizers.l1(0.005), activation='relu'))
nn7.add(layers.Dense(256, kernel_regularizer=regularizers.l1(0.005), activation='relu'))
nn7.add(layers.Dense(512, kernel_regularizer=regularizers.l1(0.005), activation='relu'))
nn7.add(layers.Dense(1, activation='linear'))

# Compiling the model
nn7.compile(loss='mean_squared_error',
            optimizer='adam',
            metrics=['mean_squared_error'])

# Model summary
print(nn7.summary())

# Visualising the neural network
SVG(model_to_dot(nn7, show_layer_names=False, show_shapes=True).create(prog='dot', format='svg'))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_23 (Dense)             (None, 128)               12032
# _________________________________________________________________
# dense_24 (Dense)             (None, 256)               33024
# _________________________________________________________________
# dense_25 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_26 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_27 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 242,945
# Trainable params: 242,945
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Training the model
nn7_start = time.time()

nn7_history = nn7.fit(X_train_short,
                  y_train,
                  epochs=50,
                  batch_size=256,
                  validation_split=0.1)

nn7_end = time.time()

print(f"Time taken to run: {round((nn7_end - nn7_start)/60,1)} minutes")
# Out:
# Train on 57184 samples, validate on 6354 samples
# Epoch 1/50
# 57184/57184 [==============================] - 4s 74us/step - loss: 23.2328 - mean_squared_error: 0.5825 - val_loss: 5.4966 - val_mean_squared_error: 0.1925
# Epoch 2/50
# 57184/57184 [==============================] - 3s 54us/step - loss: 2.5492 - mean_squared_error: 0.1874 - val_loss: 1.0946 - val_mean_squared_error: 0.1975
# Epoch 3/50
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.7357 - mean_squared_error: 0.1936 - val_loss: 0.5394 - val_mean_squared_error: 0.1912
# Epoch 4/50
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.4628 - mean_squared_error: 0.1838 - val_loss: 0.4232 - val_mean_squared_error: 0.1851
# Epoch 5/50
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.4011 - mean_squared_error: 0.1793 - val_loss: 0.3936 - val_mean_squared_error: 0.1823
# Epoch 6/50
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.3865 - mean_squared_error: 0.1783 - val_loss: 0.3890 - val_mean_squared_error: 0.1846
# Epoch 7/50
# 57184/57184 [==============================] - 3s 52us/step - loss: 0.3814 - mean_squared_error: 0.1779 - val_loss: 0.3824 - val_mean_squared_error: 0.1813
# Epoch 8/50
# 57184/57184 [==============================] - 3s 55us/step - loss: 0.3764 - mean_squared_error: 0.1768 - val_loss: 0.3806 - val_mean_squared_error: 0.1823
# Epoch 9/50
# 57184/57184 [==============================] - 3s 55us/step - loss: 0.3740 - mean_squared_error: 0.1758 - val_loss: 0.3780 - val_mean_squared_error: 0.1804
# Epoch 10/50
# 57184/57184 [==============================] - 3s 56us/step - loss: 0.3709 - mean_squared_error: 0.1752 - val_loss: 0.3733 - val_mean_squared_error: 0.1801
# Epoch 11/50
# 57184/57184 [==============================] - 3s 55us/step - loss: 0.3671 - mean_squared_error: 0.1741 - val_loss: 0.3725 - val_mean_squared_error: 0.1805
# Epoch 12/50
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.3650 - mean_squared_error: 0.1737 - val_loss: 0.3695 - val_mean_squared_error: 0.1795
# Epoch 13/50
# 57184/57184 [==============================] - 3s 59us/step - loss: 0.3638 - mean_squared_error: 0.1735 - val_loss: 0.3669 - val_mean_squared_error: 0.1778
# Epoch 14/50
# 57184/57184 [==============================] - 4s 72us/step - loss: 0.3618 - mean_squared_error: 0.1732 - val_loss: 0.3664 - val_mean_squared_error: 0.1774
# Epoch 15/50
# 57184/57184 [==============================] - 4s 71us/step - loss: 0.3604 - mean_squared_error: 0.1729 - val_loss: 0.3643 - val_mean_squared_error: 0.1774
# Epoch 16/50
# 57184/57184 [==============================] - 4s 63us/step - loss: 0.3597 - mean_squared_error: 0.1728 - val_loss: 0.3641 - val_mean_squared_error: 0.1776
# Epoch 17/50
# 57184/57184 [==============================] - 4s 62us/step - loss: 0.3590 - mean_squared_error: 0.1727 - val_loss: 0.3620 - val_mean_squared_error: 0.1767
# Epoch 18/50
# 57184/57184 [==============================] - 3s 56us/step - loss: 0.3592 - mean_squared_error: 0.1727 - val_loss: 0.3635 - val_mean_squared_error: 0.1782
# Epoch 19/50
# 57184/57184 [==============================] - 3s 58us/step - loss: 0.3578 - mean_squared_error: 0.1721 - val_loss: 0.3628 - val_mean_squared_error: 0.1770
# Epoch 20/50
# 57184/57184 [==============================] - 3s 58us/step - loss: 0.3581 - mean_squared_error: 0.1722 - val_loss: 0.3627 - val_mean_squared_error: 0.1772
# Epoch 21/50
# 57184/57184 [==============================] - 3s 58us/step - loss: 0.3579 - mean_squared_error: 0.1718 - val_loss: 0.3624 - val_mean_squared_error: 0.1765
# Epoch 22/50
# 57184/57184 [==============================] - 3s 56us/step - loss: 0.3567 - mean_squared_error: 0.1713 - val_loss: 0.3620 - val_mean_squared_error: 0.1772
# Epoch 23/50
# 57184/57184 [==============================] - 4s 70us/step - loss: 0.3567 - mean_squared_error: 0.1716 - val_loss: 0.3654 - val_mean_squared_error: 0.1776
# Epoch 24/50
# 57184/57184 [==============================] - 4s 69us/step - loss: 0.3571 - mean_squared_error: 0.1715 - val_loss: 0.3615 - val_mean_squared_error: 0.1763
# Epoch 25/50
# 57184/57184 [==============================] - 3s 61us/step - loss: 0.3562 - mean_squared_error: 0.1713 - val_loss: 0.3613 - val_mean_squared_error: 0.1766
# Epoch 26/50
# 57184/57184 [==============================] - 3s 59us/step - loss: 0.3559 - mean_squared_error: 0.1710 - val_loss: 0.3595 - val_mean_squared_error: 0.1756
# Epoch 27/50
# 57184/57184 [==============================] - 3s 57us/step - loss: 0.3558 - mean_squared_error: 0.1713 - val_loss: 0.3614 - val_mean_squared_error: 0.1763
# Epoch 28/50
# 57184/57184 [==============================] - 3s 55us/step - loss: 0.3553 - mean_squared_error: 0.1708 - val_loss: 0.3598 - val_mean_squared_error: 0.1760
# Epoch 29/50
# 57184/57184 [==============================] - 3s 58us/step - loss: 0.3546 - mean_squared_error: 0.1710 - val_loss: 0.3589 - val_mean_squared_error: 0.1758
# Epoch 30/50
# 57184/57184 [==============================] - 3s 57us/step - loss: 0.3548 - mean_squared_error: 0.1709 - val_loss: 0.3592 - val_mean_squared_error: 0.1759
# Epoch 31/50
# 57184/57184 [==============================] - 3s 58us/step - loss: 0.3547 - mean_squared_error: 0.1711 - val_loss: 0.3613 - val_mean_squared_error: 0.1776
# Epoch 32/50
# 57184/57184 [==============================] - 3s 59us/step - loss: 0.3551 - mean_squared_error: 0.1712 - val_loss: 0.3589 - val_mean_squared_error: 0.1746
# Epoch 33/50
# 57184/57184 [==============================] - 3s 54us/step - loss: 0.3544 - mean_squared_error: 0.1708 - val_loss: 0.3622 - val_mean_squared_error: 0.1774
# Epoch 34/50
# 57184/57184 [==============================] - 3s 56us/step - loss: 0.3544 - mean_squared_error: 0.1713 - val_loss: 0.3605 - val_mean_squared_error: 0.1769
# Epoch 35/50
# 57184/57184 [==============================] - 3s 57us/step - loss: 0.3543 - mean_squared_error: 0.1712 - val_loss: 0.3617 - val_mean_squared_error: 0.1780
# Epoch 36/50
# 57184/57184 [==============================] - 3s 58us/step - loss: 0.3532 - mean_squared_error: 0.1706 - val_loss: 0.3575 - val_mean_squared_error: 0.1764
# Epoch 37/50
# 57184/57184 [==============================] - 3s 57us/step - loss: 0.3530 - mean_squared_error: 0.1710 - val_loss: 0.3588 - val_mean_squared_error: 0.1763
# Epoch 38/50
# 57184/57184 [==============================] - 3s 60us/step - loss: 0.3535 - mean_squared_error: 0.1711 - val_loss: 0.3573 - val_mean_squared_error: 0.1753
# Epoch 39/50
# 57184/57184 [==============================] - 3s 59us/step - loss: 0.3526 - mean_squared_error: 0.1709 - val_loss: 0.3583 - val_mean_squared_error: 0.1753
# Epoch 40/50
# 57184/57184 [==============================] - 3s 57us/step - loss: 0.3522 - mean_squared_error: 0.1707 - val_loss: 0.3565 - val_mean_squared_error: 0.1757
# Epoch 41/50
# 57184/57184 [==============================] - 3s 58us/step - loss: 0.3521 - mean_squared_error: 0.1708 - val_loss: 0.3567 - val_mean_squared_error: 0.1758
# Epoch 42/50
# 57184/57184 [==============================] - 3s 54us/step - loss: 0.3521 - mean_squared_error: 0.1710 - val_loss: 0.3560 - val_mean_squared_error: 0.1757
# Epoch 43/50
# 57184/57184 [==============================] - 3s 55us/step - loss: 0.3512 - mean_squared_error: 0.1706 - val_loss: 0.3568 - val_mean_squared_error: 0.1755
# Epoch 44/50
# 57184/57184 [==============================] - 3s 54us/step - loss: 0.3513 - mean_squared_error: 0.1707 - val_loss: 0.3573 - val_mean_squared_error: 0.1765
# Epoch 45/50
# 57184/57184 [==============================] - 3s 59us/step - loss: 0.3509 - mean_squared_error: 0.1707 - val_loss: 0.3560 - val_mean_squared_error: 0.1752
# Epoch 46/50
# 57184/57184 [==============================] - 3s 56us/step - loss: 0.3499 - mean_squared_error: 0.1705 - val_loss: 0.3541 - val_mean_squared_error: 0.1750
# Epoch 47/50
# 57184/57184 [==============================] - 3s 54us/step - loss: 0.3494 - mean_squared_error: 0.1705 - val_loss: 0.3534 - val_mean_squared_error: 0.1752
# Epoch 48/50
# 57184/57184 [==============================] - 3s 54us/step - loss: 0.3495 - mean_squared_error: 0.1709 - val_loss: 0.3553 - val_mean_squared_error: 0.1761
# Epoch 49/50
# 57184/57184 [==============================] - 3s 58us/step - loss: 0.3484 - mean_squared_error: 0.1706 - val_loss: 0.3523 - val_mean_squared_error: 0.1749
# Epoch 50/50
# 57184/57184 [==============================] - 3s 55us/step - loss: 0.3479 - mean_squared_error: 0.1704 - val_loss: 0.3538 - val_mean_squared_error: 0.1770
# Time taken to run: 2.8 minutes

# %%
nn_model_evaluation(nn7, skip_epochs=2, X_train=X_train_short, X_test=X_test_short)
# Out:
# Training MSE: 0.1708
# Validation MSE: 0.1689
#
# Training r2: 0.7096
# Validation r2: 0.7105

# %% [markdown]
# The model with the additional review columns removed performs almost exactly the same as the best previous NN (Model 3). Therefore, because it is able to achieve the same performance with 18 fewer columns, it is the preferred model when choosing which model to put into production as it would require less data and be less computationally expensive.

# %% [markdown]
# ### Model 8: using latitude and longitude instead of boroughs

# %% [markdown]
# The final part of feature engineering to experiment with is to investigate whether using latitude and longitude to represent location might increase performance compared to using borough. To do so, the borough features will be dropped (in addition to the review columns that were already dropped), and latitude and longitude will be added back in and transformed using the same scaler as the rest of the data.

# %%
# Joining the transformed_df (pre-scaling) and the lat_long dataframe, after dropping excess review features
df_lat_long = transformed_df.drop(review_to_drop, axis=1).join(lat_long)

# Dropping borough columns
borough_to_drop = list(df_lat_long.columns[df_lat_long.columns.str.startswith("borough")])
df_lat_long = df_lat_long.drop(borough_to_drop, axis=1)

# Separating X and y
X_lat_long = df_lat_long.drop('price', axis=1)
y_lat_long = df_lat_long.price

# Scaling
scaler = StandardScaler()
X_lat_long = pd.DataFrame(scaler.fit_transform(X_lat_long), columns=list(X_lat_long.columns))

# Splitting into train and test sets
X_train_lat_long, X_test_lat_long, y_train_lat_long, y_test_lat_long = train_test_split(X_lat_long, y_lat_long, test_size=0.2, random_state=123)
# Out:
# C:\Users\Laura\Anaconda3\envs\learn-env\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype uint8, int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\Laura\Anaconda3\envs\learn-env\lib\site-packages\sklearn\base.py:462: DataConversionWarning: Data with input dtype uint8, int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
# Building the model
nn8 = models.Sequential()
nn8.add(layers.Dense(128, input_shape=(X_train_lat_long.shape[1],), kernel_regularizer=regularizers.l1(0.005), activation='relu'))
nn8.add(layers.Dense(256, kernel_regularizer=regularizers.l1(0.005), activation='relu'))
nn8.add(layers.Dense(256, kernel_regularizer=regularizers.l1(0.005), activation='relu'))
nn8.add(layers.Dense(512, kernel_regularizer=regularizers.l1(0.005), activation='relu'))
nn8.add(layers.Dense(1, activation='linear'))

# Compiling the model
nn8.compile(loss='mean_squared_error',
            optimizer='adam',
            metrics=['mean_squared_error'])

# Model summary
print(nn8.summary())

# Visualising the neural network
SVG(model_to_dot(nn8, show_layer_names=False, show_shapes=True).create(prog='dot', format='svg'))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_28 (Dense)             (None, 128)               8064
# _________________________________________________________________
# dense_29 (Dense)             (None, 256)               33024
# _________________________________________________________________
# dense_30 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_31 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_32 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 238,977
# Trainable params: 238,977
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Training the model
nn8_start = time.time()

nn8_history = nn8.fit(X_train_lat_long,
                  y_train_lat_long,
                  epochs=80,
                  batch_size=256,
                  validation_split=0.1)

nn8_end = time.time()

print(f"Time taken to run: {round((nn8_end - nn8_start)/60,1)} minutes")
# Out:
# Train on 57184 samples, validate on 6354 samples
# Epoch 1/80
# 57184/57184 [==============================] - 4s 66us/step - loss: 0.3540 - mean_squared_error: 0.1832 - val_loss: 0.3547 - val_mean_squared_error: 0.1847
# Epoch 2/80
# 57184/57184 [==============================] - 4s 67us/step - loss: 0.3541 - mean_squared_error: 0.1836 - val_loss: 0.3550 - val_mean_squared_error: 0.1849
# Epoch 3/80
# 57184/57184 [==============================] - 4s 65us/step - loss: 0.3536 - mean_squared_error: 0.1835 - val_loss: 0.3532 - val_mean_squared_error: 0.1837
# Epoch 4/80
# 57184/57184 [==============================] - 4s 71us/step - loss: 0.3534 - mean_squared_error: 0.1834 - val_loss: 0.3542 - val_mean_squared_error: 0.1846
# Epoch 5/80
# 57184/57184 [==============================] - 4s 78us/step - loss: 0.3533 - mean_squared_error: 0.1833 - val_loss: 0.3533 - val_mean_squared_error: 0.1840
# Epoch 6/80
# 57184/57184 [==============================] - 5s 86us/step - loss: 0.3534 - mean_squared_error: 0.1835 - val_loss: 0.3555 - val_mean_squared_error: 0.1855
# Epoch 7/80
# 57184/57184 [==============================] - 4s 76us/step - loss: 0.3528 - mean_squared_error: 0.1832 - val_loss: 0.3547 - val_mean_squared_error: 0.1853
# Epoch 8/80
# 57184/57184 [==============================] - 4s 67us/step - loss: 0.3530 - mean_squared_error: 0.1835 - val_loss: 0.3538 - val_mean_squared_error: 0.1848
# Epoch 9/80
# 57184/57184 [==============================] - 4s 70us/step - loss: 0.3530 - mean_squared_error: 0.1836 - val_loss: 0.3524 - val_mean_squared_error: 0.1832
# Epoch 10/80
# 57184/57184 [==============================] - 4s 68us/step - loss: 0.3527 - mean_squared_error: 0.1834 - val_loss: 0.3542 - val_mean_squared_error: 0.1853
# Epoch 11/80
# 57184/57184 [==============================] - 4s 63us/step - loss: 0.3530 - mean_squared_error: 0.1838 - val_loss: 0.3525 - val_mean_squared_error: 0.1835
# Epoch 12/80
# 57184/57184 [==============================] - 4s 62us/step - loss: 0.3526 - mean_squared_error: 0.1836 - val_loss: 0.3521 - val_mean_squared_error: 0.1834
# Epoch 13/80
# 57184/57184 [==============================] - 3s 60us/step - loss: 0.3524 - mean_squared_error: 0.1834 - val_loss: 0.3516 - val_mean_squared_error: 0.1833
# Epoch 14/80
# 57184/57184 [==============================] - 3s 60us/step - loss: 0.3522 - mean_squared_error: 0.1834 - val_loss: 0.3527 - val_mean_squared_error: 0.1837
# Epoch 15/80
# 57184/57184 [==============================] - 3s 61us/step - loss: 0.3522 - mean_squared_error: 0.1833 - val_loss: 0.3522 - val_mean_squared_error: 0.1834
# Epoch 16/80
# 57184/57184 [==============================] - 4s 62us/step - loss: 0.3519 - mean_squared_error: 0.1831 - val_loss: 0.3535 - val_mean_squared_error: 0.1852
# Epoch 17/80
# 57184/57184 [==============================] - 4s 70us/step - loss: 0.3516 - mean_squared_error: 0.1830 - val_loss: 0.3519 - val_mean_squared_error: 0.1834
# Epoch 18/80
# 57184/57184 [==============================] - 4s 70us/step - loss: 0.3520 - mean_squared_error: 0.1834 - val_loss: 0.3533 - val_mean_squared_error: 0.1847
# Epoch 19/80
# 57184/57184 [==============================] - 4s 71us/step - loss: 0.3520 - mean_squared_error: 0.1835 - val_loss: 0.3528 - val_mean_squared_error: 0.1848
# Epoch 20/80
# 57184/57184 [==============================] - 4s 69us/step - loss: 0.3519 - mean_squared_error: 0.1835 - val_loss: 0.3515 - val_mean_squared_error: 0.1833
# Epoch 21/80
# 57184/57184 [==============================] - 5s 84us/step - loss: 0.3520 - mean_squared_error: 0.1837 - val_loss: 0.3516 - val_mean_squared_error: 0.1831
# Epoch 22/80
# 57184/57184 [==============================] - 4s 76us/step - loss: 0.3514 - mean_squared_error: 0.1831 - val_loss: 0.3517 - val_mean_squared_error: 0.1837
# Epoch 23/80
# 57184/57184 [==============================] - 4s 77us/step - loss: 0.3516 - mean_squared_error: 0.1834 - val_loss: 0.3529 - val_mean_squared_error: 0.1847
# Epoch 24/80
# 57184/57184 [==============================] - 4s 72us/step - loss: 0.3517 - mean_squared_error: 0.1835 - val_loss: 0.3532 - val_mean_squared_error: 0.1854error
# Epoch 25/80
# 57184/57184 [==============================] - 4s 71us/step - loss: 0.3515 - mean_squared_error: 0.1834 - val_loss: 0.3510 - val_mean_squared_error: 0.1830
# Epoch 26/80
# 57184/57184 [==============================] - 4s 68us/step - loss: 0.3516 - mean_squared_error: 0.1834 - val_loss: 0.3521 - val_mean_squared_error: 0.1844
# Epoch 27/80
# 57184/57184 [==============================] - 4s 62us/step - loss: 0.3516 - mean_squared_error: 0.1837 - val_loss: 0.3521 - val_mean_squared_error: 0.1842error:
# Epoch 28/80
# 57184/57184 [==============================] - 4s 64us/step - loss: 0.3515 - mean_squared_error: 0.1835 - val_loss: 0.3528 - val_mean_squared_error: 0.1847
# Epoch 29/80
# 57184/57184 [==============================] - 3s 60us/step - loss: 0.3516 - mean_squared_error: 0.1837 - val_loss: 0.3516 - val_mean_squared_error: 0.1836
# Epoch 30/80
# 57184/57184 [==============================] - 3s 61us/step - loss: 0.3514 - mean_squared_error: 0.1835 - val_loss: 0.3530 - val_mean_squared_error: 0.1851
# Epoch 31/80
# 57184/57184 [==============================] - 4s 70us/step - loss: 0.3518 - mean_squared_error: 0.1840 - val_loss: 0.3526 - val_mean_squared_error: 0.1850
# Epoch 32/80
# 57184/57184 [==============================] - 4s 71us/step - loss: 0.3512 - mean_squared_error: 0.1834 - val_loss: 0.3520 - val_mean_squared_error: 0.1843
# Epoch 33/80
# 57184/57184 [==============================] - 4s 69us/step - loss: 0.3508 - mean_squared_error: 0.1832 - val_loss: 0.3525 - val_mean_squared_error: 0.1849
# Epoch 34/80
# 57184/57184 [==============================] - 4s 70us/step - loss: 0.3511 - mean_squared_error: 0.1834 - val_loss: 0.3527 - val_mean_squared_error: 0.1851
# Epoch 35/80
# 57184/57184 [==============================] - 4s 71us/step - loss: 0.3509 - mean_squared_error: 0.1834 - val_loss: 0.3527 - val_mean_squared_error: 0.1851
# Epoch 36/80
# 57184/57184 [==============================] - 4s 71us/step - loss: 0.3509 - mean_squared_error: 0.1833 - val_loss: 0.3528 - val_mean_squared_error: 0.1851
# Epoch 37/80
# 57184/57184 [==============================] - 4s 70us/step - loss: 0.3509 - mean_squared_error: 0.1834 - val_loss: 0.3510 - val_mean_squared_error: 0.1841
# Epoch 38/80
# 57184/57184 [==============================] - 4s 71us/step - loss: 0.3508 - mean_squared_error: 0.1834 - val_loss: 0.3524 - val_mean_squared_error: 0.1850
# Epoch 39/80
# 57184/57184 [==============================] - 4s 68us/step - loss: 0.3510 - mean_squared_error: 0.1836 - val_loss: 0.3504 - val_mean_squared_error: 0.1836
# Epoch 40/80
# 57184/57184 [==============================] - 4s 67us/step - loss: 0.3505 - mean_squared_error: 0.1832 - val_loss: 0.3496 - val_mean_squared_error: 0.1827
# Epoch 41/80
# 57184/57184 [==============================] - ETA: 0s - loss: 0.3509 - mean_squared_error: 0.1836 ETA: 0s - loss: 0.3523 - mean - 4s 69us/step - loss: 0.3509 - mean_squared_error: 0.1836 - val_loss: 0.3503 - val_mean_squared_error: 0.1830
# Epoch 42/80
# 57184/57184 [==============================] - 4s 67us/step - loss: 0.3507 - mean_squared_error: 0.1836 - val_loss: 0.3521 - val_mean_squared_error: 0.1846
# Epoch 43/80
# 57184/57184 [==============================] - 4s 69us/step - loss: 0.3501 - mean_squared_error: 0.1829 - val_loss: 0.3506 - val_mean_squared_error: 0.1834
# Epoch 44/80
# 57184/57184 [==============================] - 4s 70us/step - loss: 0.3505 - mean_squared_error: 0.1834 - val_loss: 0.3504 - val_mean_squared_error: 0.1836
# Epoch 45/80
# 57184/57184 [==============================] - 4s 69us/step - loss: 0.3505 - mean_squared_error: 0.1833 - val_loss: 0.3513 - val_mean_squared_error: 0.1842
# Epoch 46/80
# 57184/57184 [==============================] - 4s 67us/step - loss: 0.3503 - mean_squared_error: 0.1833 - val_loss: 0.3507 - val_mean_squared_error: 0.1839
# Epoch 47/80
# 57184/57184 [==============================] - 3s 60us/step - loss: 0.3503 - mean_squared_error: 0.1832 - val_loss: 0.3513 - val_mean_squared_error: 0.1841
# Epoch 48/80
# 57184/57184 [==============================] - 3s 61us/step - loss: 0.3501 - mean_squared_error: 0.1832 - val_loss: 0.3512 - val_mean_squared_error: 0.1845
# Epoch 49/80
# 57184/57184 [==============================] - 4s 63us/step - loss: 0.3502 - mean_squared_error: 0.1835 - val_loss: 0.3521 - val_mean_squared_error: 0.1851
# Epoch 50/80
# 57184/57184 [==============================] - 4s 70us/step - loss: 0.3501 - mean_squared_error: 0.1833 - val_loss: 0.3493 - val_mean_squared_error: 0.1827
# Epoch 51/80
# 57184/57184 [==============================] - 4s 71us/step - loss: 0.3502 - mean_squared_error: 0.1836 - val_loss: 0.3502 - val_mean_squared_error: 0.1838
# Epoch 52/80
# 57184/57184 [==============================] - 4s 73us/step - loss: 0.3498 - mean_squared_error: 0.1830 - val_loss: 0.3512 - val_mean_squared_error: 0.1845
# Epoch 53/80
# 57184/57184 [==============================] - 4s 71us/step - loss: 0.3498 - mean_squared_error: 0.1831 - val_loss: 0.3498 - val_mean_squared_error: 0.1835
# Epoch 54/80
# 57184/57184 [==============================] - 4s 71us/step - loss: 0.3499 - mean_squared_error: 0.1834 - val_loss: 0.3524 - val_mean_squared_error: 0.1858
# Epoch 55/80
# 57184/57184 [==============================] - 3s 56us/step - loss: 0.3499 - mean_squared_error: 0.1833 - val_loss: 0.3511 - val_mean_squared_error: 0.1848
# Epoch 56/80
# 57184/57184 [==============================] - 3s 56us/step - loss: 0.3497 - mean_squared_error: 0.1830 - val_loss: 0.3511 - val_mean_squared_error: 0.1845
# Epoch 57/80
# 57184/57184 [==============================] - 3s 57us/step - loss: 0.3499 - mean_squared_error: 0.1833 - val_loss: 0.3522 - val_mean_squared_error: 0.1857
# Epoch 58/80
# 57184/57184 [==============================] - 3s 58us/step - loss: 0.3499 - mean_squared_error: 0.1835 - val_loss: 0.3507 - val_mean_squared_error: 0.1841
# Epoch 59/80
# 57184/57184 [==============================] - 3s 56us/step - loss: 0.3499 - mean_squared_error: 0.1834 - val_loss: 0.3510 - val_mean_squared_error: 0.1849
# Epoch 60/80
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.3499 - mean_squared_error: 0.1835 - val_loss: 0.3500 - val_mean_squared_error: 0.1834
# Epoch 61/80
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.3497 - mean_squared_error: 0.1833 - val_loss: 0.3502 - val_mean_squared_error: 0.1841
# Epoch 62/80
# 57184/57184 [==============================] - 3s 54us/step - loss: 0.3499 - mean_squared_error: 0.1836 - val_loss: 0.3521 - val_mean_squared_error: 0.1856
# Epoch 63/80
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.3500 - mean_squared_error: 0.1837 - val_loss: 0.3499 - val_mean_squared_error: 0.1840
# Epoch 64/80
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.3498 - mean_squared_error: 0.1836 - val_loss: 0.3514 - val_mean_squared_error: 0.1853
# Epoch 65/80
# 57184/57184 [==============================] - 3s 59us/step - loss: 0.3496 - mean_squared_error: 0.1833 - val_loss: 0.3509 - val_mean_squared_error: 0.1847
# Epoch 66/80
# 57184/57184 [==============================] - 3s 57us/step - loss: 0.3498 - mean_squared_error: 0.1836 - val_loss: 0.3499 - val_mean_squared_error: 0.1839
# Epoch 67/80
# 57184/57184 [==============================] - 3s 56us/step - loss: 0.3496 - mean_squared_error: 0.1834 - val_loss: 0.3504 - val_mean_squared_error: 0.1846
# Epoch 68/80
# 57184/57184 [==============================] - 3s 55us/step - loss: 0.3493 - mean_squared_error: 0.1833 - val_loss: 0.3519 - val_mean_squared_error: 0.1857
# Epoch 69/80
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.3497 - mean_squared_error: 0.1836 - val_loss: 0.3521 - val_mean_squared_error: 0.1861
# Epoch 70/80
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.3495 - mean_squared_error: 0.1835 - val_loss: 0.3498 - val_mean_squared_error: 0.1843
# Epoch 71/80
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.3494 - mean_squared_error: 0.1835 - val_loss: 0.3506 - val_mean_squared_error: 0.1846
# Epoch 72/80
# 57184/57184 [==============================] - 3s 55us/step - loss: 0.3495 - mean_squared_error: 0.1834 - val_loss: 0.3501 - val_mean_squared_error: 0.1843
# Epoch 73/80
# 57184/57184 [==============================] - 3s 54us/step - loss: 0.3495 - mean_squared_error: 0.1835 - val_loss: 0.3494 - val_mean_squared_error: 0.1837
# Epoch 74/80
# 57184/57184 [==============================] - 3s 59us/step - loss: 0.3497 - mean_squared_error: 0.1837 - val_loss: 0.3494 - val_mean_squared_error: 0.1837
# Epoch 75/80
# 57184/57184 [==============================] - 3s 56us/step - loss: 0.3492 - mean_squared_error: 0.1834 - val_loss: 0.3501 - val_mean_squared_error: 0.1843
# Epoch 76/80
# 57184/57184 [==============================] - 3s 54us/step - loss: 0.3497 - mean_squared_error: 0.1838 - val_loss: 0.3506 - val_mean_squared_error: 0.1849
# Epoch 77/80
# 57184/57184 [==============================] - 3s 55us/step - loss: 0.3490 - mean_squared_error: 0.1831 - val_loss: 0.3500 - val_mean_squared_error: 0.1841
# Epoch 78/80
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.3491 - mean_squared_error: 0.1833 - val_loss: 0.3500 - val_mean_squared_error: 0.1844
# Epoch 79/80
# 57184/57184 [==============================] - 3s 52us/step - loss: 0.3495 - mean_squared_error: 0.1836 - val_loss: 0.3506 - val_mean_squared_error: 0.1850
# Epoch 80/80
# 57184/57184 [==============================] - 3s 53us/step - loss: 0.3491 - mean_squared_error: 0.1833 - val_loss: 0.3507 - val_mean_squared_error: 0.1851
# Time taken to run: 4.9 minutes

# %%
nn_model_evaluation(nn8, X_train=X_train_lat_long, X_test=X_test_lat_long, y_train=y_train_lat_long, y_test=y_test_lat_long)
# Out:
# Training MSE: 0.1835
# Validation MSE: 0.1825
#
# Training r2: 0.688
# Validation r2: 0.6872

# %% [markdown]
# Using latitude and longitude performs worse than using borough for location.

# %% [markdown]
# ### Model 9: five-layer neural network with a min-max scaler

# %% [markdown]
# Model 3 is still the best model. As a final attempt to improve its performance, an alternative scaling method will be used (min-max scaling to a range of 0-1) and an additional layer will be added.

# %%
# Dropping review columns from the original dataframe (after log transformation)
df_minmax = transformed_df.drop(review_to_drop, axis=1)

# Separating X and y
X_minmax = df_minmax.drop('price', axis=1)
y_minmax = df_minmax.price

# Scaling
scaler = MinMaxScaler(feature_range=(0, 1))
X_minmax = pd.DataFrame(scaler.fit_transform(X_minmax), columns=list(X_minmax.columns))

# Splitting into train and test sets
X_train_minmax, X_test_minmax, y_train_minmax, y_test_minmax = train_test_split(X_minmax, y_minmax, test_size=0.2, random_state=123)
# Out:
# C:\Users\Laura\Anaconda3\envs\learn-env\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype uint8, int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
# Building the model
nn9 = models.Sequential()
nn9.add(layers.Dense(128, input_shape=(X_train_minmax.shape[1],), kernel_regularizer=regularizers.l1(0.005), activation='relu'))
nn9.add(layers.Dense(256, kernel_regularizer=regularizers.l1(0.005), activation='relu'))
nn9.add(layers.Dense(256, kernel_regularizer=regularizers.l1(0.005), activation='relu'))
nn9.add(layers.Dense(512, kernel_regularizer=regularizers.l1(0.005), activation='relu'))
nn9.add(layers.Dense(1024, kernel_regularizer=regularizers.l1(0.005), activation='relu'))
nn9.add(layers.Dense(1, activation='linear'))

# Compiling the model
nn9.compile(loss='mean_squared_error',
            optimizer='adam',
            metrics=['mean_squared_error'])

# Model summary
print(nn9.summary())

# Visualising the neural network
SVG(model_to_dot(nn9, show_layer_names=False, show_shapes=True).create(prog='dot', format='svg'))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_33 (Dense)             (None, 128)               12032
# _________________________________________________________________
# dense_34 (Dense)             (None, 256)               33024
# _________________________________________________________________
# dense_35 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_36 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_37 (Dense)             (None, 1024)              525312
# _________________________________________________________________
# dense_38 (Dense)             (None, 1)                 1025
# =================================================================
# Total params: 768,769
# Trainable params: 768,769
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Training the model
nn9_start = time.time()

nn9_history = nn9.fit(X_train_minmax,
                  y_train_minmax,
                  epochs=80,
                  batch_size=256,
                  validation_split = 0.1)

nn9_end = time.time()

print(f"Time taken to run: {round((nn9_end - nn9_start)/60,1)} minutes")
# Out:
# Train on 57184 samples, validate on 6354 samples
# Epoch 1/80
# 57184/57184 [==============================] - 10s 170us/step - loss: 31.6174 - mean_squared_error: 0.6529 - val_loss: 5.5732 - val_mean_squared_error: 0.2705
# Epoch 2/80
# 57184/57184 [==============================] - 8s 146us/step - loss: 3.3681 - mean_squared_error: 0.2604 - val_loss: 2.0893 - val_mean_squared_error: 0.2550
# Epoch 3/80
# 57184/57184 [==============================] - 8s 144us/step - loss: 1.5973 - mean_squared_error: 0.2482 - val_loss: 1.2652 - val_mean_squared_error: 0.2424
# Epoch 4/80
# 57184/57184 [==============================] - 8s 141us/step - loss: 1.1044 - mean_squared_error: 0.2375 - val_loss: 0.9833 - val_mean_squared_error: 0.2345
# Epoch 5/80
# 57184/57184 [==============================] - 9s 156us/step - loss: 0.9168 - mean_squared_error: 0.2306 - val_loss: 0.8646 - val_mean_squared_error: 0.2278
# Epoch 6/80
# 57184/57184 [==============================] - 9s 160us/step - loss: 0.8385 - mean_squared_error: 0.2268 - val_loss: 0.8118 - val_mean_squared_error: 0.2242
# Epoch 7/80
# 57184/57184 [==============================] - 9s 151us/step - loss: 0.7955 - mean_squared_error: 0.2216 - val_loss: 0.7808 - val_mean_squared_error: 0.2206
# Epoch 8/80
# 57184/57184 [==============================] - 9s 158us/step - loss: 0.7722 - mean_squared_error: 0.2179 - val_loss: 0.7653 - val_mean_squared_error: 0.2182
# Epoch 9/80
# 57184/57184 [==============================] - 9s 159us/step - loss: 0.7579 - mean_squared_error: 0.2135 - val_loss: 0.7533 - val_mean_squared_error: 0.2127
# Epoch 10/80
# 57184/57184 [==============================] - 9s 152us/step - loss: 0.7489 - mean_squared_error: 0.2095 - val_loss: 0.7482 - val_mean_squared_error: 0.2085
# Epoch 11/80
# 57184/57184 [==============================] - 9s 153us/step - loss: 0.7420 - mean_squared_error: 0.2055 - val_loss: 0.7396 - val_mean_squared_error: 0.2048
# Epoch 12/80
# 57184/57184 [==============================] - 9s 152us/step - loss: 0.7360 - mean_squared_error: 0.2018 - val_loss: 0.7381 - val_mean_squared_error: 0.2048
# Epoch 13/80
# 57184/57184 [==============================] - 9s 150us/step - loss: 0.7329 - mean_squared_error: 0.1993 - val_loss: 0.7329 - val_mean_squared_error: 0.2000
# Epoch 14/80
# 57184/57184 [==============================] - 8s 148us/step - loss: 0.7294 - mean_squared_error: 0.1970 - val_loss: 0.7302 - val_mean_squared_error: 0.1978
# Epoch 15/80
# 57184/57184 [==============================] - 8s 136us/step - loss: 0.7269 - mean_squared_error: 0.1948 - val_loss: 0.7292 - val_mean_squared_error: 0.1970
# Epoch 16/80
# 57184/57184 [==============================] - 9s 151us/step - loss: 0.7239 - mean_squared_error: 0.1932 - val_loss: 0.7254 - val_mean_squared_error: 0.1949
# Epoch 17/80
# 57184/57184 [==============================] - 8s 142us/step - loss: 0.7235 - mean_squared_error: 0.1927 - val_loss: 0.7231 - val_mean_squared_error: 0.1948
# Epoch 18/80
# 57184/57184 [==============================] - 8s 137us/step - loss: 0.7204 - mean_squared_error: 0.1911 - val_loss: 0.7259 - val_mean_squared_error: 0.1970
# Epoch 19/80
# 57184/57184 [==============================] - 9s 166us/step - loss: 0.7191 - mean_squared_error: 0.1908 - val_loss: 0.7206 - val_mean_squared_error: 0.1934
# Epoch 20/80
# 57184/57184 [==============================] - 9s 159us/step - loss: 0.7173 - mean_squared_error: 0.1901 - val_loss: 0.7181 - val_mean_squared_error: 0.1926
# Epoch 21/80
# 57184/57184 [==============================] - 10s 179us/step - loss: 0.7164 - mean_squared_error: 0.1897 - val_loss: 0.7187 - val_mean_squared_error: 0.1932
# Epoch 22/80
# 57184/57184 [==============================] - 10s 171us/step - loss: 0.7154 - mean_squared_error: 0.1896 - val_loss: 0.7206 - val_mean_squared_error: 0.1961
# Epoch 23/80
# 57184/57184 [==============================] - 9s 165us/step - loss: 0.7148 - mean_squared_error: 0.1895 - val_loss: 0.7170 - val_mean_squared_error: 0.1925
# Epoch 24/80
# 57184/57184 [==============================] - 8s 136us/step - loss: 0.7138 - mean_squared_error: 0.1892 - val_loss: 0.7194 - val_mean_squared_error: 0.1942
# Epoch 25/80
# 57184/57184 [==============================] - 9s 149us/step - loss: 0.7137 - mean_squared_error: 0.1894 - val_loss: 0.7166 - val_mean_squared_error: 0.1932
# Epoch 26/80
# 57184/57184 [==============================] - 9s 159us/step - loss: 0.7132 - mean_squared_error: 0.1894 - val_loss: 0.7144 - val_mean_squared_error: 0.1914
# Epoch 27/80
# 57184/57184 [==============================] - 8s 144us/step - loss: 0.7115 - mean_squared_error: 0.1890 - val_loss: 0.7146 - val_mean_squared_error: 0.1934
# Epoch 28/80
# 57184/57184 [==============================] - 11s 190us/step - loss: 0.7115 - mean_squared_error: 0.1892 - val_loss: 0.7137 - val_mean_squared_error: 0.1915
# Epoch 29/80
# 57184/57184 [==============================] - 9s 161us/step - loss: 0.7116 - mean_squared_error: 0.1894 - val_loss: 0.7139 - val_mean_squared_error: 0.1923
# Epoch 30/80
# 57184/57184 [==============================] - 8s 140us/step - loss: 0.7105 - mean_squared_error: 0.1889 - val_loss: 0.7150 - val_mean_squared_error: 0.1934
# Epoch 31/80
# 57184/57184 [==============================] - 8s 144us/step - loss: 0.7101 - mean_squared_error: 0.1889 - val_loss: 0.7140 - val_mean_squared_error: 0.1931
# Epoch 32/80
# 57184/57184 [==============================] - 8s 145us/step - loss: 0.7100 - mean_squared_error: 0.1891 - val_loss: 0.7103 - val_mean_squared_error: 0.1911
# Epoch 33/80
# 57184/57184 [==============================] - 8s 143us/step - loss: 0.7095 - mean_squared_error: 0.1888 - val_loss: 0.7134 - val_mean_squared_error: 0.1930
# Epoch 34/80
# 57184/57184 [==============================] - 8s 142us/step - loss: 0.7094 - mean_squared_error: 0.1892 - val_loss: 0.7141 - val_mean_squared_error: 0.1951
# Epoch 35/80
# 57184/57184 [==============================] - 8s 137us/step - loss: 0.7085 - mean_squared_error: 0.1886 - val_loss: 0.7125 - val_mean_squared_error: 0.1937
# Epoch 36/80
# 57184/57184 [==============================] - 8s 140us/step - loss: 0.7082 - mean_squared_error: 0.1891 - val_loss: 0.7102 - val_mean_squared_error: 0.1914
# Epoch 37/80
# 57184/57184 [==============================] - 8s 137us/step - loss: 0.7080 - mean_squared_error: 0.1893 - val_loss: 0.7235 - val_mean_squared_error: 0.2041
# Epoch 38/80
# 57184/57184 [==============================] - 8s 139us/step - loss: 0.7073 - mean_squared_error: 0.1887 - val_loss: 0.7124 - val_mean_squared_error: 0.1950
# Epoch 39/80
# 57184/57184 [==============================] - 8s 147us/step - loss: 0.7066 - mean_squared_error: 0.1885 - val_loss: 0.7144 - val_mean_squared_error: 0.1963
# Epoch 40/80
# 57184/57184 [==============================] - 10s 166us/step - loss: 0.7061 - mean_squared_error: 0.1885 - val_loss: 0.7091 - val_mean_squared_error: 0.1922
# Epoch 41/80
# 57184/57184 [==============================] - 9s 159us/step - loss: 0.7072 - mean_squared_error: 0.1899 - val_loss: 0.7097 - val_mean_squared_error: 0.1938
# Epoch 42/80
# 57184/57184 [==============================] - 9s 159us/step - loss: 0.7056 - mean_squared_error: 0.1888 - val_loss: 0.7099 - val_mean_squared_error: 0.1944
# Epoch 43/80
# 57184/57184 [==============================] - 10s 169us/step - loss: 0.7050 - mean_squared_error: 0.1889 - val_loss: 0.7072 - val_mean_squared_error: 0.1916
# Epoch 44/80
# 57184/57184 [==============================] - 8s 139us/step - loss: 0.7039 - mean_squared_error: 0.1883 - val_loss: 0.7079 - val_mean_squared_error: 0.1922
# Epoch 45/80
# 57184/57184 [==============================] - 8s 148us/step - loss: 0.7036 - mean_squared_error: 0.1886 - val_loss: 0.7065 - val_mean_squared_error: 0.1928
# Epoch 46/80
# 57184/57184 [==============================] - 9s 164us/step - loss: 0.7030 - mean_squared_error: 0.1888 - val_loss: 0.7072 - val_mean_squared_error: 0.1925
# Epoch 47/80
# 57184/57184 [==============================] - 8s 136us/step - loss: 0.7026 - mean_squared_error: 0.1887 - val_loss: 0.7036 - val_mean_squared_error: 0.1912
# Epoch 48/80
# 57184/57184 [==============================] - 8s 137us/step - loss: 0.7022 - mean_squared_error: 0.1887 - val_loss: 0.7059 - val_mean_squared_error: 0.1918
# Epoch 49/80
# 57184/57184 [==============================] - 8s 146us/step - loss: 0.7023 - mean_squared_error: 0.1894 - val_loss: 0.7039 - val_mean_squared_error: 0.1916
# Epoch 50/80
# 57184/57184 [==============================] - 9s 162us/step - loss: 0.7019 - mean_squared_error: 0.1894 - val_loss: 0.7023 - val_mean_squared_error: 0.1910
# Epoch 51/80
# 57184/57184 [==============================] - 9s 164us/step - loss: 0.7005 - mean_squared_error: 0.1885 - val_loss: 0.7018 - val_mean_squared_error: 0.1908
# Epoch 52/80
# 57184/57184 [==============================] - 9s 163us/step - loss: 0.7015 - mean_squared_error: 0.1896 - val_loss: 0.7027 - val_mean_squared_error: 0.1918
# Epoch 53/80
# 57184/57184 [==============================] - 9s 165us/step - loss: 0.7001 - mean_squared_error: 0.1885 - val_loss: 0.7025 - val_mean_squared_error: 0.1913
# Epoch 54/80
# 57184/57184 [==============================] - 10s 172us/step - loss: 0.7003 - mean_squared_error: 0.1888 - val_loss: 0.7023 - val_mean_squared_error: 0.1906
# Epoch 55/80
# 57184/57184 [==============================] - 9s 165us/step - loss: 0.6999 - mean_squared_error: 0.1886 - val_loss: 0.7028 - val_mean_squared_error: 0.1913
# Epoch 56/80
# 57184/57184 [==============================] - 9s 153us/step - loss: 0.6999 - mean_squared_error: 0.1887 - val_loss: 0.7007 - val_mean_squared_error: 0.1909
# Epoch 57/80
# 57184/57184 [==============================] - 9s 159us/step - loss: 0.6996 - mean_squared_error: 0.1886 - val_loss: 0.7039 - val_mean_squared_error: 0.1928
# Epoch 58/80
# 57184/57184 [==============================] - 9s 156us/step - loss: 0.6994 - mean_squared_error: 0.1885 - val_loss: 0.7012 - val_mean_squared_error: 0.1908
# Epoch 59/80
# 57184/57184 [==============================] - 8s 148us/step - loss: 0.6992 - mean_squared_error: 0.1886 - val_loss: 0.7054 - val_mean_squared_error: 0.1945
# Epoch 60/80
# 57184/57184 [==============================] - 9s 153us/step - loss: 0.6994 - mean_squared_error: 0.1889 - val_loss: 0.7017 - val_mean_squared_error: 0.1912
# Epoch 61/80
# 57184/57184 [==============================] - 9s 150us/step - loss: 0.6988 - mean_squared_error: 0.1886 - val_loss: 0.7027 - val_mean_squared_error: 0.1934
# Epoch 62/80
# 57184/57184 [==============================] - 10s 168us/step - loss: 0.6989 - mean_squared_error: 0.1889 - val_loss: 0.7029 - val_mean_squared_error: 0.1938
# Epoch 63/80
# 57184/57184 [==============================] - 9s 160us/step - loss: 0.6993 - mean_squared_error: 0.1896 - val_loss: 0.7013 - val_mean_squared_error: 0.1915
# Epoch 64/80
# 57184/57184 [==============================] - 8s 138us/step - loss: 0.6979 - mean_squared_error: 0.1883 - val_loss: 0.7105 - val_mean_squared_error: 0.2016
# Epoch 65/80
# 57184/57184 [==============================] - 8s 136us/step - loss: 0.6980 - mean_squared_error: 0.1886 - val_loss: 0.7001 - val_mean_squared_error: 0.1916
# Epoch 66/80
# 57184/57184 [==============================] - 8s 142us/step - loss: 0.6975 - mean_squared_error: 0.1882 - val_loss: 0.7024 - val_mean_squared_error: 0.1932
# Epoch 67/80
# 57184/57184 [==============================] - 9s 164us/step - loss: 0.6982 - mean_squared_error: 0.1892 - val_loss: 0.7048 - val_mean_squared_error: 0.1965
# Epoch 68/80
# 57184/57184 [==============================] - 9s 151us/step - loss: 0.6972 - mean_squared_error: 0.1885 - val_loss: 0.6991 - val_mean_squared_error: 0.1915
# Epoch 69/80
# 57184/57184 [==============================] - 9s 163us/step - loss: 0.6976 - mean_squared_error: 0.1889 - val_loss: 0.7022 - val_mean_squared_error: 0.1932
# Epoch 70/80
# 57184/57184 [==============================] - 8s 135us/step - loss: 0.6967 - mean_squared_error: 0.1884 - val_loss: 0.6984 - val_mean_squared_error: 0.1905
# Epoch 71/80
# 57184/57184 [==============================] - 8s 135us/step - loss: 0.6969 - mean_squared_error: 0.1887 - val_loss: 0.7002 - val_mean_squared_error: 0.1926
# Epoch 72/80
# 57184/57184 [==============================] - 8s 138us/step - loss: 0.6967 - mean_squared_error: 0.1887 - val_loss: 0.6982 - val_mean_squared_error: 0.1910
# Epoch 73/80
# 57184/57184 [==============================] - 8s 135us/step - loss: 0.6972 - mean_squared_error: 0.1893 - val_loss: 0.7004 - val_mean_squared_error: 0.1926
# Epoch 74/80
# 57184/57184 [==============================] - 8s 136us/step - loss: 0.6961 - mean_squared_error: 0.1884 - val_loss: 0.6988 - val_mean_squared_error: 0.1926
# Epoch 75/80
# 57184/57184 [==============================] - 8s 139us/step - loss: 0.6972 - mean_squared_error: 0.1899 - val_loss: 0.6977 - val_mean_squared_error: 0.1903
# Epoch 76/80
# 57184/57184 [==============================] - 8s 145us/step - loss: 0.6956 - mean_squared_error: 0.1883 - val_loss: 0.6983 - val_mean_squared_error: 0.1910
# Epoch 77/80
# 57184/57184 [==============================] - 9s 163us/step - loss: 0.6955 - mean_squared_error: 0.1883 - val_loss: 0.6973 - val_mean_squared_error: 0.1918
# Epoch 78/80
# 57184/57184 [==============================] - 9s 153us/step - loss: 0.6957 - mean_squared_error: 0.1889 - val_loss: 0.6982 - val_mean_squared_error: 0.1912
# Epoch 79/80
# 57184/57184 [==============================] - 8s 138us/step - loss: 0.6953 - mean_squared_error: 0.1886 - val_loss: 0.6967 - val_mean_squared_error: 0.1906
# Epoch 80/80
# 57184/57184 [==============================] - 8s 136us/step - loss: 0.6951 - mean_squared_error: 0.1885 - val_loss: 0.6977 - val_mean_squared_error: 0.1911
# Time taken to run: 11.5 minutes

# %%
nn_model_evaluation(nn9, skip_epochs=4, X_train=X_train_minmax, X_test=X_test_minmax, y_train=y_train_minmax, y_test=y_test_minmax)
# Out:
# Training MSE: 0.1877
# Validation MSE: 0.1847
#
# Training r2: 0.6808
# Validation r2: 0.6834

# %% [markdown]
# The five-layer NN performs worse than the previous best-scoring NN (Model 7).

# %% [markdown]
# ### Final model selection

# %% [markdown]
# Overall, the XGBoost model (Model 1) is the preferred model, which performs ever so slightly better than the best neural network (Model 7) and is less computationally expensive. It could possibly be improved further with hyper-parameter tuning.

# %% [markdown]
# ***

# %% [markdown]
# # Conclusions and recommendations

# %% [markdown]
# This is one of those situations where deep learning simply isn't necessary for prediction, and a machine learning model performs just as well.
# However, even in the best performing model, the model was only able to explain 73% of the variation in price. The remaining 27% is probably made up of features that were not present in the data. It is likely that a significant proportion of this unexplained variance is due to variations in the listing photos. The photos of properties on Airbnb are very important in encouraging guests to book, and so can also be expected to have a significant impact on price - better photos (primarily better quality properties and furnishings, but also better quality photography) equal higher prices.

# %% [markdown]
# **Potential directions for future work**
# - Find a way to incorporate image quality into the model, e.g. by using the output of a convolutional neural network to assess image quality as an input into the pricing model
# - Use better quality/more accurate data which includes the actual average prices paid per night
# - Include a wider geographic area, e.g. the rest of the UK or other major cities around the world
# - Augment the model with natural language processing (NLP) of listing descriptions and/or reviews, e.g. for sentiment analysis or looking for keywords
# - In addition to predicting base prices, a sequence model could be created to calculate daily rates using data on seasonality and occupancy, which would allow the creation of actual pricing software
# - Tailor the model more specifically to new listings in order to help hosts set prices for new properties, by removing features that would not be known at the time - e.g. other fees, availability and reviews
